# %%
##Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import random as rd
np.random.seed(sum(map(ord, "aesthetics")))

# %%
##              **** csv file data cleansing ****
## Problems with our data was evident when attempts to convert columns from
## strings to numbers were failing, and our first attempt to fix this was 
## to remove the companies and investments that had foreign currencies.  
## Further data cleansing continued with the organizations.csv file which 
## had over 497,523 records.  I merged the organizations.csv file with the 
## completed merged_df to create a smaller file new_org, but using new_org
## in place of organizations.csv caused the final merged_df record count to 
## increase.  At that point, I ran new_org through a drop_duplicates delete 
## process, and ended up with 6,696 unique organization records.  After this
## the record count improved (10,270), but still didn't make sense.  Logically, 
## we shouldn't have more than 9,069 records (compnay-funding merged records),
## since we were only matching on Company to get the URL.  So, after a manual 
## review found duplicates in merged_df, I decided to run the merged_df data 
## frame through a drop_duplicates delete process which resulted in the final 
## merged_df record count of 8,798.  The previous data frame had 59 records 
## of funding type D and that changed to 41 after the drop duplicates delete 
## process.  After further review of the 59 Series D records, I found 18 
## likely duplicates which accounted for the change from 59 to 41 Series D 
## records.

# %%
## Read file and then sort for companies_df = 8,664 records
csv_file = "a_companies.csv"
companies_df = pd.read_csv(csv_file, encoding="iso-8859-1",
                           parse_dates=["Founded Date","Closed Date",
                                        "Last Funding Date"])
companies_df = companies_df.sort_values("Company Name").reset_index(drop=True)
#companies_df.columns
#print(len(companies_df.index))

# %%
# Remove some columns from the data frame
companies_df = companies_df[["Company Name", "Founded Date", "Closed Date", 
                             "Number of Funding Rounds", "Last Funding Date", 
                             "Last Funding Amount", "Total Funding Amount", "Status"]]

# %%
# Rename columns
companies_pf = companies_df.rename(columns={
    "Company Name" : "Company",
    "Number of Funding Rounds" : "Funding Rounds"   
})
#companies_pf.head(5)

# %%
## Read file and then sort for funding_df = 10,901 records
funding = "a_funding_rounds.csv"
funding_df = pd.read_csv(funding, encoding="iso-8859-1", 
                         parse_dates=["Announced On Date"])
funding_df = funding_df.sort_values("Company Name").reset_index(drop=True)
#funding_df.columns
#print(len(funding_df.index))

# %%
# Remove some columns from the data frame
funding_df = funding_df[["Company Name", 
                         "Funding Type", 
                         "Money Raised", 
                         "Announced On Date"]]

# %%
# Rename columns
funding_pf = funding_df.rename(columns={
    "Company Name" : "Company"
})
#funding_pf.head(5)

# %%
# Merge companies_pf (8,664) and funding_pf (10,901)on Company to create merged_data = 9,069
merged_data = pd.merge(companies_pf, funding_pf,how="inner",on="Company")
#merged_data.head(5)
#print(len(merged_data.index))

# %%
## Read file of organizations 6,696 records - was organization.csv 497,523
org = "a_unique_organizations.csv"
unique_org = pd.read_csv(org, encoding="iso-8859-1")
#unique_org.head(5)  
#print(len(unique_org.index))

# %%
# merged_data = 9,069 with unique_org = 6696 to create merged_df = 10,270  
merged_df1 = pd.merge(merged_data, unique_org, left_on="Company", right_on="Company", how='inner')
#merged_df1.head(5)
#print(len(merged_df1.index))

# %%
# Remove duplicates from merged_df1 = 10,270 to create merged_df = 8,798 which removed 
# 1472 records based on matching Company, Funding Type, and Money Raised.
merged_df = merged_df1.drop_duplicates(subset=["Company","Funding Type","Money Raised"],
                                       keep="first").reset_index(drop=True)
#merged_df.head(5)
#print(len(merged_df.index))

# %%
# Convert fields to usable formats
merged_df["Money Raised"] = merged_df["Money Raised"].str.strip() \
                                                   .replace('[\$,]','', regex=True ).astype(np.int64)
    
merged_df["Last Funding Amount"] = merged_df["Last Funding Amount"] \
                                                   .replace('[\$,]','', regex=True ).astype(np.int64)
merged_df["Total Funding Amount"] = merged_df["Total Funding Amount"] \
                                                   .replace('[\$,]','', regex=True ).astype(np.int64)
merged_df.head(5)
# Out:
#       Company Founded Date Closed Date  Funding Rounds Last Funding Date  \
# 0    #waywire   2012-06-01         NaT               1        2012-06-30
# 1  *gram Labs   2015-08-01         NaT               1        2016-07-27
# 2         .io   2015-03-01         NaT               1        2015-10-01
# 3  /dev/color   2015-05-01         NaT               1        2016-08-23
# 4    10 By 10   2015-01-01         NaT               1        2017-07-01
#
#    Last Funding Amount  Total Funding Amount        Status Funding Type  \
# 0              1750000               1750000  Was Acquired         Seed
# 1              1000000               1000000     Operating         Seed
# 2              1500000               1500000     Operating         Seed
# 3               120000                120000     Operating         Seed
# 4               120000                120000     Operating         Seed
#
#    Money Raised Announced On Date                              UUID  \
# 0       1750000        2012-06-30  3ca068193ca9ce42ce20f0e150d563a0
# 1       1000000        2016-07-27  18e8dd5efe1d5f8ef2edb254171d7f5d
# 2       1500000        2015-10-01  cf169e68c903c0898789bdd557d6a4c1
# 3        120000        2016-08-23  165f412c361d7931fd3bcf5e2a1ccef3
# 4        120000        2017-07-01  e1670a304ff5893d0ae3ceb761e1c251
#
#                    Homepage
# 0    http://www.waywire.com
# 1    http://www.gramlabs.ai
# 2          https://onthe.io
# 3  http://www.devcolor.org/
# 4    https://www.10by10.io/

# %%
# Save Data from all  to csv without index, with header
#merged_df.to_csv("all_files_merged_df.csv", index=False, header=True)

# %%
# Expore the data - Dates
min_found_date = min(merged_df["Founded Date"])
print("Min Founded Date: ", min_found_date)
# Out:
# Min Founded Date:  2012-01-01 00:00:00

# %%
# Expore the data - Status
# 232 records with Status == "Closed"
closed_df = merged_df.loc[merged_df["Status"] == "Closed"].reset_index(drop=True)
#closed_df.head(5)
#print(len(closed_df.index))

# %%
# 232 - 53 records based on matching Company = 179 closed_nodups
#closed_nodups = closed_df.drop_duplicates(subset=["Company"],
#                                       keep="last").reset_index(drop=True)
#closed_nodups.head(5)
#print(len(closed_nodups.index))

# %%
# Save Data from all  to csv without index, with header
#closed_nodups.to_csv("closed_nodups.csv", index=False, header=True)

# %%
# Expore the data - Dates
max_close_date = max(closed_df["Closed Date"])
print("Max Closed Date: ", max_close_date)
# Out:
# Max Closed Date:  2017-08-26 00:00:00

# %%
# Expore the data - Status
# 7982 records with Status == "Operating"
oper_df = merged_df.loc[merged_df["Status"] == "Operating"].reset_index(drop=True)
#oper_df.head(5)
#print(len(oper_df.index))

# %%
# Explore the data - All the Funding Type counts
funding_type = merged_df["Funding Type"].value_counts()
funding_type
# Out:
# Seed        5174
# Series A    2461
# Series B     904
# Series C     218
# Series D      41
# Name: Funding Type, dtype: int64

# %%
# Explore the data - All the Status counts
status_counts = merged_df["Status"].value_counts()
status_counts
# Out:
# Operating       7982
# Was Acquired     548
# Closed           232
# IPO               36
# Name: Status, dtype: int64

# %%
# 5174 records with funding type "Seed"
# 4988 "Seed" records with Status "Operating"
seed_df = merged_df.loc[(merged_df["Funding Type"] == "Seed") & 
                   (merged_df["Status"] != "Closed")].reset_index(drop=True)
#seed_df.head(5)
#print(len(seed_df.index))

# %%
# 2461 records with funding type "Series A"
# 2425 "Seed" records and Status != "Closed"
series_a = merged_df.loc[(merged_df['Funding Type'] == "Series A") &
                  (merged_df["Status"] != "Closed")].reset_index(drop=True)
#series_a.head(5)
#print(len(series_a.index))

# %%
# 904 records with Funding Type "Series B"
# 894 "Series B" records and Status != "Closed"
series_b = merged_df.loc[(merged_df['Funding Type'] == "Series B") &
                   (merged_df["Status"] != "Closed")].reset_index(drop=True)
#series_b.head(5)
#print(len(series_b.index))

# %%
# 218 records with Funding Type "Series C"
# 218 "Series C" and Status != "Closed"
series_c = merged_df.loc[(merged_df['Funding Type'] == "Series C") &
                  (merged_df["Status"] != "Closed")].reset_index(drop=True)
#series_c.head(5)
#print(len(series_c.index))

# %%
# 41 records with Funding Type "Series D"
# 41 "Series D" and Status != "Closed"
series_d = merged_df.loc[(merged_df['Funding Type'] == "Series D") &
                 (merged_df["Status"] != "Closed")].reset_index(drop=True)
#series_d.head(5)
#print(len(series_d.index))

# %%
# # Build a scatter plot for each data type
# plt.scatter(seed_df["Funding Type"], 
#             seed_df["Status"],
#             s=100, edgecolor="black", linewidths=1, c="red", marker="o", 
#             alpha=0.8)

# # Incorporate the other graph properties
# plt.title("Funding Type Status")
# plt.ylabel("Funding Type")
# plt.xlabel("Status")
# plt.grid(True)

# # Save the figure
# plt.savefig("funding_type_scatter_chart.png")

# # Show plot
# plt.show()

# %%
# Some ideas from Rachel for grouping and plotting

# #seed = merged_df[merged_df['Status'] == "Operating"]
# seed = merged_df[merged_df['Status'] == "Was Acquired"]
# seed = merged_df[merged_df['Status'] == "Closed"]
# seed = merged_df[merged_df['Status'] == "IPO"]

# # # x-axis
# seed_operating = seed.groupby(["Status"]).count()["Closed"]
# # #y-axis
# seed_acquired = seed.groupby(["Status"]).count()["Was Acquired"]

# # # x-axis
# seed_closedt = seed.groupby(["Status"]).count()["Closed"]
# # #y-axis
# seed_ips = seed.groupby(["Status"]).count()["IPO"]

# %%
funding_sum = merged_df.groupby('Funding Type')["Money Raised"].sum()
#funding_sum

# %%
plt.rcParams['font.size'] = 12.0
fig = plt.figure(figsize=[6, 6])
ax = fig.add_subplot(111)

types_area = ["Seed", "Series A", "Series B", "Series C","Series D" ]
numbers = funding_sum
colors = ["gold", "lightcoral", "cyan", "lightgreen", "lightskyblue"]
explode = (0, 0.06, 0, 0, 0)

x_axis = np.arange(0, len(types_area))

ax.set_title("Funding Type Total Funding Percentages\n for Startups", 
             weight='bold').set_fontsize('18')
ax.pie(numbers, explode=explode, labels=types_area, colors=colors,
       autopct="%1.2f%%", textprops={'weight': 'bold', 'fontsize':'14'},
       shadow=True, startangle=30, labeldistance=1.05)
ax.axis("equal")

# Save the figure
plt.tight_layout()
plt.savefig("funding_type_sum_pie_chart.png",bbox_inches="tight")

plt.show()

# %%
# sum of counts is 10278
funding_pct = merged_df.groupby('Funding Type')["Money Raised"].count()
funding_pct
# Out:
# Funding Type
# Seed        5174
# Series A    2461
# Series B     904
# Series C     218
# Series D      41
# Name: Money Raised, dtype: int64

# %%
plt.rcParams['font.size'] = 12.0

fig = plt.figure(figsize=[6, 6])
ax = fig.add_subplot(111)

types_area = ["Seed", "Series A", "Series B", "Series C","Series D" ]
numbers = funding_pct
colors = ["gold", "lightcoral", "cyan", "lightgreen", "lightskyblue"]
explode = (0.06, 0, 0, 0, 0)

x_axis = np.arange(0, len(types_area))

ax.set_title("Funding Type Percentages for Startups", weight='bold').set_fontsize('18')

ax.pie(numbers, explode=explode, 
       labels=types_area, colors=colors,
       autopct="%1.2f%%", textprops={'weight': 'bold', 'fontsize':'14'}, 
       shadow=True, startangle=30, pctdistance=.85, labeldistance=1.05)

ax.axis("equal")

# Save the figure
#plt.tight_layout()
plt.savefig("funding_type_count_pie_chart.png",bbox_inches="tight")

plt.show()

# %%
# y axis for funding_average_per_type_bar_chart 
fund_avgs = np.array(merged_df.groupby('Funding Type')["Money Raised"].median()/1000000)
fund_avgs
# Out:
# array([  0.6,   6.5,  16. ,  30. ,  46. ])

# %%
# x axis for funding_average_per_type_bar_chart 
funding_types = merged_df["Funding Type"].unique()
funding_types
# Out:
# array(['Seed', 'Series A', 'Series B', 'Series C', 'Series D'], dtype=object)

# %%
# funding_average_per_type_bar_chart 
# Helpful links to building this chart
# http://composition.al/blog/2015/11/29/a-better-way-to-add-labels-to-bar-charts-with-matplotlib/
# http://matplotlib.org/examples/api/barchart_demo.html
# https://matplotlib.org/examples/color/named_colors.html

# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# Set the label on top of the bars
def autolabel(rects, ax):
    # Get y-axis height to calculate label position from.
    (y_bottom, y_top) = ax.get_ylim()
    y_height = y_top - y_bottom
    
    for rect in rects:
        height = rect.get_height()
        #print("height is ", height)
        # Fraction of axis height taken up by this rectangle
        p_height = (height / y_height)
        #print("p_height is ", p_height)
        # fit the label above the column or inside
        if p_height > 0.95: # arbitrary
            label_position = height - (y_height * 0.05)
        else:
            label_position = height + (y_height * 0.01)

        ax.text(rect.get_x() + rect.get_width()/2., label_position,
                '%2.1f' % float(height),
                ha='center', va='bottom', weight='bold')

fig = plt.figure()
ax = fig.add_subplot(111)

x_axis = np.arange(1, len(funding_types)+ 1)
xtick_locations = [x for x in x_axis]

ax.set_title("Funding Type Average Investment (MM)", weight='bold').set_fontsize('18')
ax.set_xlabel("Funding Types", weight='bold').set_fontsize('14')
ax.set_ylabel("Average Investment (MM)", weight='bold').set_fontsize('14')

ax.set_xlim(0, len(funding_types)+ 1)

plt.ticklabel_format(style = 'plain')

rects1 = ax.bar(x_axis, fund_avgs, facecolor="royalblue", width=.4)
autolabel(rects1, ax)
ax.set_xticks(xtick_locations)

ax.set_xticklabels(funding_types, rotation=35, weight='bold')
ax.set_yticklabels([0,10,20,30,40,50],
                   rotation=360, weight='bold')

plt.tight_layout()
plt.savefig("funding_type_avg_investment_bar_chart.png")
plt.show()

# %%
## Add these columns to the series_d data frame for scraping
series_d["Total Visits"] = ""
series_d["Avg Visit Duration"] = ""
series_d["Pages Per Visit"] = ""
series_d["Bounce Rate"] = ""
series_d.head(5)
# series_d
# Out:
#                 Company Founded Date Closed Date  Funding Rounds  \
# 0           908 Devices   2012-01-01         NaT               5
# 1               Alector   2013-01-01         NaT               3
# 2                AveXis   2013-01-01         NaT               4
# 3                 Blend   2012-05-01         NaT               5
# 4  Bustle Digital Group   2013-01-01         NaT               5
#
#   Last Funding Date  Last Funding Amount  Total Funding Amount        Status  \
# 0        2017-03-15             20000000              49300000     Operating
# 1        2016-01-07             29500000              61500000     Operating
# 2        2015-09-08             65000000              75000000  Was Acquired
# 3        2017-08-24            100000000             160000000     Operating
# 4        2017-03-10             12000000              50500000     Operating
#
#   Funding Type  Money Raised Announced On Date  \
# 0     Series D      20000000        2017-03-15
# 1     Series D      29500000        2016-01-07
# 2     Series D      65000000        2015-09-08
# 3     Series D     100000000        2017-08-24
# 4     Series D      12000000        2017-03-10
#
#                                UUID                Homepage Total Visits  \
# 0  9c3b4ae472afb6d63f029c811f56fb40   http://908devices.com
# 1  9dd3b221ff3bbdb834da7774e6510b63      http://alector.com
# 2  b09be91c91a9632e870dc5ed83c46717     https://avexis.com/
# 3  e35a34d36b1d1d5b1665190c7daa4460  http://www.blendsd.com
# 4  b7d88b9f3a746aea845159ecd4851518       http://bustle.com
#
#   Avg Visit Duration Pages Per Visit Bounce Rate
# 0
# 1
# 2
# 3
# 4

# %%
## Add these columns to the closed_df data frame for scraping
closed_df["Total Visits"] = ""
closed_df["Avg Visit Duration"] = ""
closed_df["Pages Per Visit"] = ""
closed_df["Bounce Rate"] = ""
closed_df.head(5)
# closed_df
# Out:
#             Company Founded Date Closed Date  Funding Rounds  \
# 0          27 Perry   2012-01-01  2013-01-01               1
# 1          4wrdtech   2015-05-29         NaT               1
# 2  Accordion Health   2014-05-14  2017-06-01               2
# 3  Accordion Health   2014-05-14  2017-06-01               2
# 4            Alekto   2012-07-01  2013-01-01               1
#
#   Last Funding Date  Last Funding Amount  Total Funding Amount  Status  \
# 0        2012-05-17               118000                118000  Closed
# 1        2015-12-08                80000                 80000  Closed
# 2        2015-11-01              1000000               1150000  Closed
# 3        2015-11-01              1000000               1150000  Closed
# 4        2012-08-27                50000                 50000  Closed
#
#   Funding Type  Money Raised Announced On Date  \
# 0         Seed        118000        2012-05-17
# 1         Seed         80000        2015-12-08
# 2         Seed       1000000        2015-11-01
# 3         Seed        150000        2014-07-02
# 4         Seed         50000        2012-08-27
#
#                                UUID                     Homepage Total Visits  \
# 0  40d8d076df13484162029389201bb1fa       http://www.27perry.com
# 1  84420e6294f4ea624ed9711a96f467c9         https://4wrdtech.com
# 2  dad5fb42208622ca30fc7db8349a3a1c  https://accordionhealth.com
# 3  dad5fb42208622ca30fc7db8349a3a1c  https://accordionhealth.com
# 4  0e19d30ebf03535f97daef13751335e0         http://www.alekto.co
#
#   Avg Visit Duration Pages Per Visit Bounce Rate
# 0
# 1
# 2
# 3
# 4

# %%
## Read file and then sort for funding_df = 10,901 records
closed1 = "closed_df1.csv"
closeddf1 = pd.read_csv(closed1, encoding="iso-8859-1",
                           parse_dates=["Founded Date","Closed Date",
                                        "Last Funding Date"])
#print(len(closed1))
#closeddf1
# Out:
#                       Company Founded Date Closed Date  Funding Rounds  \
# 0                    27 Perry   2012-01-01  2013-01-01               1
# 1                    4wrdtech   2015-05-29         NaT               1
# 2            Accordion Health   2014-05-14  2017-06-01               2
# 3                      Alekto   2012-07-01  2013-01-01               1
# 4               Alexis Graham   2014-01-15         NaT               1
# 5                    Alminder   2012-04-01         NaT               1
# 6                 Alumni Labs   2013-06-01         NaT               1
# 7                     Applits   2012-07-01  2015-08-01               1
# 8   Armour.io - OWN YOUR DATA   2014-03-07  2016-06-19               1
# 9      Ashvattha Therapeutics   2015-01-01         NaT               1
# 10                  Audienced   2014-01-09         NaT               1
# 11                  Autopilot   2012-06-01  2015-03-01               2
# 12        Aventa Technologies   2012-01-01         NaT               1
# 13                     BTCjam   2013-10-01  2017-05-25               3
# 14                  Batch Inc   2014-03-01         NaT               1
# 15                     Beacon   2014-01-01  2016-03-01               2
# 16                 Beautified   2013-01-01  2015-10-14               1
# 17             Bee Cave Games   2012-01-01  2016-04-19               5
# 18                    Bitcast   2012-10-01         NaT               1
# 19                       Blab   2015-01-01  2016-08-15               1
# 20                   Blinpick   2013-01-01         NaT               1
# 21                  Boomerang   2012-01-01         NaT               1
# 22                 Buttercoin   2013-01-01         NaT               2
# 23            Campus Connectr   2013-01-01         NaT               2
# 24                Campus Quad   2012-01-01  2015-09-24               3
# 25                  Careerflo   2013-01-01  2014-06-30               1
# 26                    CasaHop   2012-01-01         NaT               1
# 27                    Citybot   2012-01-01  2014-01-01               2
# 28              CloudAptitude   2012-01-28         NaT               1
#
#    Last Funding Date  Last Funding Amount  Total Funding Amount  Status  \
# 0         2012-05-17               118000                118000  Closed
# 1         2015-12-08                80000                 80000  Closed
# 2         2015-11-01              1000000               1150000  Closed
# 3         2012-08-27                50000                 50000  Closed
# 4         2014-06-01               100000                100000  Closed
# 5         2013-10-22              1525000               1525000  Closed
# 6         2013-06-01                20000                 20000  Closed
# 7         2013-07-09                63000                 63000  Closed
# 8         2014-10-01               350000                350000  Closed
# 9         2016-06-07                37400                 37400  Closed
# 10        2015-02-15                20000                 20000  Closed
# 11        2014-05-20             10000000              10200000  Closed
# 12        2012-09-13              1000000               1000000  Closed
# 13        2015-10-29              1900000               9200000  Closed
# 14        2015-07-10                25000                 25000  Closed
# 15        2015-07-22              7500000               8500000  Closed
# 16        2014-08-13              1200000               1200000  Closed
# 17        2015-06-01              5500000              10850000  Closed
# 18        2013-06-18                20000                 20000  Closed
# 19        2015-01-09              5000000               5000000  Closed
# 20        2013-01-01               100000                100000  Closed
# 21        2012-07-31              1000000               1000000  Closed
# 22        2013-09-18               250000               1250000  Closed
# 23        2014-02-19               286799                516799  Closed
# 24        2015-02-02              5000000               6900000  Closed
# 25        2013-01-01               100000                100000  Closed
# 26        2012-06-26              1200000               1200000  Closed
# 27        2012-09-30               750000                750000  Closed
# 28        2012-01-29                15000                 15000  Closed
#
#    Funding Type  Money Raised Announced On Date  \
# 0          Seed        118000         5/17/2012
# 1          Seed         80000         12/8/2015
# 2          Seed        150000          7/2/2014
# 3          Seed         50000         8/27/2012
# 4          Seed        100000          6/1/2014
# 5          Seed       1525000        10/22/2013
# 6          Seed         20000          6/1/2013
# 7          Seed         63000          7/9/2013
# 8          Seed        350000         10/1/2014
# 9          Seed         37400          6/7/2016
# 10         Seed         20000         2/15/2015
# 11     Series B      10000000         5/20/2014
# 12     Series A       1000000         9/13/2012
# 13     Series A       1900000        10/29/2015
# 14         Seed         25000         7/10/2015
# 15     Series A       7500000         7/22/2015
# 16         Seed       1200000         8/13/2014
# 17         Seed       1900000          1/9/2014
# 18         Seed         20000         6/18/2013
# 19         Seed       5000000          1/9/2015
# 20         Seed        100000          1/1/2013
# 21         Seed       1000000         7/31/2012
# 22         Seed       1000000         8/19/2013
# 23     Series A        286799         2/19/2014
# 24     Series A       5000000          2/2/2015
# 25         Seed        100000          1/1/2013
# 26         Seed       1200000         6/26/2012
# 27         Seed        750000         9/30/2012
# 28         Seed         15000         1/29/2012
#
#                                 UUID                               Homepage  \
# 0   40d8d076df13484162029389201bb1fa                 http://www.27perry.com
# 1   84420e6294f4ea624ed9711a96f467c9                   https://4wrdtech.com
# 2   dad5fb42208622ca30fc7db8349a3a1c            https://accordionhealth.com
# 3   0e19d30ebf03535f97daef13751335e0                   http://www.alekto.co
# 4   22f6492b66a78ff36256ed387a92fb41         https://accelerateproduct.com/
# 5   ecafe94154b17c6d62e2ec5437bf9d05                         http://mynd.me
# 6   73c4766994c100903d0117d936f8e2a7              http://www.alumnilabs.com
# 7   318ea816d16abc8d4782700fd8a56ea9                     http://applits.com
# 8   710f8064a7df8cfd5cda4b94e5edbd04                   http://www.armour.io
# 9   30483541966d7523cae513446900bfea  http://www.ashvatthatherapeutics.com/
# 10  f9e995eee8a3a938788a7483daf82974            http://www.getaudienced.com
# 11  6b9d6c7ed07457b8c375aea43a714b3d             http://www.autopilothq.com
# 12  f044533f237a08d873a47c9e3b25f9f5              http://www.aventatech.com
# 13  919ed85fc6b14ea8a61c9ec22998a236                      http://btcjam.com
# 14  34153ad5d8708294d86eb5a8c806397c               https://www.batchinc.com
# 15  1a98da83aa7a99d9747a01bb879a38e2                 https://flybeacon.com/
# 16  b9e402001435317d9d0564e60cd43b8e           http://www.getbeautified.com
# 17  ed79c070f3d53503296be8391c9d1a11            http://www.beecavegames.com
# 18  cfadc9d59444cc00dbb557fd0b6e3872                  http://www.bitcast.io
# 19  46fab25db73c54c3f79be571065ca5d9                         http://blab.im
# 20  83ea00268156a0763761f2607efa326b                http://www.blinpick.com
# 21  8d86e03778d03ec56955bac58224c80f                        http://rang.com
# 22  fb3d7636e08058eb3a457e97eed36fb5                  http://buttercoin.com
# 23  1301ffc6538e646a838d636f36fb2ed2          http://www.campusconnectr.com
# 24  2f7660c5a09f384806f497c44bff3523               http://www.campusquad.co
# 25  0a80901a8d25833b677704f578519169               http://www.careerflo.com
# 26  675e55f9c476e41a97e6121a61127998                     http://casahop.com
# 27  e926df1375b38946484d881f55049f52                     http://citybot.com
# 28  00107fd1b65b85cd7d60c00c4b2ae2fb               http://cloudaptitude.com
#
#     Total Visits  Avg Visit Duration  Pages Per Visit  Bounce Rate
# 0            NaN                 NaN              NaN          NaN
# 1            NaN                 NaN              NaN          NaN
# 2            NaN                 NaN              NaN          NaN
# 3            NaN                 NaN              NaN          NaN
# 4            NaN                 NaN              NaN          NaN
# 5            NaN                 NaN              NaN          NaN
# 6            NaN                 NaN              NaN          NaN
# 7            NaN                 NaN              NaN          NaN
# 8            NaN                 NaN              NaN          NaN
# 9            NaN                 NaN              NaN          NaN
# 10           NaN                 NaN              NaN          NaN
# 11           NaN                 NaN              NaN          NaN
# 12           NaN                 NaN              NaN          NaN
# 13           NaN                 NaN              NaN          NaN
# 14           NaN                 NaN              NaN          NaN
# 15           NaN                 NaN              NaN          NaN
# 16           NaN                 NaN              NaN          NaN
# 17           NaN                 NaN              NaN          NaN
# 18           NaN                 NaN              NaN          NaN
# 19           NaN                 NaN              NaN          NaN
# 20           NaN                 NaN              NaN          NaN
# 21           NaN                 NaN              NaN          NaN
# 22           NaN                 NaN              NaN          NaN
# 23           NaN                 NaN              NaN          NaN
# 24           NaN                 NaN              NaN          NaN
# 25           NaN                 NaN              NaN          NaN
# 26           NaN                 NaN              NaN          NaN
# 27           NaN                 NaN              NaN          NaN
# 28           NaN                 NaN              NaN          NaN

# %%
## Web scraping program with 45 second sleep time.

## Splinter documenation:
## https://github.com/douglasmiranda/splinter-examples/blob/master/another_examples/screenshot.py
## http://splinter.readthedocs.io/en/latest/tutorial.html

## BeautifulSoup Documentation:
## https://www.crummy.com/software/BeautifulSoup/bs4/doc

from splinter import Browser
import csv
from bs4 import BeautifulSoup 
import time

# # browser = Browser('chrome')
# # browser = Browser('firefox')

# Set some URL parameters
url1 = "https://www.similarweb.com/website/" 
url_suffix = "#overview"

# # csv file names and data frames to process
# # file_name = ['series_d', 'closed_df']
file_name = ['closeddf1']

with Browser() as browser:
    for fn in file_name:
        #print("file name is ", fn)
        if fn == 'series_d':
            scrape_df = series_d
        elif fn == 'closeddf1':
            scrape_df = closeddf1
        else:
            print("unknown input!  Exiting loop...")
            break
        # Get the index for the file name
        fn_index = file_name.index(fn)
        #print("fn_index is ", fn_index)
        
        # loop thru the urls all data frames 
        counter = 0
        for index, row in scrape_df.iterrows():
            url = ""
            # url2 is a list
            url2 = row["Homepage"].split('/')
            #print("url2 is ", url2)
            if len(url2) > 2:
                counter += 1
                url = url1 + url2[2] + url_suffix
                print("url counter: ", counter,end=" - ")
                print(url)
        
            try:
                browser.visit(url)
                time.sleep(45)
                html = browser.html
                soup = BeautifulSoup(html, "html.parser")
                #print(soup.prettify())
   
                count = 0
                # Grab the 4 activity stats from the html 
                for line in soup.findAll('span',class_="engagementInfo-valueNumber js-countValue"):
                    print(line.get_text())
                    count += 1
                    # Write to data frame
                    if count == 1:
                        scrape_df.set_value(index, "Total Visits", line.getText())
                    elif count == 2:
                        scrape_df.set_value(index, "Avg Visit Duration", line.getText())
                    elif count == 3:
                        scrape_df.set_value(index, "Pages Per Visit", line.getText())
                    else:
                        scrape_df.set_value(index, "Bounce Rate", line.getText())
            except:
                print("Error with url: ", url)
        # Save screen scraped data to csv without index and with header
        scrape_df.to_csv( file_name[fn_index] + "_plus_scraping.csv", index=False, header=True)
        print("Created " + file_name[fn_index] + "_plus_scraping.csv")
        
        print("urls processed: ", counter)
# Out:
# url counter:  1 - https://www.similarweb.com/website/www.27perry.com#overview
# <12K
# 00:00:39
# 2.00
# N/A
# url counter:  2 - https://www.similarweb.com/website/4wrdtech.com#overview
# url counter:  3 - https://www.similarweb.com/website/accordionhealth.com#overview
# <12K
# 00:00:21
# 1.81
# 77.55%
# url counter:  4 - https://www.similarweb.com/website/accordionhealth.com#overview
# Error with url:  https://www.similarweb.com/website/accordionhealth.com#overview
# url counter:  5 - https://www.similarweb.com/website/www.alekto.co#overview
# <12K
# 00:01:47
# 2.00
# N/A
# url counter:  6 - https://www.similarweb.com/website/accelerateproduct.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  7 - https://www.similarweb.com/website/mynd.me#overview
# <12K
# N/A
# 1.29
# 71.39%
# url counter:  8 - https://www.similarweb.com/website/www.alumnilabs.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  9 - https://www.similarweb.com/website/applits.com#overview
# <12K
# 00:00:01
# 1.02
# 6.19%
# url counter:  10 - https://www.similarweb.com/website/www.armour.io#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  11 - https://www.similarweb.com/website/www.ashvatthatherapeutics.com#overview
# url counter:  12 - https://www.similarweb.com/website/www.getaudienced.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  13 - https://www.similarweb.com/website/www.autopilothq.com#overview
# 581.41K
# 00:02:25
# 3.32
# 61.80%
# url counter:  14 - https://www.similarweb.com/website/www.autopilothq.com#overview
# 581.41K
# 00:02:25
# 3.32
# 61.80%
# url counter:  15 - https://www.similarweb.com/website/www.autopilothq.com#overview
# 581.41K
# 00:02:25
# 3.32
# 61.80%
# url counter:  16 - https://www.similarweb.com/website/www.aventatech.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  17 - https://www.similarweb.com/website/btcjam.com#overview
# 94.03K
# 00:03:21
# 5.22
# 33.80%
# url counter:  18 - https://www.similarweb.com/website/btcjam.com#overview
# Error with url:  https://www.similarweb.com/website/btcjam.com#overview
# url counter:  19 - https://www.similarweb.com/website/www.batchinc.com#overview
# url counter:  20 - https://www.similarweb.com/website/flybeacon.com#overview
# <12K
# 00:00:47
# 1.17
# 82.66%
# url counter:  21 - https://www.similarweb.com/website/flybeacon.com#overview
# Error with url:  https://www.similarweb.com/website/flybeacon.com#overview
# url counter:  22 - https://www.similarweb.com/website/www.getbeautified.com#overview
# <12K
# 00:06:41
# 1.97
# 16.23%
# url counter:  23 - https://www.similarweb.com/website/www.beecavegames.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  24 - https://www.similarweb.com/website/www.beecavegames.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  25 - https://www.similarweb.com/website/www.beecavegames.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  26 - https://www.similarweb.com/website/www.bitcast.io#overview
# <12K
# 00:01:50
# 1.33
# 67.22%
# url counter:  27 - https://www.similarweb.com/website/blab.im#overview
# 25.80K
# 00:00:20
# 1.26
# 44.10%
# url counter:  28 - https://www.similarweb.com/website/www.blinpick.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  29 - https://www.similarweb.com/website/rang.com#overview
# <12K
# 00:00:01
# 2.12
# 29.79%
# url counter:  30 - https://www.similarweb.com/website/buttercoin.com#overview
# <12K
# 00:00:08
# 1.13
# 89.60%
# url counter:  31 - https://www.similarweb.com/website/www.campusconnectr.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  32 - https://www.similarweb.com/website/www.campusquad.co#overview
# <12K
# 00:09:56
# 3.10
# N/A
# url counter:  33 - https://www.similarweb.com/website/www.campusquad.co#overview
# <12K
# 00:09:56
# 3.10
# N/A
# url counter:  34 - https://www.similarweb.com/website/www.careerflo.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  35 - https://www.similarweb.com/website/casahop.com#overview
# <12K
# N/A
# 1.00
# 100.00%
# url counter:  36 - https://www.similarweb.com/website/citybot.com#overview
# <12K
# N/A
# 1.00
# 100.00%
# url counter:  37 - https://www.similarweb.com/website/cloudaptitude.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  38 - https://www.similarweb.com/website/coinex.io#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  39 - https://www.similarweb.com/website/compassquality.com#overview
# <12K
# N/A
# N/A
# N/A
# url counter:  40 - https://www.similarweb.com/website/getcomposure.com#overview
# Error with url:  https://www.similarweb.com/website/getcomposure.com#overview
# url counter:  41 - https://www.similarweb.com/website/www.consanomed.com#overview
# Error with url:  https://www.similarweb.com/website/www.consanomed.com#overview
# url counter:  42 - https://www.similarweb.com/website/www.consignd.com#overview
# Error with url:  https://www.similarweb.com/website/www.consignd.com#overview
# url counter:  43 - https://www.similarweb.com/website/www.zinc.it#overview
# Error with url:  https://www.similarweb.com/website/www.zinc.it#overview
# url counter:  44 - https://www.similarweb.com/website/www.zinc.it#overview
# Error with url:  https://www.similarweb.com/website/www.zinc.it#overview
# url counter:  45 - https://www.similarweb.com/website/www.couponsnearme.com#overview
# Error with url:  https://www.similarweb.com/website/www.couponsnearme.com#overview
# url counter:  46 - https://www.similarweb.com/website/www.crowdhall.com#overview
# Error with url:  https://www.similarweb.com/website/www.crowdhall.com#overview
# url counter:  47 - https://www.similarweb.com/website/www.crowdhall.com#overview
# Error with url:  https://www.similarweb.com/website/www.crowdhall.com#overview
# url counter:  48 - https://www.similarweb.com/website/www.crowdpc.com#overview
# Error with url:  https://www.similarweb.com/website/www.crowdpc.com#overview
# url counter:  49 - https://www.similarweb.com/website/www.crowdlaun.ch#overview
# Error with url:  https://www.similarweb.com/website/www.crowdlaun.ch#overview
# url counter:  50 - https://www.similarweb.com/website/www.cubikal.com#overview
# Error with url:  https://www.similarweb.com/website/www.cubikal.com#overview
# url counter:  51 - https://www.similarweb.com/website/www.cuff.io#overview
# Error with url:  https://www.similarweb.com/website/www.cuff.io#overview
# url counter:  52 - https://www.similarweb.com/website/www.curesquare.com#overview
# Error with url:  https://www.similarweb.com/website/www.curesquare.com#overview
# url counter:  53 - https://www.similarweb.com/website/www.cuturia.com#overview
# Error with url:  https://www.similarweb.com/website/www.cuturia.com#overview
# url counter:  54 - https://www.similarweb.com/website/www.dickorbro.com#overview
# Error with url:  https://www.similarweb.com/website/www.dickorbro.com#overview
# url counter:  55 - https://www.similarweb.com/website/www.din.co#overview
# Error with url:  https://www.similarweb.com/website/www.din.co#overview
# url counter:  56 - https://www.similarweb.com/website/www.dinamundo.com#overview
# Error with url:  https://www.similarweb.com/website/www.dinamundo.com#overview
# url counter:  57 - https://www.similarweb.com/website/www.dragossecurity.com#overview
# Error with url:  https://www.similarweb.com/website/www.dragossecurity.com#overview
# url counter:  58 - https://www.similarweb.com/website/drivepulseapp.com#overview
# Error with url:  https://www.similarweb.com/website/drivepulseapp.com#overview
# url counter:  59 - https://www.similarweb.com/website/www.easiestcreditcardtogetapprovedfor.com#overview
# Error with url:  https://www.similarweb.com/website/www.easiestcreditcardtogetapprovedfor.com#overview
# url counter:  60 - https://www.similarweb.com/website/wordsu.com#overview
# Error with url:  https://www.similarweb.com/website/wordsu.com#overview
# url counter:  61 - https://www.similarweb.com/website/elephant.is#overview
# Error with url:  https://www.similarweb.com/website/elephant.is#overview
# url counter:  62 - https://www.similarweb.com/website/emergentone.com#overview
# Error with url:  https://www.similarweb.com/website/emergentone.com#overview
# url counter:  63 - https://www.similarweb.com/website/emergentone.com#overview
# Error with url:  https://www.similarweb.com/website/emergentone.com#overview
# url counter:  64 - https://www.similarweb.com/website/www.envelopvr.com#overview
# Error with url:  https://www.similarweb.com/website/www.envelopvr.com#overview
# url counter:  65 - https://www.similarweb.com/website/www.envelopvr.com#overview
# Error with url:  https://www.similarweb.com/website/www.envelopvr.com#overview
# url counter:  66 - https://www.similarweb.com/website/www.fetchmd.com#overview
# Error with url:  https://www.similarweb.com/website/www.fetchmd.com#overview
# url counter:  67 - https://www.similarweb.com/website/www.getfitvia.com#overview
# Error with url:  https://www.similarweb.com/website/www.getfitvia.com#overview
# url counter:  68 - https://www.similarweb.com/website/www.fiture.co#overview
# Error with url:  https://www.similarweb.com/website/www.fiture.co#overview
# url counter:  69 - https://www.similarweb.com/website/www.flapshare.com#overview
# Error with url:  https://www.similarweb.com/website/www.flapshare.com#overview
# url counter:  70 - https://www.similarweb.com/website/www.freshdish.com#overview
# Error with url:  https://www.similarweb.com/website/www.freshdish.com#overview
# url counter:  71 - https://www.similarweb.com/website/friendsignia.com#overview
# Error with url:  https://www.similarweb.com/website/friendsignia.com#overview
# url counter:  72 - https://www.similarweb.com/website/gastonlabs.com#overview
# Error with url:  https://www.similarweb.com/website/gastonlabs.com#overview
# url counter:  73 - https://www.similarweb.com/website/gli.ph#overview
# Error with url:  https://www.similarweb.com/website/gli.ph#overview
# url counter:  74 - https://www.similarweb.com/website/gli.ph#overview
# Error with url:  https://www.similarweb.com/website/gli.ph#overview
# url counter:  75 - https://www.similarweb.com/website/gli.ph#overview
# Error with url:  https://www.similarweb.com/website/gli.ph#overview
# url counter:  76 - https://www.similarweb.com/website/digitallegends.net#overview
# Error with url:  https://www.similarweb.com/website/digitallegends.net#overview
# url counter:  77 - https://www.similarweb.com/website/gyde.ly#overview
# Error with url:  https://www.similarweb.com/website/gyde.ly#overview
# url counter:  78 - https://www.similarweb.com/website/www.gradfly.co#overview
# Error with url:  https://www.similarweb.com/website/www.gradfly.co#overview
# url counter:  79 - https://www.similarweb.com/website/gui.de#overview
# Error with url:  https://www.similarweb.com/website/gui.de#overview
# url counter:  80 - https://www.similarweb.com/website/www.hashtip.com#overview
# Error with url:  https://www.similarweb.com/website/www.hashtip.com#overview
# url counter:  81 - https://www.similarweb.com/website/www.joinhaven.com#overview
# Error with url:  https://www.similarweb.com/website/www.joinhaven.com#overview
# url counter:  82 - https://www.similarweb.com/website/www.joinhaven.com#overview
# Error with url:  https://www.similarweb.com/website/www.joinhaven.com#overview
# url counter:  83 - https://www.similarweb.com/website/www.joinhaven.com#overview
# Error with url:  https://www.similarweb.com/website/www.joinhaven.com#overview
# url counter:  84 - https://www.similarweb.com/website/www.homehero.org#overview
# Error with url:  https://www.similarweb.com/website/www.homehero.org#overview
# url counter:  85 - https://www.similarweb.com/website/www.homehero.org#overview
# Error with url:  https://www.similarweb.com/website/www.homehero.org#overview
# url counter:  86 - https://www.similarweb.com/website/www.homehero.org#overview
# Error with url:  https://www.similarweb.com/website/www.homehero.org#overview
# url counter:  87 - https://www.similarweb.com/website/www.hukkster.com#overview
# Error with url:  https://www.similarweb.com/website/www.hukkster.com#overview
# url counter:  88 - https://www.similarweb.com/website/www.hukkster.com#overview
# Error with url:  https://www.similarweb.com/website/www.hukkster.com#overview
# url counter:  89 - https://www.similarweb.com/website/www.imzy.com#overview
# Error with url:  https://www.similarweb.com/website/www.imzy.com#overview
# url counter:  90 - https://www.similarweb.com/website/www.imzy.com#overview
# Error with url:  https://www.similarweb.com/website/www.imzy.com#overview
# url counter:  91 - https://www.similarweb.com/website/jut.io#overview
# Error with url:  https://www.similarweb.com/website/jut.io#overview
# url counter:  92 - https://www.similarweb.com/website/getkanoa.com#overview
# Error with url:  https://www.similarweb.com/website/getkanoa.com#overview
# url counter:  93 - https://www.similarweb.com/website/www.kitchensurfing.com#overview
# Error with url:  https://www.similarweb.com/website/www.kitchensurfing.com#overview
# url counter:  94 - https://www.similarweb.com/website/www.kitchensurfing.com#overview
# Error with url:  https://www.similarweb.com/website/www.kitchensurfing.com#overview
# url counter:  95 - https://www.similarweb.com/website/www.kitchensurfing.com#overview
# Error with url:  https://www.similarweb.com/website/www.kitchensurfing.com#overview
# url counter:  96 - https://www.similarweb.com/website/www.kyogermedia.com#overview
# Error with url:  https://www.similarweb.com/website/www.kyogermedia.com#overview
# url counter:  97 - https://www.similarweb.com/website/last.co#overview
# Error with url:  https://www.similarweb.com/website/last.co#overview
# url counter:  98 - https://www.similarweb.com/website/www.lily.camera#overview
# Error with url:  https://www.similarweb.com/website/www.lily.camera#overview
# url counter:  99 - https://www.similarweb.com/website/www.lily.camera#overview
# Error with url:  https://www.similarweb.com/website/www.lily.camera#overview
# url counter:  100 - https://www.similarweb.com/website/www.lingorami.com#overview
# Error with url:  https://www.similarweb.com/website/www.lingorami.com#overview
# url counter:  101 - https://www.similarweb.com/website/www.livrada.com#overview
# Error with url:  https://www.similarweb.com/website/www.livrada.com#overview
# url counter:  102 - https://www.similarweb.com/website/www.livrada.com#overview
# Error with url:  https://www.similarweb.com/website/www.livrada.com#overview
# url counter:  103 - https://www.similarweb.com/website/www.locish.com#overview
# Error with url:  https://www.similarweb.com/website/www.locish.com#overview
# url counter:  104 - https://www.similarweb.com/website/magnifi.fm#overview
# Error with url:  https://www.similarweb.com/website/magnifi.fm#overview
# url counter:  105 - https://www.similarweb.com/website/marvincar.com#overview
# Error with url:  https://www.similarweb.com/website/marvincar.com#overview
# url counter:  106 - https://www.similarweb.com/website/www.medgrc.com#overview
# Error with url:  https://www.similarweb.com/website/www.medgrc.com#overview
# url counter:  107 - https://www.similarweb.com/website/mindpirate.com#overview
# Error with url:  https://www.similarweb.com/website/mindpirate.com#overview
# url counter:  108 - https://www.similarweb.com/website/www.modabound.com#overview
# Error with url:  https://www.similarweb.com/website/www.modabound.com#overview
# url counter:  109 - https://www.similarweb.com/website/www.monthlys.com#overview
# Error with url:  https://www.similarweb.com/website/www.monthlys.com#overview
# url counter:  110 - https://www.similarweb.com/website/www.nalace.com#overview
# Error with url:  https://www.similarweb.com/website/www.nalace.com#overview
# url counter:  111 - https://www.similarweb.com/website/www.nitrous.io#overview
# Error with url:  https://www.similarweb.com/website/www.nitrous.io#overview
# url counter:  112 - https://www.similarweb.com/website/www.nitrous.io#overview
# Error with url:  https://www.similarweb.com/website/www.nitrous.io#overview
# url counter:  113 - https://www.similarweb.com/website/www.novimedicine.com#overview
# Error with url:  https://www.similarweb.com/website/www.novimedicine.com#overview
# url counter:  114 - https://www.similarweb.com/website/operatinganalytics.com#overview
# Error with url:  https://www.similarweb.com/website/operatinganalytics.com#overview
# url counter:  115 - https://www.similarweb.com/website/paydragon.com#overview
# Error with url:  https://www.similarweb.com/website/paydragon.com#overview
# url counter:  116 - https://www.similarweb.com/website/www.pearlapp.co#overview
# Error with url:  https://www.similarweb.com/website/www.pearlapp.co#overview
# url counter:  117 - https://www.similarweb.com/website/www.petsitnstay.com#overview
# Error with url:  https://www.similarweb.com/website/www.petsitnstay.com#overview
# url counter:  118 - https://www.similarweb.com/website/pickle.com#overview
# Error with url:  https://www.similarweb.com/website/pickle.com#overview
# url counter:  119 - https://www.similarweb.com/website/pickle.com#overview
# Error with url:  https://www.similarweb.com/website/pickle.com#overview
# url counter:  120 - https://www.similarweb.com/website/picklify.com#overview
# Error with url:  https://www.similarweb.com/website/picklify.com#overview
# url counter:  121 - https://www.similarweb.com/website/picvoice.com#overview
# Error with url:  https://www.similarweb.com/website/picvoice.com#overview
# url counter:  122 - https://www.similarweb.com/website/www.pintics.com#overview
# Error with url:  https://www.similarweb.com/website/www.pintics.com#overview
# url counter:  123 - https://www.similarweb.com/website/www.poliana.com#overview
# Error with url:  https://www.similarweb.com/website/www.poliana.com#overview
# url counter:  124 - https://www.similarweb.com/website/www.pollvaultr.com#overview
# Error with url:  https://www.similarweb.com/website/www.pollvaultr.com#overview
# url counter:  125 - https://www.similarweb.com/website/prognos.health#overview
# Error with url:  https://www.similarweb.com/website/prognos.health#overview
# url counter:  126 - https://www.similarweb.com/website/www.protoexchange.com#overview
# Error with url:  https://www.similarweb.com/website/www.protoexchange.com#overview
# url counter:  127 - https://www.similarweb.com/website/www.quack.com#overview
# Error with url:  https://www.similarweb.com/website/www.quack.com#overview
# url counter:  128 - https://www.similarweb.com/website/www.qualityrenters.com#overview
# Error with url:  https://www.similarweb.com/website/www.qualityrenters.com#overview
# url counter:  129 - https://www.similarweb.com/website/quantifiedvapor.com#overview
# Error with url:  https://www.similarweb.com/website/quantifiedvapor.com#overview
# url counter:  130 - https://www.similarweb.com/website/quantifiedvapor.com#overview
# Error with url:  https://www.similarweb.com/website/quantifiedvapor.com#overview
# url counter:  131 - https://www.similarweb.com/website/www.retenant.com#overview
# Error with url:  https://www.similarweb.com/website/www.retenant.com#overview
# url counter:  132 - https://www.similarweb.com/website/www.relationshipmanager.com#overview
# Error with url:  https://www.similarweb.com/website/www.relationshipmanager.com#overview
# url counter:  133 - https://www.similarweb.com/website/www.rememberthemember.com#overview
# Error with url:  https://www.similarweb.com/website/www.rememberthemember.com#overview
# url counter:  134 - https://www.similarweb.com/website/www.rewardmyway.com#overview
# Error with url:  https://www.similarweb.com/website/www.rewardmyway.com#overview
# url counter:  135 - https://www.similarweb.com/website/ripplecommerce.com#overview
# Error with url:  https://www.similarweb.com/website/ripplecommerce.com#overview
# url counter:  136 - https://www.similarweb.com/website/rocketraise.com#overview
# Error with url:  https://www.similarweb.com/website/rocketraise.com#overview
# url counter:  137 - https://www.similarweb.com/website/www.skully.com#overview
# Error with url:  https://www.similarweb.com/website/www.skully.com#overview
# url counter:  138 - https://www.similarweb.com/website/www.skully.com#overview
# Error with url:  https://www.similarweb.com/website/www.skully.com#overview
# url counter:  139 - https://www.similarweb.com/website/www.stand.tc#overview
# Error with url:  https://www.similarweb.com/website/www.stand.tc#overview
# url counter:  140 - https://www.similarweb.com/website/safecare.publichealth.gsu.edu#overview
# Error with url:  https://www.similarweb.com/website/safecare.publichealth.gsu.edu#overview
# url counter:  141 - https://www.similarweb.com/website/savyswap.co#overview
# Error with url:  https://www.similarweb.com/website/savyswap.co#overview
# url counter:  142 - https://www.similarweb.com/website/scootdoodle.com#overview
# Error with url:  https://www.similarweb.com/website/scootdoodle.com#overview
# url counter:  143 - https://www.similarweb.com/website/www.seatswapr.com#overview
# Error with url:  https://www.similarweb.com/website/www.seatswapr.com#overview
# url counter:  144 - https://www.similarweb.com/website/www.secret.ly#overview
# Error with url:  https://www.similarweb.com/website/www.secret.ly#overview
# url counter:  145 - https://www.similarweb.com/website/www.secret.ly#overview
# Error with url:  https://www.similarweb.com/website/www.secret.ly#overview
# url counter:  146 - https://www.similarweb.com/website/www.secret.ly#overview
# Error with url:  https://www.similarweb.com/website/www.secret.ly#overview
# url counter:  147 - https://www.similarweb.com/website/www.sericatrading.com#overview
# Error with url:  https://www.similarweb.com/website/www.sericatrading.com#overview
# url counter:  148 - https://www.similarweb.com/website/www.thehunt.com#overview
# Error with url:  https://www.similarweb.com/website/www.thehunt.com#overview
# url counter:  149 - https://www.similarweb.com/website/www.thehunt.com#overview
# Error with url:  https://www.similarweb.com/website/www.thehunt.com#overview
# url counter:  150 - https://www.similarweb.com/website/shuddle.us#overview
# Error with url:  https://www.similarweb.com/website/shuddle.us#overview
# url counter:  151 - https://www.similarweb.com/website/shuddle.us#overview
# Error with url:  https://www.similarweb.com/website/shuddle.us#overview
# url counter:  152 - https://www.similarweb.com/website/smartlanestechnologies.com#overview
# Error with url:  https://www.similarweb.com/website/smartlanestechnologies.com#overview
# url counter:  153 - https://www.similarweb.com/website/smartstay.io#overview
# Error with url:  https://www.similarweb.com/website/smartstay.io#overview
# url counter:  154 - https://www.similarweb.com/website/socialthreader.com#overview
# Error with url:  https://www.similarweb.com/website/socialthreader.com#overview
# url counter:  155 - https://www.similarweb.com/website/socialthreader.com#overview
# Error with url:  https://www.similarweb.com/website/socialthreader.com#overview
# url counter:  156 - https://www.similarweb.com/website/www.solidinnovations.net#overview
# Error with url:  https://www.similarweb.com/website/www.solidinnovations.net#overview
# url counter:  157 - https://www.similarweb.com/website/www.soundroadie.com#overview
# Error with url:  https://www.similarweb.com/website/www.soundroadie.com#overview
# url counter:  158 - https://www.similarweb.com/website/soundstache.net#overview
# Error with url:  https://www.similarweb.com/website/soundstache.net#overview
# url counter:  159 - https://www.similarweb.com/website/www.spiffysociety.com#overview
# Error with url:  https://www.similarweb.com/website/www.spiffysociety.com#overview
# url counter:  160 - https://www.similarweb.com/website/spotster.com#overview
# Error with url:  https://www.similarweb.com/website/spotster.com#overview
# url counter:  161 - https://www.similarweb.com/website/www.sprig.com#overview
# Error with url:  https://www.similarweb.com/website/www.sprig.com#overview
# url counter:  162 - https://www.similarweb.com/website/www.sprig.com#overview
# Error with url:  https://www.similarweb.com/website/www.sprig.com#overview
# url counter:  163 - https://www.similarweb.com/website/www.sprig.com#overview
# Error with url:  https://www.similarweb.com/website/www.sprig.com#overview
# url counter:  164 - https://www.similarweb.com/website/www.sprig.com#overview
# Error with url:  https://www.similarweb.com/website/www.sprig.com#overview
# url counter:  165 - https://www.similarweb.com/website/www.sqwiggle.com#overview
# Error with url:  https://www.similarweb.com/website/www.sqwiggle.com#overview
# url counter:  166 - https://www.similarweb.com/website/www.standoffer.com#overview
# Error with url:  https://www.similarweb.com/website/www.standoffer.com#overview
# url counter:  167 - https://www.similarweb.com/website/www.standoffer.com#overview
# Error with url:  https://www.similarweb.com/website/www.standoffer.com#overview
# url counter:  168 - https://www.similarweb.com/website/www.starbates.com#overview
# Error with url:  https://www.similarweb.com/website/www.starbates.com#overview
# url counter:  169 - https://www.similarweb.com/website/www.starboardstorage.com#overview
# Error with url:  https://www.similarweb.com/website/www.starboardstorage.com#overview
# url counter:  170 - https://www.similarweb.com/website/statushq.com#overview
# Error with url:  https://www.similarweb.com/website/statushq.com#overview
# url counter:  171 - https://www.similarweb.com/website/www.sumpto.com#overview
# Error with url:  https://www.similarweb.com/website/www.sumpto.com#overview
# url counter:  172 - https://www.similarweb.com/website/www.sunnybump.com#overview
# Error with url:  https://www.similarweb.com/website/www.sunnybump.com#overview
# url counter:  173 - https://www.similarweb.com/website/www.supplyseeker.com#overview
# Error with url:  https://www.similarweb.com/website/www.supplyseeker.com#overview
# url counter:  174 - https://www.similarweb.com/website/www.sweetslap.com#overview
# Error with url:  https://www.similarweb.com/website/www.sweetslap.com#overview
# url counter:  175 - https://www.similarweb.com/website/www.tagapet.com#overview
# Error with url:  https://www.similarweb.com/website/www.tagapet.com#overview
# url counter:  176 - https://www.similarweb.com/website/www.tendertree.com#overview
# Error with url:  https://www.similarweb.com/website/www.tendertree.com#overview
# url counter:  177 - https://www.similarweb.com/website/www.textandthecity.com#overview
# Error with url:  https://www.similarweb.com/website/www.textandthecity.com#overview
# url counter:  178 - https://www.similarweb.com/website/www.textandthecity.com#overview
# Error with url:  https://www.similarweb.com/website/www.textandthecity.com#overview
# url counter:  179 - https://www.similarweb.com/website/www.textandthecity.com#overview
# Error with url:  https://www.similarweb.com/website/www.textandthecity.com#overview
# url counter:  180 - https://www.similarweb.com/website/www.textandthecity.com#overview
# Error with url:  https://www.similarweb.com/website/www.textandthecity.com#overview
# url counter:  181 - https://www.similarweb.com/website/www.thehappyhome.co#overview
# Error with url:  https://www.similarweb.com/website/www.thehappyhome.co#overview
# url counter:  182 - https://www.similarweb.com/website/www.thryveapp.com#overview
# Error with url:  https://www.similarweb.com/website/www.thryveapp.com#overview
# url counter:  183 - https://www.similarweb.com/website/www.titt.at#overview
# Error with url:  https://www.similarweb.com/website/www.titt.at#overview
# url counter:  184 - https://www.similarweb.com/website/trafficapp.co#overview
# Error with url:  https://www.similarweb.com/website/trafficapp.co#overview
# url counter:  185 - https://www.similarweb.com/website/transpose.com#overview
# Error with url:  https://www.similarweb.com/website/transpose.com#overview
# url counter:  186 - https://www.similarweb.com/website/www.tylrmobile.com#overview
# Error with url:  https://www.similarweb.com/website/www.tylrmobile.com#overview
# url counter:  187 - https://www.similarweb.com/website/uguru.me#overview
# Error with url:  https://www.similarweb.com/website/uguru.me#overview
# url counter:  188 - https://www.similarweb.com/website/vicino.com#overview
# Error with url:  https://www.similarweb.com/website/vicino.com#overview
# url counter:  189 - https://www.similarweb.com/website/www.vidbid.com#overview
# Error with url:  https://www.similarweb.com/website/www.vidbid.com#overview
# url counter:  190 - https://www.similarweb.com/website/www.visidraft.com#overview
# Error with url:  https://www.similarweb.com/website/www.visidraft.com#overview
# url counter:  191 - https://www.similarweb.com/website/www.vitrumview.com#overview
# Error with url:  https://www.similarweb.com/website/www.vitrumview.com#overview
# url counter:  192 - https://www.similarweb.com/website/www.vitrumview.com#overview
# Error with url:  https://www.similarweb.com/website/www.vitrumview.com#overview
# url counter:  193 - https://www.similarweb.com/website/vouch.com#overview
# Error with url:  https://www.similarweb.com/website/vouch.com#overview
# url counter:  194 - https://www.similarweb.com/website/vouch.com#overview
# Error with url:  https://www.similarweb.com/website/vouch.com#overview
# url counter:  195 - https://www.similarweb.com/website/wutwut.com#overview
# Error with url:  https://www.similarweb.com/website/wutwut.com#overview
# url counter:  196 - https://www.similarweb.com/website/www.wallcompass.com#overview
# Error with url:  https://www.similarweb.com/website/www.wallcompass.com#overview
# url counter:  197 - https://www.similarweb.com/website/www.getwashio.com#overview
# Error with url:  https://www.similarweb.com/website/www.getwashio.com#overview
# url counter:  198 - https://www.similarweb.com/website/www.getwashio.com#overview
# Error with url:  https://www.similarweb.com/website/www.getwashio.com#overview
# url counter:  199 - https://www.similarweb.com/website/www.getwashio.com#overview
# Error with url:  https://www.similarweb.com/website/www.getwashio.com#overview
# url counter:  200 - https://www.similarweb.com/website/www.watercluster.com#overview
# Error with url:  https://www.similarweb.com/website/www.watercluster.com#overview
# url counter:  201 - https://www.similarweb.com/website/www.getweave.com#overview
# Error with url:  https://www.similarweb.com/website/www.getweave.com#overview
# url counter:  202 - https://www.similarweb.com/website/crowd911.com#overview
# Error with url:  https://www.similarweb.com/website/crowd911.com#overview
# url counter:  203 - https://www.similarweb.com/website/crowd911.com#overview
# Error with url:  https://www.similarweb.com/website/crowd911.com#overview
# url counter:  204 - https://www.similarweb.com/website/winwinslots.com#overview
# Error with url:  https://www.similarweb.com/website/winwinslots.com#overview
# url counter:  205 - https://www.similarweb.com/website/gowiper.com#overview
# Error with url:  https://www.similarweb.com/website/gowiper.com#overview
# url counter:  206 - https://www.similarweb.com/website/gowiper.com#overview
# Error with url:  https://www.similarweb.com/website/gowiper.com#overview
# url counter:  207 - https://www.similarweb.com/website/wire.im#overview
# Error with url:  https://www.similarweb.com/website/wire.im#overview
# url counter:  208 - https://www.similarweb.com/website/wokrr.com#overview
# Error with url:  https://www.similarweb.com/website/wokrr.com#overview
# url counter:  209 - https://www.similarweb.com/website/woofradar.com#overview
# Error with url:  https://www.similarweb.com/website/woofradar.com#overview
# url counter:  210 - https://www.similarweb.com/website/worksurfers.com#overview
# Error with url:  https://www.similarweb.com/website/worksurfers.com#overview
# url counter:  211 - https://www.similarweb.com/website/www.playwovo.com#overview
# Error with url:  https://www.similarweb.com/website/www.playwovo.com#overview
# url counter:  212 - https://www.similarweb.com/website/wrkriot.com#overview
# Error with url:  https://www.similarweb.com/website/wrkriot.com#overview
# url counter:  213 - https://www.similarweb.com/website/wrkriot.com#overview
# Error with url:  https://www.similarweb.com/website/wrkriot.com#overview
# url counter:  214 - https://www.similarweb.com/website/www.wyldfireapp.com#overview
# Error with url:  https://www.similarweb.com/website/www.wyldfireapp.com#overview
# url counter:  215 - https://www.similarweb.com/website/www.wyldfireapp.com#overview
# Error with url:  https://www.similarweb.com/website/www.wyldfireapp.com#overview
# url counter:  216 - https://www.similarweb.com/website/www.wyldfireapp.com#overview
# Error with url:  https://www.similarweb.com/website/www.wyldfireapp.com#overview
# url counter:  217 - https://www.similarweb.com/website/www.xdynia.com#overview
# Error with url:  https://www.similarweb.com/website/www.xdynia.com#overview
# url counter:  218 - https://www.similarweb.com/website/www.xdynia.com#overview
# Error with url:  https://www.similarweb.com/website/www.xdynia.com#overview
# url counter:  219 - https://www.similarweb.com/website/www.yakify.com#overview
# Error with url:  https://www.similarweb.com/website/www.yakify.com#overview
# url counter:  220 - https://www.similarweb.com/website/www.yeloha.com#overview
# Error with url:  https://www.similarweb.com/website/www.yeloha.com#overview
# url counter:  221 - https://www.similarweb.com/website/www.yeloha.com#overview
# Error with url:  https://www.similarweb.com/website/www.yeloha.com#overview
# url counter:  222 - https://www.similarweb.com/website/www.yikyak.com#overview
# Error with url:  https://www.similarweb.com/website/www.yikyak.com#overview
# url counter:  223 - https://www.similarweb.com/website/www.yikyak.com#overview
# Error with url:  https://www.similarweb.com/website/www.yikyak.com#overview
# url counter:  224 - https://www.similarweb.com/website/www.yikyak.com#overview
# Error with url:  https://www.similarweb.com/website/www.yikyak.com#overview
# url counter:  225 - https://www.similarweb.com/website/www.bulletn.info#overview
# Error with url:  https://www.similarweb.com/website/www.bulletn.info#overview
# url counter:  226 - https://www.similarweb.com/website/www.castar.com#overview
# Error with url:  https://www.similarweb.com/website/www.castar.com#overview
# url counter:  227 - https://www.similarweb.com/website/www.dvisit.com#overview
# Error with url:  https://www.similarweb.com/website/www.dvisit.com#overview
# url counter:  228 - https://www.similarweb.com/website/dreamsha.re#overview
# Error with url:  https://www.similarweb.com/website/dreamsha.re#overview
# url counter:  229 - https://www.similarweb.com/website/www.dxcare.com#overview
# Error with url:  https://www.similarweb.com/website/www.dxcare.com#overview
# url counter:  230 - https://www.similarweb.com/website/www.ishbowl.com#overview
# Error with url:  https://www.similarweb.com/website/www.ishbowl.com#overview
# url counter:  231 - https://www.similarweb.com/website/www.dapperjobs.com#overview
# Error with url:  https://www.similarweb.com/website/www.dapperjobs.com#overview
# url counter:  232 - https://www.similarweb.com/website/walkby.com#overview
# Error with url:  https://www.similarweb.com/website/walkby.com#overview
# Created closeddf1_plus_scraping.csv
# urls processed:  232
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-54-05791b5111ab> in <module>()
#      78         print("Created " + file_name[fn_index] + "_plus_scraping.csv")
#      79
# ---> 80         print("urls processed: ", counter)
#
# C:\Users\Chrisg\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in __exit__(self, exc_type, exc_value, traceback)
#     166
#     167     def __exit__(self, exc_type, exc_value, traceback):
# --> 168         self.quit()
#     169
#     170     @property
#
# C:\Users\Chrisg\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in quit(self)
#     474
#     475     def quit(self):
# --> 476         self.driver.quit()
#     477
#     478     @property
#
# C:\Users\Chrisg\Anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in quit(self)
#     181         """Quits the driver and close every associated window."""
#     182         try:
# --> 183             RemoteWebDriver.quit(self)
#     184         except (http_client.BadStatusLine, socket.error):
#     185             # Happens if Firefox shutsdown before we've read the response from
#
# C:\Users\Chrisg\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in quit(self)
#     590         """
#     591         try:
# --> 592             self.execute(Command.QUIT)
#     593         finally:
#     594             self.stop_client()
#
# C:\Users\Chrisg\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     295         response = self.command_executor.execute(driver_command, params)
#     296         if response:
# --> 297             self.error_handler.check_response(response)
#     298             response['value'] = self._unwrap_value(
#     299                 response.get('value', None))
#
# C:\Users\Chrisg\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     192         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     193             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 194         raise exception_class(message, screen, stacktrace)
#     195
#     196     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: Tried to run command without establishing a connection

# %%
scrape_df.to_csv( "closed_df1_plus_scraping.csv", index=False, header=True)

# %%
##
## Reload series_d data to work with Screen scrape data without scraping
##
## Read file 
# csv_file = "series_d_plus_scraping.csv"
# series_d = pd.read_csv(csv_file, encoding="iso-8859-1", 
#            parse_dates=["Founded Date", "Last Funding Date", "Announced On Date"])
# series_d.head(5)
# series_d.dtypes

# %%
# regex module
# import re  

# ## Total Visits: strip non-numeric characters and convert to float64
# for index, row in series_d.iterrows():
#     print("index is: ", index)
#     print(row["Total Visits"])
#     print(type(row["Total Visits"]))
    
#     str1 = str(row["Total Visits"])
#     if "K" in str1:
#         str1 = re.sub('[<K]', '', str1)
#         flt_str1 = float(str1) * 1000
#         print("str1 with a K is ", str1)
#         series_d.set_value(index, "Total Visits", flt_str1)
#     else:
#         str1 = re.sub('[<M]', '', str1)
#         flt_str1 = float(str1) * 1000000
#         print("other str1 is ", str1)
#         series_d.set_value(index, "Total Visits", flt_str1)

# pd.set_option('display.float_format', lambda x: '%.2f' % x)
# series_d["Total Visits"] = series_d["Total Visits"]      
# series_d   
# series_d.dtypes

# %%
## Convert string columns into usable data types

## Convert a column to datetime64 type with only the time?
## pd.to_datetime.dt.time is a datetime.time object but not datetime64.
## Therefore, it is correct that the dtype for the column is object.  
## Converting Avg Visit Duration to datetime.time renders the desired 
## format 00:00:00.
## Check out this documentation on Time series:
## https://pandas.pydata.org/pandas-docs/stable/timeseries.html

# series_d["Avg Visit Duration"] = pd.to_datetime(series_d["Avg Visit Duration"],format="%H:%M:%S").dt.time

# series_d["Bounce Rate"] = series_d["Bounce Rate"].replace('[%]','', regex=True ).astype(np.float64)

# series_d["Pages Per Visit"] = series_d["Pages Per Visit"].astype(np.float64)

# series_d
# series_d.dtype

# %%
##
## Reload closed_df data to work with Screen scrape data without more scraping
##
## Read file 
# csv_file = "closed_df_plus_scraping.csv"
# closed_df = pd.read_csv(csv_file, encoding="iso-8859-1", 
#            parse_dates=["Founded Date", "Last Funding Date", "Announced On Date"])

# closed_df["Money Raised"] = top_orgs["Money Raised"].replace('[\$,]','', regex=True ).astype(np.int64)
# closed_df["Homepage"] = top_orgs["Homepage"].replace(np.nan, '', regex=True)
# closed_df["Total Visits"] = top_orgs["Total Visits"].replace(np.nan, 0, regex=True)
# closed_df["Pages Per Visit"] = top_orgs["Pages Per Visit"].replace(np.nan, 0, regex=True)
# closed_df["Bounce Rate"] = top_orgs["Bounce Rate"].replace(np.nan, 0, regex=True)

# closed_df.head(5)
# closed_df.dtypes

# %%
# regex module
# import re  

# ## Total Visits: strip non-numeric characters and convert to float64
# for index, row in closed_df.iterrows():
#     print("index is: ", index)
#     print(row["Total Visits"])
#     print(type(row["Total Visits"]))
    
#     str1 = str(row["Total Visits"])
#     if "K" in str1:
#         str1 = re.sub('[<K]', '', str1)
#         flt_str1 = float(str1) * 1000
#         print("str1 with a K is ", str1)
#         closed_df.set_value(index, "Total Visits", flt_str1)
#     else:
#         str1 = re.sub('[<M]', '', str1)
#         flt_str1 = float(str1) * 1000000
#         print("other str1 is ", str1)
#         closed_df.set_value(index, "Total Visits", flt_str1)

# pd.set_option('display.float_format', lambda x: '%.2f' % x)
# closed_df["Total Visits"] = closed_df["Total Visits"]      
# closed_df   
# closed_df.dtypes

# %%
## Convert string columns into usable data types

## Convert a column to datetime64 type with only the time?
## pd.to_datetime.dt.time is a datetime.time object but not datetime64.
## Therefore, it is correct that the dtype for the column is object.  
## Converting Avg Visit Duration to datetime.time renders the desired 
## format 00:00:00.
## Check out this documentation on Time series:
## https://pandas.pydata.org/pandas-docs/stable/timeseries.html

# closed_df["Avg Visit Duration"] = pd.to_datetime(closed_df["Avg Visit Duration"],format="%H:%M:%S").dt.time

# closed_df["Bounce Rate"] = closed_df["Bounce Rate"].replace('[%]','', regex=True ).astype(np.float64)

# closed_df["Pages Per Visit"] = closed_df["Pages Per Visit"].astype(np.float64)

# closed_df
# closed_df.dtype
