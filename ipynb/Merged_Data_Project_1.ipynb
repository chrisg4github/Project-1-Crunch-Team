# %%
##Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import random as rd
np.random.seed(sum(map(ord, "aesthetics")))

# %%
## Read file and then sort 
csv_file = "companies.csv"
companies_df = pd.read_csv(csv_file, encoding="iso-8859-1",
                           parse_dates=["Founded Date","Closed Date","Last Funding Date"])
companies_df = companies_df.sort_values("Company Name").reset_index(drop=True)
print(len(companies_df.index))
companies_df.head(5)
# Out:
# 8664
#   Company Name                                   Company Name URL  \
# 0     #waywire    https://www.crunchbase.com/organization/waywire
# 1   *gram Labs  https://www.crunchbase.com/organization/gram-labs
# 2          .io  https://www.crunchbase.com/organization/io-rea...
# 3   /dev/color  https://www.crunchbase.com/organization/dev-color
# 4     10 By 10   https://www.crunchbase.com/organization/10-by-10
#
#                                      Category Groups  \
# 0  Media and Entertainment, Government and Milita...
# 1  Science and Engineering, Hardware, Data and An...
# 2                                 Data and Analytics
# 3                                                NaN
# 4                    Software, Professional Services
#
#                       Headquarters Location  \
# 0         New York, New York, United States
# 1         New York, New York, United States
# 2       Alexandria, Virginia, United States
# 3     Menlo Park, California, United States
# 4  San Francisco, California, United States
#
#                                          Description Crunchbase Rank  \
# 0  #waywire is an online community focused on soc...          21,987
# 1  GramLabs is a start up, leveraging deep learni...          11,897
# 2          .io is a real-time intelligence platform.          16,844
# 3  /dev/color is a non-profit organization that a...          35,003
# 4  10by10 builds a marketplace to more quickly ma...          59,822
#
#   Founded Date Closed Date  Number of Funding Rounds Last Funding Date  \
# 0   2012-06-01         NaT                         1        2012-06-30
# 1   2015-08-01         NaT                         1        2016-07-27
# 2   2015-03-01         NaT                         1        2015-10-01
# 3   2015-05-01         NaT                         1        2016-08-23
# 4   2015-01-01         NaT                         1        2017-07-01
#
#   Last Funding Amount Last Funding Type Total Funding Amount        Status
# 0         $1,750,000               Seed          $1,750,000   Was Acquired
# 1         $1,000,000               Seed          $1,000,000      Operating
# 2         $1,500,000               Seed          $1,500,000      Operating
# 3           $120,000               Seed            $120,000      Operating
# 4           $120,000               Seed            $120,000      Operating

# %%
companies_df.columns
# Out:
# Index(['Company Name', 'Company Name URL', 'Category Groups',
#        'Headquarters Location', 'Description', 'Crunchbase Rank',
#        'Founded Date', 'Closed Date', 'Number of Funding Rounds',
#        'Last Funding Date', 'Last Funding Amount', 'Last Funding Type',
#        'Total Funding Amount', 'Status'],
#       dtype='object')

# %%
companies_df.dtypes
# Out:
# Company Name                        object
# Company Name URL                    object
# Category Groups                     object
# Headquarters Location               object
# Description                         object
# Crunchbase Rank                     object
# Founded Date                datetime64[ns]
# Closed Date                 datetime64[ns]
# Number of Funding Rounds             int64
# Last Funding Date           datetime64[ns]
# Last Funding Amount                 object
# Last Funding Type                   object
# Total Funding Amount                object
# Status                              object
# dtype: object

# %%
companies_df = companies_df[["Company Name", "Founded Date", "Closed Date", "Number of Funding Rounds", "Last Funding Date", "Last Funding Amount", "Total Funding Amount", "Status"]]
companies_df.head()
# Out:
#   Company Name Founded Date Closed Date  Number of Funding Rounds  \
# 0     #waywire   2012-06-01         NaT                         1
# 1   *gram Labs   2015-08-01         NaT                         1
# 2          .io   2015-03-01         NaT                         1
# 3   /dev/color   2015-05-01         NaT                         1
# 4     10 By 10   2015-01-01         NaT                         1
#
#   Last Funding Date Last Funding Amount Total Funding Amount        Status
# 0        2012-06-30         $1,750,000           $1,750,000   Was Acquired
# 1        2016-07-27         $1,000,000           $1,000,000      Operating
# 2        2015-10-01         $1,500,000           $1,500,000      Operating
# 3        2016-08-23           $120,000             $120,000      Operating
# 4        2017-07-01           $120,000             $120,000      Operating

# %%
companies_pf = companies_df.rename(columns={
    "Company Name" : "Company",
    "Number of Funding Rounds" : "Funding Rounds"   
})

companies_pf.head()
# Out:
#       Company Founded Date Closed Date  Funding Rounds Last Funding Date  \
# 0    #waywire   2012-06-01         NaT               1        2012-06-30
# 1  *gram Labs   2015-08-01         NaT               1        2016-07-27
# 2         .io   2015-03-01         NaT               1        2015-10-01
# 3  /dev/color   2015-05-01         NaT               1        2016-08-23
# 4    10 By 10   2015-01-01         NaT               1        2017-07-01
#
#   Last Funding Amount Total Funding Amount        Status
# 0         $1,750,000           $1,750,000   Was Acquired
# 1         $1,000,000           $1,000,000      Operating
# 2         $1,500,000           $1,500,000      Operating
# 3           $120,000             $120,000      Operating
# 4           $120,000             $120,000      Operating

# %%
## Read file and then sort 
funding = "Funding_Rounds.csv"
funding_df = pd.read_csv(funding, encoding="iso-8859-1")
funding_df.head(5)
# Out:
#   Company Name                                   Company Name URL  \
# 0          .io  https://www.crunchbase.com/organization/io-rea...
# 1   *gram Labs  https://www.crunchbase.com/organization/gram-labs
# 2   /dev/color  https://www.crunchbase.com/organization/dev-color
# 3     #waywire    https://www.crunchbase.com/organization/waywire
# 4     10 By 10   https://www.crunchbase.com/organization/10-by-10
#
#   Funding Type Money Raised Announced On Date
# 0         Seed  $1,500,000            10/1/15
# 1         Seed  $1,000,000            7/27/16
# 2         Seed    $120,000            8/23/16
# 3         Seed  $1,750,000            6/30/12
# 4         Seed    $120,000             7/1/17

# %%
funding_df.dtypes
# Out:
# Company Name         object
# Company Name URL     object
# Funding Type         object
# Money Raised         object
# Announced On Date    object
# dtype: object

# %%
funding_df = funding_df[["Company Name", "Funding Type", "Money Raised", "Announced On Date"]]
funding_df.head()
# Out:
#   Company Name Funding Type Money Raised Announced On Date
# 0          .io         Seed  $1,500,000            10/1/15
# 1   *gram Labs         Seed  $1,000,000            7/27/16
# 2   /dev/color         Seed    $120,000            8/23/16
# 3     #waywire         Seed  $1,750,000            6/30/12
# 4     10 By 10         Seed    $120,000             7/1/17

# %%
funding_pf = funding_df.rename(columns={
    "Company Name" : "Company"
})

funding_pf.head()
# Out:
#       Company Funding Type Money Raised Announced On Date
# 0         .io         Seed  $1,500,000            10/1/15
# 1  *gram Labs         Seed  $1,000,000            7/27/16
# 2  /dev/color         Seed    $120,000            8/23/16
# 3    #waywire         Seed  $1,750,000            6/30/12
# 4    10 By 10         Seed    $120,000             7/1/17

# %%
merged_data = pd.merge(companies_pf, funding_pf,how="inner",on="Company")
merged_data.head(5)
# Out:
#       Company Founded Date Closed Date  Funding Rounds Last Funding Date  \
# 0    #waywire   2012-06-01         NaT               1        2012-06-30
# 1  *gram Labs   2015-08-01         NaT               1        2016-07-27
# 2         .io   2015-03-01         NaT               1        2015-10-01
# 3  /dev/color   2015-05-01         NaT               1        2016-08-23
# 4    10 By 10   2015-01-01         NaT               1        2017-07-01
#
#   Last Funding Amount Total Funding Amount        Status Funding Type  \
# 0         $1,750,000           $1,750,000   Was Acquired         Seed
# 1         $1,000,000           $1,000,000      Operating         Seed
# 2         $1,500,000           $1,500,000      Operating         Seed
# 3           $120,000             $120,000      Operating         Seed
# 4           $120,000             $120,000      Operating         Seed
#
#   Money Raised Announced On Date
# 0  $1,750,000            6/30/12
# 1  $1,000,000            7/27/16
# 2  $1,500,000            10/1/15
# 3    $120,000            8/23/16
# 4    $120,000             7/1/17

# %%
merged_data.to_csv("Homepage_Output.csv")

# %%
merged_data.columns
# Out:
# Index(['Company', 'Founded Date', 'Closed Date', 'Funding Rounds',
#        'Last Funding Date', 'Last Funding Amount', 'Total Funding Amount',
#        'Status', 'Funding Type', 'Money Raised', 'Announced On Date'],
#       dtype='object')

# %%
type(merged_data['Announced On Date'].values[0])
# Out:
# str

# %%
merged_data['Announced On Date'].values[0]
# Out:
# '6/30/12'

# %%
# convert sting to datetime

from datetime import datetime

# datetime_object = datetime.strptime('Jun 1 2005  1:33PM', '%b %d %Y %I:%M%p')
datetime_object = datetime.strptime('6/30/12', '%m/%d/%y')

# %%
datetime_object
# Out:
# datetime.datetime(2012, 6, 30, 0, 0)

# %%
merged_data['Announced On Date Converted'] = merged_data['Announced On Date'].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))

# %%
merged_data.head()
# Out:
#       Company Founded Date Closed Date  Funding Rounds Last Funding Date  \
# 0    #waywire   2012-06-01         NaT               1        2012-06-30
# 1  *gram Labs   2015-08-01         NaT               1        2016-07-27
# 2         .io   2015-03-01         NaT               1        2015-10-01
# 3  /dev/color   2015-05-01         NaT               1        2016-08-23
# 4    10 By 10   2015-01-01         NaT               1        2017-07-01
#
#   Last Funding Amount Total Funding Amount        Status Funding Type  \
# 0         $1,750,000           $1,750,000   Was Acquired         Seed
# 1         $1,000,000           $1,000,000      Operating         Seed
# 2         $1,500,000           $1,500,000      Operating         Seed
# 3           $120,000             $120,000      Operating         Seed
# 4           $120,000             $120,000      Operating         Seed
#
#   Money Raised Announced On Date Announced On Date Converted
# 0  $1,750,000            6/30/12                  2012-06-30
# 1  $1,000,000            7/27/16                  2016-07-27
# 2  $1,500,000            10/1/15                  2015-10-01
# 3    $120,000            8/23/16                  2016-08-23
# 4    $120,000             7/1/17                  2017-07-01

# %%
## Read file and then sort 
org = "organizations.csv"
org_df = pd.read_csv(org, encoding="iso-8859-1")
org_df.head(5)
# Out:
#    UNKNOWN                                  UUID Company Name  \
# 0   352124  ea359946-4db6-5eee-b466-bd0774491e2d            1
# 1    24310  019602e2-8727-7fc1-af9f-4134dc629ca5           39
# 2    62273  01eb53db-bcee-c57f-3ab1-54fb53f6de65           55
# 3   231876  c1723121-d8a2-457c-1b81-25fc42e78d95           99
# 4   402099  934bd25a-4b91-9d78-12c3-524c679d3e69          101
#
#                     Homepage
# 0               http://y.com
# 1           http://39inc.com
# 2  http://www.fifty-five.com
# 3     http://www.99taxis.com
# 4      http://www.101edu.co/

# %%
# Rename columns for readability
new_file = org_df.rename(columns={
    "crunchbase_uuid": "UUID",
    "Company Name" : "Company",
    "homepage_url" : "Homepage"   
})

new_file.head()
# Out:
#    UNKNOWN                                  UUID Company  \
# 0   352124  ea359946-4db6-5eee-b466-bd0774491e2d       1
# 1    24310  019602e2-8727-7fc1-af9f-4134dc629ca5      39
# 2    62273  01eb53db-bcee-c57f-3ab1-54fb53f6de65      55
# 3   231876  c1723121-d8a2-457c-1b81-25fc42e78d95      99
# 4   402099  934bd25a-4b91-9d78-12c3-524c679d3e69     101
#
#                     Homepage
# 0               http://y.com
# 1           http://39inc.com
# 2  http://www.fifty-five.com
# 3     http://www.99taxis.com
# 4      http://www.101edu.co/

# %%
new_file = new_file[["UUID", "Company", "Homepage"]]
new_file.head()
# Out:
#                                    UUID Company                   Homepage
# 0  ea359946-4db6-5eee-b466-bd0774491e2d       1               http://y.com
# 1  019602e2-8727-7fc1-af9f-4134dc629ca5      39           http://39inc.com
# 2  01eb53db-bcee-c57f-3ab1-54fb53f6de65      55  http://www.fifty-five.com
# 3  c1723121-d8a2-457c-1b81-25fc42e78d95      99     http://www.99taxis.com
# 4  934bd25a-4b91-9d78-12c3-524c679d3e69     101      http://www.101edu.co/

# %%
new_file.to_csv("Org_Output.csv")

# %%
merged_df = pd.merge(merged_data, new_file,how="inner",on="Company")
merged_df.head()
# Out:
#       Company Founded Date Closed Date  Funding Rounds Last Funding Date  \
# 0    #waywire   2012-06-01         NaT               1        2012-06-30
# 1  *gram Labs   2015-08-01         NaT               1        2016-07-27
# 2         .io   2015-03-01         NaT               1        2015-10-01
# 3  /dev/color   2015-05-01         NaT               1        2016-08-23
# 4    10 By 10   2015-01-01         NaT               1        2017-07-01
#
#   Last Funding Amount Total Funding Amount        Status Funding Type  \
# 0         $1,750,000           $1,750,000   Was Acquired         Seed
# 1         $1,000,000           $1,000,000      Operating         Seed
# 2         $1,500,000           $1,500,000      Operating         Seed
# 3           $120,000             $120,000      Operating         Seed
# 4           $120,000             $120,000      Operating         Seed
#
#   Money Raised Announced On Date Announced On Date Converted  \
# 0  $1,750,000            6/30/12                  2012-06-30
# 1  $1,000,000            7/27/16                  2016-07-27
# 2  $1,500,000            10/1/15                  2015-10-01
# 3    $120,000            8/23/16                  2016-08-23
# 4    $120,000             7/1/17                  2017-07-01
#
#                                    UUID                  Homepage
# 0  3ca06819-3ca9-ce42-ce20-f0e150d563a0    http://www.waywire.com
# 1  18e8dd5e-fe1d-5f8e-f2ed-b254171d7f5d    http://www.gramlabs.ai
# 2  cf169e68-c903-c089-8789-bdd557d6a4c1          https://onthe.io
# 3  165f412c-361d-7931-fd3b-cf5e2a1ccef3  http://www.devcolor.org/
# 4  e1670a30-4ff5-893d-0ae3-ceb761e1c251    https://www.10by10.io/

# %%
# didn't work
# merged_pf = merged_df["UUID"].replace("-", "")
# merged_pf.head()

# %%
# didn't work
# merged_df["UUID"].replace("-", "", inplace=True)

# %%
# didn't work BUT replaces dashes but doesn't replace the value
# merged_df['UUID'].apply(lambda x: x.replace("-", ""))
# print('done')

# %%
# works
for i, el in enumerate(merged_df.iterrows()):
    val = el[1]['UUID'].replace("-", "")
    merged_df.set_value(i, "UUID", val)

# %%
# check if dashes are gone in UUID column
merged_df.head()['UUID']
# Out:
# 0    3ca068193ca9ce42ce20f0e150d563a0
# 1    18e8dd5efe1d5f8ef2edb254171d7f5d
# 2    cf169e68c903c0898789bdd557d6a4c1
# 3    165f412c361d7931fd3bcf5e2a1ccef3
# 4    e1670a304ff5893d0ae3ceb761e1c251
# Name: UUID, dtype: object

# %%
merged_df.head(5)
# Out:
#       Company Founded Date Closed Date  Funding Rounds Last Funding Date  \
# 0    #waywire   2012-06-01         NaT               1        2012-06-30
# 1  *gram Labs   2015-08-01         NaT               1        2016-07-27
# 2         .io   2015-03-01         NaT               1        2015-10-01
# 3  /dev/color   2015-05-01         NaT               1        2016-08-23
# 4    10 By 10   2015-01-01         NaT               1        2017-07-01
#
#   Last Funding Amount Total Funding Amount        Status Funding Type  \
# 0         $1,750,000           $1,750,000   Was Acquired         Seed
# 1         $1,000,000           $1,000,000      Operating         Seed
# 2         $1,500,000           $1,500,000      Operating         Seed
# 3           $120,000             $120,000      Operating         Seed
# 4           $120,000             $120,000      Operating         Seed
#
#   Money Raised Announced On Date Announced On Date Converted  \
# 0  $1,750,000            6/30/12                  2012-06-30
# 1  $1,000,000            7/27/16                  2016-07-27
# 2  $1,500,000            10/1/15                  2015-10-01
# 3    $120,000            8/23/16                  2016-08-23
# 4    $120,000             7/1/17                  2017-07-01
#
#                                UUID                  Homepage
# 0  3ca068193ca9ce42ce20f0e150d563a0    http://www.waywire.com
# 1  18e8dd5efe1d5f8ef2edb254171d7f5d    http://www.gramlabs.ai
# 2  cf169e68c903c0898789bdd557d6a4c1          https://onthe.io
# 3  165f412c361d7931fd3bcf5e2a1ccef3  http://www.devcolor.org/
# 4  e1670a304ff5893d0ae3ceb761e1c251    https://www.10by10.io/

# %%
'a' in ['a', 'b', 'c']
# Out:
# True

# %%
'd' in ['a', 'b', 'c']
# Out:
# False

# %%
#funding = merged_df.groupby('Company')["Funding Type"].value_counts()
funding_df = merged_df[merged_df['Company'] == "Seed"]
#funding_df = funding[funding['Funding Type'] == "Seed"]
funding_df.head(100)
# Out:
# Empty DataFrame
# Columns: [Company, Founded Date, Closed Date, Funding Rounds, Last Funding Date, Last Funding Amount, Total Funding Amount, Status, Funding Type, Money Raised, Announced On Date, Announced On Date Converted, UUID, Homepage]
# Index: []

# %%
merged_df.dtypes
# Out:
# Company                                object
# Founded Date                   datetime64[ns]
# Closed Date                    datetime64[ns]
# Funding Rounds                          int64
# Last Funding Date              datetime64[ns]
# Last Funding Amount                    object
# Total Funding Amount                   object
# Status                                 object
# Funding Type                           object
# Money Raised                           object
# Announced On Date                      object
# Announced On Date Converted    datetime64[ns]
# UUID                                   object
# Homepage                               object
# dtype: object

# %%
status = merged_df.groupby('Funding Type')["Status"].value_counts()

#g1 = df1.groupby(["Name", "City"], as_index=False).count()

status.head(10)
# Out:
# Funding Type  Status
# Seed          Operating       5434
#               Was Acquired     371
#               Closed           222
#               IPO                3
# Series A      Operating       2594
#               Was Acquired     203
#               Closed            51
#               IPO               16
# Series B      Operating        953
#               Was Acquired      65
# Name: Status, dtype: int64

# %%
df1 = pd.DataFrame(status).rename(columns={
    'Status': 'Count'})

df1.head(100)
# Out:
#                            Count
# Funding Type Status
# Seed         Operating      5434
#              Was Acquired    371
#              Closed          222
#              IPO               3
# Series A     Operating      2594
#              Was Acquired    203
#              Closed           51
#              IPO              16
# Series B     Operating       953
#              Was Acquired     65
#              IPO              15
#              Closed           13
# Series C     Operating       264
#              Was Acquired     13
#              IPO               2
# Series D     Operating        57
#              Was Acquired      2

# %%
series_d = merged_df[merged_df['Funding Type'] == "Series D"]
series_d
# Out:
#                          Company Founded Date Closed Date  Funding Rounds  \
# 82                   908 Devices   2012-01-01         NaT               5
# 421                      Alector   2013-01-01         NaT               3
# 933                       AveXis   2013-01-01         NaT               4
# 1325                       Blend   2012-05-01         NaT               5
# 1326                       Blend   2012-05-01         NaT               5
# 1327                       Blend   2012-05-01         NaT               5
# 1650        Bustle Digital Group   2013-01-01         NaT               5
# 1839                    Catalant   2013-01-01         NaT               5
# 1840                    Catalant   2013-01-01         NaT               5
# 2064    CloudHealth Technologies   2012-01-01         NaT               5
# 2077               Clover Health   2013-01-01         NaT               5
# 2130                    Coinbase   2012-06-01         NaT               6
# 2147   College Ave Student Loans   2014-01-01         NaT               4
# 2226                     Compass   2012-10-04         NaT               5
# 2227                     Compass   2012-10-04         NaT               5
# 2228                     Compass   2012-10-04         NaT               5
# 2229                     Compass   2012-10-04         NaT               5
# 2230                     Compass   2012-10-04         NaT               5
# 2231                     Compass   2012-10-04         NaT               5
# 2232                     Compass   2012-10-04         NaT               5
# 2261                     Compass   2014-01-01         NaT               1
# 2262                     Compass   2014-01-01         NaT               1
# 2263                     Compass   2014-01-01         NaT               1
# 2264                     Compass   2014-01-01         NaT               1
# 2265                     Compass   2014-01-01         NaT               1
# 2266                     Compass   2014-01-01         NaT               1
# 2267                     Compass   2014-01-01         NaT               1
# 2412                    Coursera   2012-01-01         NaT               7
# 2594                  Cybereason   2012-01-01         NaT               4
# 2604                     Cylance   2012-07-04         NaT               4
# 2655                  Databricks   2013-01-01         NaT               4
# 2751               Desktop Metal   2015-01-01         NaT               5
# 3550                       Fugue   2012-01-01         NaT               5
# 3682                       Giphy   2013-02-01         NaT               4
# 4316                     Illumio   2013-01-01         NaT               4
# 4420                   Instacart   2012-01-01         NaT               7
# 4583                  JustVisual   2015-04-07         NaT               1
# 4922          Life Boost (Tespo)   2013-01-01         NaT               1
# 5016                     Livongo   2014-01-01         NaT               6
# 5769                     NowThis   2012-09-01         NaT               4
# 5886                     Onshape   2012-01-01         NaT               4
# 5915                    Opendoor   2014-01-01         NaT               4
# 6112                      Paxata   2012-05-29         NaT               4
# 6290                    PillPack   2013-01-31         NaT               5
# 6491                   Prescient   2013-01-01         NaT               3
# 6492                   Prescient   2013-01-01         NaT               3
# 6723                       REBBL   2012-01-01         NaT               2
# 6984                        Ring   2012-01-01         NaT               6
# 6985                        Ring   2012-01-01         NaT               6
# 7118                      Rubrik   2014-01-01         NaT               4
# 7729         Snowflake Computing   2012-01-01         NaT               4
# 8183        Super Evil Mega Corp   2012-01-01         NaT               6
# 8366        Tarveda Therapeutics   2012-01-01         NaT               6
# 8372                   Tastemade   2012-01-01         NaT               4
# 8672                   TrendKite   2012-01-01         NaT               6
# 8737     True North Therapeutics   2013-01-01         NaT               4
# 8942                     Upstart   2012-04-01         NaT               5
# 9064             VeloCloud, Inc.   2012-01-01         NaT               3
# 10101                  honeygrow   2012-01-01         NaT               2
#
#       Last Funding Date Last Funding Amount Total Funding Amount  \
# 82           2017-03-15        $20,000,000          $49,300,000
# 421          2016-01-07        $29,500,000          $61,500,000
# 933          2015-09-08        $65,000,000          $75,000,000
# 1325         2017-08-24       $100,000,000         $160,000,000
# 1326         2017-08-24       $100,000,000         $160,000,000
# 1327         2017-08-24       $100,000,000         $160,000,000
# 1650         2017-03-10        $12,000,000          $50,500,000
# 1839         2017-06-27        $41,000,000          $75,550,000
# 1840         2017-06-27        $41,000,000          $75,550,000
# 2064         2017-06-27        $46,000,000          $85,700,000
# 2077         2017-05-10       $130,000,000         $425,000,000
# 2130         2017-08-10       $100,000,000         $217,209,590
# 2147         2017-04-13        $30,000,000          $63,400,000
# 2226         2016-08-31        $75,000,000         $208,000,000
# 2227         2016-08-31        $75,000,000         $208,000,000
# 2228         2016-08-31        $75,000,000         $208,000,000
# 10101                  2016-11-17  3826eca93eb0118a76c1667fc2ddf0ff
#
#                                       Homepage
# 82                       http://908devices.com
# 421                         http://alector.com
# 933                        https://avexis.com/
# 1325                    http://www.blendsd.com
# 1326                     https://www.blend.com
# 1327                     http://www.blend.life
# 1650                         http://bustle.com
# 1839                 http://www.gocatalant.com
# 1840                        http://catalant.co
# 2064            http://www.cloudhealthtech.com
# 2077                   http://cloverhealth.com
# 2130                  https://www.coinbase.com
# 2147   https://www.collegeavestudentloans.com/
# 2226                  http://www.compassmc.com
# 2227                     http://www.compass.co
# 2228           http://www.compassbeverages.com
# 2229                         http://compass.li
# 2230                    http://www.compass.com
# 2231                  http://hellocompass.com/
# 2232               http://www.compass3d.com.br
# 2261                  http://www.compassmc.com
# 2262                     http://www.compass.co
# 2263           http://www.compassbeverages.com
# 2264                         http://compass.li
# 2265                    http://www.compass.com
# 2266                  http://hellocompass.com/
# 2267               http://www.compass3d.com.br
# 2412                   http://www.coursera.org
# 2594                 http://www.cybereason.com
# 2604                    http://www.cylance.com
# 2655                    https://databricks.com
# 2751               http://www.desktopmetal.com
# 3550                         https://fugue.co/
# 3682                          http://giphy.com
# 4316                    http://www.illumio.com
# 4420                 https://www.instacart.com
# 4583                 http://www.justvisual.com
# 4922                     https://gettespo.com/
# 5016                   http://www.livongo.com/
# 5769                    http://nowthisnews.com
# 5886                    http://www.onshape.com
# 5915                  https://www.opendoor.com
# 6112                     http://www.paxata.com
# 6290                   http://www.pillpack.com
# 6491                http://www.prescientco.com
# 6492               http://www.prescienthg.com/
# 6723                           http://rebbl.co
# 6984                          https://ring.com
# 6985                           http://ring.cx/
# 7118                        http://rubrik.com/
# 7729                 http://www.snowflake.net/
# 8183          http://www.superevilmegacorp.com
# 8366                   http://www.tarveda.com/
# 8372                  http://www.tastemade.com
# 8672                      http://trendkite.com
# 8737               http://www.truenorthrx.com/
# 8942                    http://www.upstart.com
# 9064                  http://www.velocloud.com
# 10101                http://www.honeygrow.com/

# %%
funding_df = merged_df[merged_df['Funding Type'] == "Seed"]
funding_df
# Out:
#                                       Company Founded Date Closed Date  \
# 0                                    #waywire   2012-06-01         NaT
# 1                                  *gram Labs   2015-08-01         NaT
# 2                                         .io   2015-03-01         NaT
# 3                                  /dev/color   2015-05-01         NaT
# 4                                    10 By 10   2015-01-01         NaT
# 9                                       10sec   2013-07-08         NaT
# 10                                    12 Labs   2014-08-01         NaT
# 11                                 121 Mobile   2012-02-17         NaT
# 12                             128 Technology   2014-07-07         NaT
# 16                                     17hats   2014-01-01         NaT
# 18                                   18Angles   2015-01-01         NaT
# 19                                     19Labs   2015-01-01         NaT
# 21                                    1Huddle   2015-01-01         NaT
# 22                                    1Huddle   2015-01-01         NaT
# 23                                       1UPd   2015-08-12         NaT
# 26                                        20n   2013-01-01         NaT
# 27                                        20n   2013-01-01         NaT
# 30                                     23VIVI   2015-12-22         NaT
# 31                                   27 Perry   2012-01-01  2013-01-01
# 32                                 2Hat Media   2012-01-01         NaT
# 33                                  2ULaundry   2015-12-01         NaT
# 34                         30 Second Showcase   2013-04-01         NaT
# 35                                    37coins   2014-01-01         NaT
# 36                                    37coins   2014-01-01         NaT
# 37                        3D Operations, Inc.   2014-01-01         NaT
# 38                                  3D-SensIR   2016-01-01         NaT
# 40                                  3Diligent   2014-07-23         NaT
# 41                               3MayDay Inc.   2013-02-08         NaT
# 42                               3MayDay Inc.   2013-02-08         NaT
# 43                                      3TEN8   2013-08-15         NaT
# ...                                       ...          ...         ...
# 10241                                   uBack   2014-10-01         NaT
# 10244                                   uMake   2014-04-01         NaT
# 10246                                 uMix.TV   2013-01-01         NaT
# 10247                                   uSens   2013-01-01         NaT
# 10248                                   uSens   2013-01-01         NaT
# 10250                               udiospace   2014-01-01         NaT
# 10251                                  unGlue   2015-01-01         NaT
# 10252                              uniRow Inc   2013-06-15         NaT
# 10253                                   vDice   2016-01-01         NaT
# 10254                                 venVelo   2012-01-01         NaT
# 10255                                   vidIQ   2012-01-01         NaT
# 10256                                   vidIQ   2012-01-01         NaT
# 10257                                    voie   2016-07-21         NaT
# 10258                                vushaper   2012-01-01         NaT
# 10259                                  walkby   2012-08-01  2013-01-01
# 10260                          weBounty, Inc.   2015-01-14         NaT
# 10261                                wpXtreme   2012-08-01         NaT
# 10262                             wrkbench.io   2013-01-01         NaT
# 10263                             wrkbench.io   2013-01-01         NaT
# 10264                                    x.ai   2014-04-14         NaT
# 10268                                  xendit   2014-11-01         NaT
# 10269                                     xiQ   2013-09-01         NaT
# 10270                                  yaBeam   2013-08-01         NaT
# 10271                                   yoPay   2016-01-01         NaT
# 10272                               youarrive   2016-01-01         NaT
# 10273                                zEconomy   2013-01-01         NaT
# 10274  zPREDICTA (formerly Ixchel Scientific)   2014-01-01         NaT
# 10275                                   zanda   2013-01-01         NaT
# 10276                                 zipster   2014-04-01         NaT
# 10277                                   zurvu   2012-01-01         NaT
#
#        Funding Rounds Last Funding Date Last Funding Amount  \
# 0                   1        2012-06-30         $1,750,000
# 1                   1        2016-07-27         $1,000,000
# 2                   1        2015-10-01         $1,500,000
# 3                   1        2016-08-23           $120,000
# 4                   1        2017-07-01           $120,000
# 9                   2        2014-05-08         $1,600,000
# 10                  1        2014-11-26           $935,000
# 11                  4        2015-12-18         $2,200,000
# 12                  4        2017-05-31        $21,500,000
# 16                  2        2015-10-15         $4,000,000
# 18                  1        2016-02-01           $500,000
# 19                  1        2016-09-01           $680,000
# 21                  2        2017-03-15           $500,000
# 22                  2        2017-03-15           $500,000
# 23                  1        2015-09-09            $30,000
# 26                  2        2015-05-01         $2,100,000
# 27                  2        2015-05-01         $2,100,000
# 30                  1        2016-02-12            $20,000
# 31                  1        2012-05-17           $118,000
# 32                  1        2013-01-01           $150,000
# 33                  1        2016-11-14           $400,000
# 34                  1        2013-05-20            $25,000
# 35                  2        2014-06-01           $500,000
# 36                  2        2014-06-01           $500,000
# 37                  1        2014-05-15             $7,500
# 38                  1        2016-09-26            $75,000
# 40                  2        2015-03-15           $900,000
# 41                  2        2017-03-21            $80,000
# 42                  2        2017-03-21            $80,000
# 43                  1        2015-04-15         $1,670,000
# ...               ...               ...                 ...
# 10241               1        2017-02-08         $2,000,000
# 10244               3        2015-12-03         $4,500,000
# 10246               1        2013-04-01           $130,000
# 10247               3        2016-06-01        $20,000,000
# 10248               3        2016-06-01        $20,000,000
# 10250               1        2016-05-15            $50,000
# 10251               2        2017-03-02         $1,500,000
# 10252               2        2014-05-06           $214,471
# 10253               1        2016-12-08         $1,800,000
# 10254               1        2015-01-06         $1,300,000
# 10255               3        2013-02-26         $2,000,000
# 10256               3        2013-02-26         $2,000,000
# 10257               1        2016-07-21           $160,000
# 10258               1        2012-03-01           $200,000
# 10259               2        2013-04-10           $650,000
# 10260               1        2015-02-28            $20,000
# 10261               2        2013-11-10           $100,000
# 10262               2        2015-03-12           $975,000
# 10263               2        2015-03-12           $975,000
# 10264               4        2017-08-14        $10,000,000
# 10268               2        2015-09-01           $120,000
# 10269               1        2014-11-18           $725,000
# 10270               1        2013-06-01           $150,000
# 10271               1        2016-01-29           $550,000
# 10272               1        2016-01-01           $250,000
# 10273               1        2014-06-18         $1,550,000
# 10274               1        2015-09-01           $120,000
# 10275               1        2013-01-21            $10,000
# 10276               2        2016-08-12         $2,000,000
# 10277               1        2014-03-20         $1,200,000
#
#       Total Funding Amount        Status Funding Type Money Raised  \
# 0              $1,750,000   Was Acquired         Seed  $1,750,000
# 1              $1,000,000      Operating         Seed  $1,000,000
# 2              $1,500,000      Operating         Seed  $1,500,000
# 3                $120,000      Operating         Seed    $120,000
# 4                $120,000      Operating         Seed    $120,000
# 9              $1,600,000      Operating         Seed  $1,600,000
# 10               $935,000      Operating         Seed    $935,000
# 11             $4,000,000      Operating         Seed  $2,200,000
# 12            $57,499,347      Operating         Seed  $4,000,000
# 16             $5,250,000      Operating         Seed  $1,250,000
# 18               $500,000      Operating         Seed    $500,000
# 19               $680,000      Operating         Seed    $680,000
# 21               $625,000      Operating         Seed    $500,000
# 22               $625,000      Operating         Seed    $125,000
# 23                $30,000      Operating         Seed     $30,000
# 26             $2,220,000      Operating         Seed  $2,100,000
# 27             $2,220,000      Operating         Seed    $120,000
# 30                $20,000      Operating         Seed     $20,000
# 31               $118,000         Closed         Seed    $118,000
# 32               $150,000      Operating         Seed    $150,000
# 33               $400,000      Operating         Seed    $400,000
# 34                $25,000      Operating         Seed     $25,000
# 35               $525,000      Operating         Seed    $500,000
# 36               $525,000      Operating         Seed     $25,000
# 37                 $7,500      Operating         Seed      $7,500
# 38                $75,000      Operating         Seed     $75,000
# 40             $1,150,000      Operating         Seed    $900,000
# 41               $230,000      Operating         Seed    $150,000
# 42               $230,000      Operating         Seed     $80,000
# 43             $1,670,000      Operating         Seed  $1,670,000
# ...                    ...           ...          ...          ...
# 10241          $2,000,000      Operating         Seed  $2,000,000
# 10244          $5,200,000      Operating         Seed    $700,000
# 10246            $130,000      Operating         Seed    $130,000
# 10247         $26,700,000      Operating         Seed  $5,500,000
# 10248         $26,700,000      Operating         Seed  $1,200,000
# 10250             $50,000      Operating         Seed     $50,000
# 10251          $1,500,000      Operating         Seed  $1,500,000
# 10252          $1,214,471      Operating         Seed    $214,471
# 10253          $1,800,000      Operating         Seed  $1,800,000
# 10254          $1,300,000      Operating         Seed  $1,300,000
# 10255          $4,000,000      Operating         Seed  $2,000,000
# 10256          $4,000,000      Operating         Seed  $2,000,000
# 10257            $160,000      Operating         Seed    $160,000
# 10258            $200,000      Operating         Seed    $200,000
# 10259            $650,000         Closed         Seed    $650,000
# 10260             $20,000      Operating         Seed     $20,000
# 10261            $132,000      Operating         Seed    $100,000
# 10262          $1,035,000      Operating         Seed    $975,000
# 10263          $1,035,000      Operating         Seed     $60,000
# 10264         $44,300,000      Operating         Seed  $2,100,000
# 10268            $120,000      Operating         Seed    $120,000
# 10269            $725,000      Operating         Seed    $725,000
# 10270            $150,000      Operating         Seed    $150,000
# 10271            $550,000      Operating         Seed    $550,000
# 10272            $250,000      Operating         Seed    $250,000
# 10273          $1,550,000      Operating         Seed  $1,550,000
# 10274            $120,000      Operating         Seed    $120,000
# 10275             $10,000      Operating         Seed     $10,000
# 10276          $4,200,000      Operating         Seed  $2,000,000
# 10277          $1,200,000   Was Acquired         Seed  $1,200,000
#
#       Announced On Date Announced On Date Converted  \
# 0               6/30/12                  2012-06-30
# 1               7/27/16                  2016-07-27
# 2               10/1/15                  2015-10-01
# 3               8/23/16                  2016-08-23
# 4                7/1/17                  2017-07-01
# 9                5/8/14                  2014-05-08
# 10             11/26/14                  2014-11-26
# 11             12/18/15                  2015-12-18
# 12               7/7/14                  2014-07-07
# 16              2/18/15                  2015-02-18
# 18               2/1/16                  2016-02-01
# 19               9/1/16                  2016-09-01
# 21              3/15/17                  2017-03-15
# 22             10/20/15                  2015-10-20
# 23               9/9/15                  2015-09-09
# 26               5/1/15                  2015-05-01
# 27              12/1/14                  2014-12-01
# 30              2/12/16                  2016-02-12
# 31              5/17/12                  2012-05-17
# 32               1/1/13                  2013-01-01
# 33             11/14/16                  2016-11-14
# 34              5/20/13                  2013-05-20
# 35               6/1/14                  2014-06-01
# 36              3/15/14                  2014-03-15
# 37              5/15/14                  2014-05-15
# 38              9/26/16                  2016-09-26
# 40              3/15/15                  2015-03-15
# 41             11/16/13                  2013-11-16
# 42              3/21/17                  2017-03-21
# 43              4/15/15                  2015-04-15
# ...                 ...                         ...
# 10241            2/8/17                  2017-02-08
# 10244            9/1/15                  2015-09-01
# 10246            4/1/13                  2013-04-01
# 10247           9/14/15                  2015-09-14
# 10248           10/2/14                  2014-10-02
# 10250           5/15/16                  2016-05-15
# 10251            3/2/17                  2017-03-02
# 10252            5/6/14                  2014-05-06
# 10253           12/8/16                  2016-12-08
# 10254            1/6/15                  2015-01-06
# 10255            8/1/12                  2012-08-01
# 10256           2/26/13                  2013-02-26
# 10257           7/21/16                  2016-07-21
# 10258            3/1/12                  2012-03-01
# 10259           4/10/13                  2013-04-10
# 10260           2/28/15                  2015-02-28
# 10261          11/10/13                  2013-11-10
# 10262           3/12/15                  2015-03-12
# 10263           10/1/13                  2013-10-01
# 10264           5/21/14                  2014-05-21
# 10268            9/1/15                  2015-09-01
# 10269          11/18/14                  2014-11-18
# 10270            6/1/13                  2013-06-01
# 10253  0b88035af33c85a29e93de36382c8278            https://www.vdice.io/
# 10254  98759cf503230ed821953b8f9364bd6c               http://venvelo.com
# 10255  53baed17d1ae3bce54ca4db92b796d47                 http://vidiq.com
# 10256  53baed17d1ae3bce54ca4db92b796d47                 http://vidiq.com
# 10257  108e5f9c7700d894d800b9bf24af66e2              http://www.voie.com
# 10258  d4446bcd406522b2ead78dc78cba2e1e              http://vushaper.com
# 10259  8631b587d8ff66ecd53fe00318560f0a                http://walkby.com
# 10260  dbfdabb6a1030cba3e887baf5aafa782              http://webounty.com
# 10261  622adb6c6cac81819e04d7c8442251fa                 http://wpxtre.me
# 10262  a172e6979eb2a494ec8f3ba6fed91735               http://wrkbench.io
# 10263  a172e6979eb2a494ec8f3ba6fed91735               http://wrkbench.io
# 10264  d2e42e38102cf24256c2d50e950188d8                     https://x.ai
# 10268  f7ccba4d13899d898cdc68c8e37dbd96             http://www.xendit.co
# 10269  24e589a2b092e867467129fa8dfb7029                http://www.xiq.ai
# 10270  8cd466d436647160a9b0f8aee32f924d                http://yabeam.com
# 10271  5d476d7e60a62651fe539f8d23b5c1b0         http://www.getyopay.com/
# 10272  e144495aaff8e9e3b6c60746b970c523         http://www.youarrive.com
# 10273  e33b075af561ea0e1c39db72804500f2         http://www.zeconomy.com/
# 10274  b7daa791bbf49459e9eca8852a07e24b             http://zpredicta.com
# 10275  de94b5c9f9be08116b29725abe87fac2              http://www.zanda.fr
# 10276  ee45629b3eae8118203b834502d46772           https://www.zipster.co
# 10277  aa116f6a49a61e8222393e0fe5a3557c           https://www.zurvu.com/
#
# [6030 rows x 14 columns]

# %%
seed = merged_df[merged_df['Status'] == "Was Acquired"].count
seed_df = merged_df[merged_df['Funding Type'] == "Seed"]

seed_df = seed_df[seed_df['Status'] == "Was Acquired"]

seed_df
# Out:
#                          Company Founded Date Closed Date  Funding Rounds  \
# 0                       #waywire   2012-06-01         NaT               1
# 97                       ADSHIFT   2013-01-01         NaT               1
# 165                       Abakus   2013-01-01         NaT               1
# 166                       Abakus   2013-01-01         NaT               1
# 167                    AbbeyPost   2012-08-01         NaT               5
# 168                    AbbeyPost   2012-08-01         NaT               5
# 169                    AbbeyPost   2012-08-01         NaT               5
# 170                    AbbeyPost   2012-08-01         NaT               5
# 217                 Acquaintable   2012-01-01         NaT               1
# 224                      ActionX   2012-01-01         NaT               2
# 228        Activate by Bloglovin   2012-03-15         NaT               4
# 229        Activate by Bloglovin   2012-03-15         NaT               4
# 230        Activate by Bloglovin   2012-03-15         NaT               4
# 231        Activate by Bloglovin   2012-03-15         NaT               4
# 240                   AdEspresso   2013-10-01         NaT               4
# 241                   AdEspresso   2013-10-01         NaT               4
# 262                    Addvocate   2012-05-01         NaT               2
# 278                   Admittedly   2013-05-01         NaT               2
# 279                   Admittedly   2013-05-01         NaT               2
# 326    Agency of Trillions (AoT)   2013-01-01         NaT               4
# 466                   Allclasses   2013-01-01         NaT               2
# 467                   Allclasses   2013-01-01         NaT               2
# 641                     AppLovin   2012-03-01         NaT               2
# 645                     AppMyDay   2012-10-01         NaT               1
# 648                    AppSlingr   2013-01-01         NaT               1
# 649                    AppThwack   2012-03-29         NaT               2
# 650                    AppThwack   2012-03-29         NaT               2
# 665                      Appetas   2012-07-02         NaT               3
# 666                      Appetas   2012-07-02         NaT               3
# 667                      Appetas   2012-07-02         NaT               3
# ...                          ...          ...         ...             ...
# 9461                   WeDeliver   2013-01-08         NaT               1
# 9473                Wealthminder   2013-01-01         NaT               3
# 9490                Wedding Spot   2013-05-01         NaT               2
# 9499                      Welkio   2014-09-12         NaT               1
# 9527                       Wheel   2012-01-01         NaT               1
# 9607               Wise.io, Inc.   2012-05-21         NaT               4
# 9618                      Wit.ai   2013-10-31  2017-08-01               2
# 9621                   Wittlebee   2012-01-01         NaT               1
# 9675                    Worklife   2014-01-01         NaT               3
# 9676                    Worklife   2014-01-01         NaT               3
# 9677                    Worklife   2014-01-01         NaT               3
# 9702                      Wunwun   2013-09-01         NaT               2
# 9736                       Xendo   2013-08-13         NaT               1
# 9764                       Yarly   2012-11-01         NaT               1
# 9767                 Yellowsmith   2012-08-01         NaT               1
# 9771                    YesGraph   2012-01-01         NaT               3
# 9772                    YesGraph   2012-01-01         NaT               3
# 9773                    YesGraph   2012-01-01         NaT               3
# 9779                        Yhat   2013-06-01         NaT               3
# 9780                        Yhat   2013-06-01         NaT               3
# 9781                        Yhat   2013-06-01         NaT               3
# 9797                      Yonder   2013-01-01         NaT               1
# 9858                     Zaption   2012-01-01         NaT               1
# 9860                      Zarget   2015-02-18         NaT               2
# 10019                     bop.fm   2013-01-01  2015-11-01               3
# 10096                 harvest.ai   2014-09-01         NaT               3
# 10182                      nvite   2013-06-01         NaT               1
# 10189                    plug.dj   2012-02-01         NaT               1
# 10201                    room.me   2014-07-01         NaT               1
# 10277                      zurvu   2012-01-01         NaT               1
#
#       Last Funding Date Last Funding Amount Total Funding Amount  \
# 0            2012-06-30         $1,750,000           $1,750,000
# 97           2016-02-23           $650,000             $650,000
# 165          2013-12-25           $825,000             $825,000
# 166          2013-12-25           $825,000             $825,000
# 167          2014-07-11           $425,000             $875,000
# 168          2014-07-11           $425,000             $875,000
# 169          2014-07-11           $425,000             $875,000
# 170          2014-07-11           $425,000             $875,000
# 217          2013-01-07            $40,000              $40,000
# 224          2013-09-16         $3,000,000           $5,000,000
# 228          2014-08-31           $500,000           $1,465,000
# 229          2014-08-31           $500,000           $1,465,000
# 230          2014-08-31           $500,000           $1,465,000
# 231          2014-08-31           $500,000           $1,465,000
# 240          2016-05-06         $1,400,000           $3,200,000
# 241          2016-05-06         $1,400,000           $3,200,000
# 262          2013-07-24         $2,390,000           $2,729,000
# 278          2014-08-26         $1,200,000           $1,240,000
# 279          2014-08-26         $1,200,000           $1,240,000
# 326          2016-11-29           $500,000           $3,000,000
# 466          2014-05-06         $1,500,000           $1,750,000
# 467          2014-05-06         $1,500,000           $1,750,000
# 641          2014-07-31         $4,000,000           $4,020,000
# 645          2014-10-21           $900,000             $900,000
# 648          2013-07-10            $28,000              $28,000
# 649          2013-03-01           $600,000             $618,000
# 650          2013-03-01           $600,000             $618,000
# 665          2013-07-31            $50,000             $120,000
# 666          2013-07-31            $50,000             $120,000
# 667          2013-07-31            $50,000             $120,000
# ...                 ...                 ...                  ...
# 9461         2014-01-15           $800,000             $800,000
# 9473         2016-05-26           $425,000           $2,130,529
# 9490         2014-09-22         $3,000,000           $3,225,000
# 9499         2015-10-16           $400,000             $400,000
# 9527         2015-04-23         $2,000,000           $2,000,000
# 9607         2014-07-31           $965,000           $3,579,554
# 9618         2014-10-15         $3,000,000           $3,000,000
# 9621         2012-04-05         $2,500,000           $2,500,000
# 9675         2015-04-05         $1,700,000           $2,720,000
# 9676         2015-04-05         $1,700,000           $2,720,000
# 9677         2015-04-05         $1,700,000           $2,720,000
# 9702         2014-02-18        $16,000,000          $17,500,000
# 9736         2014-02-19            $28,000              $28,000
# 9764         2014-05-12            $25,000              $25,000
# 9767         2012-08-20           $850,000             $850,000
# 9771         2016-08-24           $120,000           $2,420,000
# 9772         2016-08-24           $120,000           $2,420,000
# 9773         2016-08-24           $120,000           $2,420,000
# 9779         2015-05-30         $1,500,000           $2,620,000
# 9780         2015-05-30         $1,500,000           $2,620,000
# 9781         2015-05-30         $1,500,000           $2,620,000
# 9797         2015-05-28         $2,000,000           $2,000,000
# 9858         2015-05-19         $1,500,000           $1,500,000
# 9860         2016-11-02         $6,000,000           $7,500,000
# 10019        2014-07-09         $2,000,000           $2,000,000
# 10096        2015-03-24         $2,300,000           $2,793,000
# 10182        2014-08-18         $1,000,000           $1,000,000
# 10189        2013-12-06         $1,250,000           $1,250,000
# 10201        2015-07-15         $1,100,000           $1,100,000
# 10277        2014-03-20         $1,200,000           $1,200,000
#
#              Status Funding Type Money Raised Announced On Date  \
# 0      Was Acquired         Seed  $1,750,000            6/30/12
# 97     Was Acquired         Seed    $650,000            2/23/16
# 165    Was Acquired         Seed    $825,000           12/25/13
# 166    Was Acquired         Seed    $825,000           12/25/13
# 167    Was Acquired         Seed    $425,000            7/11/14
# 168    Was Acquired         Seed    $225,000             4/6/14
# 169    Was Acquired         Seed    $100,000            1/30/14
# 170    Was Acquired         Seed     $25,000            7/30/13
# 217    Was Acquired         Seed     $40,000             1/7/13
# 224    Was Acquired         Seed  $2,000,000             3/1/12
# 228    Was Acquired         Seed    $500,000            8/31/14
# 229    Was Acquired         Seed    $435,000            5/16/13
# 230    Was Acquired         Seed    $345,000            9/30/13
# 231    Was Acquired         Seed    $185,000            4/15/13
# 240    Was Acquired         Seed  $1,300,000            6/24/14
# 241    Was Acquired         Seed    $500,000           12/25/13
# 262    Was Acquired         Seed    $339,000            5/15/13
# 278    Was Acquired         Seed  $1,200,000            8/26/14
# 279    Was Acquired         Seed     $40,000             6/3/13
# 326    Was Acquired         Seed  $1,000,000             1/1/13
# 466    Was Acquired         Seed  $1,500,000             5/6/14
# 467    Was Acquired         Seed    $250,000            4/18/14
# 641    Was Acquired         Seed  $4,000,000            7/31/14
# 645    Was Acquired         Seed    $900,000           10/21/14
# 648    Was Acquired         Seed     $28,000            7/10/13
# 649    Was Acquired         Seed    $600,000             3/1/13
# 166                        http://www.abakus.com
# 167                         http://abbeypost.com
# 168                         http://abbeypost.com
# 169                         http://abbeypost.com
# 170                         http://abbeypost.com
# 217                      http://acquaintable.com
# 224                           http://actionx.com
# 228    https://activate.bloglovin.com/dashboard/
# 229    https://activate.bloglovin.com/dashboard/
# 230    https://activate.bloglovin.com/dashboard/
# 231    https://activate.bloglovin.com/dashboard/
# 240                        http://adespresso.com
# 241                        http://adespresso.com
# 262                         http://addvocate.com
# 278                        http://admittedly.com
# 279                        http://admittedly.com
# 326                            http://www.aot.co
# 466                       http://allclasses.com/
# 467                       http://allclasses.com/
# 641                      http://www.applovin.com
# 645                      http://www.appmyday.com
# 648                     http://www.appslingr.com
# 649                        https://appthwack.com
# 650                        https://appthwack.com
# 665                       http://www.appetas.com
# 666                       http://www.appetas.com
# 667                       http://www.appetas.com
# ...                                          ...
# 9461                         http://wedeliver.us
# 9473                 http://www.wealthminder.com
# 9490                 http://www.wedding-spot.com
# 9499                         https://welkio.com/
# 9527                            http://ferris.tv
# 9607                              http://wise.io
# 9618                         https://www.wit.ai/
# 9621                        http://wittlebee.com
# 9675                    https://www.worklife.com
# 9676                    https://www.worklife.com
# 9677                    https://www.worklife.com
# 9702                           http://wunwun.com
# 9736                               http://xen.do
# 9764                             http://yarly.co
# 9767                  http://www.yellowsmith.com
# 9771                    https://www.yesgraph.com
# 9772                    https://www.yesgraph.com
# 9773                    https://www.yesgraph.com
# 9779                           http://yhathq.com
# 9780                           http://yhathq.com
# 9781                           http://yhathq.com
# 9797               http://www.yonder.it/#landing
# 9858                     http://www.zaption.com/
# 9860                       http://www.zarget.com
# 10019                          http://www.bop.fm
# 10096                         http://harvest.ai/
# 10182                           http://nvite.com
# 10189                            https://plug.dj
# 10201                             http://room.me
# 10277                     https://www.zurvu.com/
#
# [371 rows x 14 columns]

# %%
# # Build a scatter plot for each data type
# plt.scatter(seed_df["Funding Type"], 
#             seed_df["Status"],
#             s=100, edgecolor="black", linewidths=1, c="red", marker="o", 
#             alpha=0.8)

# # Incorporate the other graph properties
# plt.title("Seed Funding Type Status")
# plt.ylabel("Funding Type")
# plt.xlabel("Status")
# plt.grid(True)

# # Save the figure
# plt.savefig("Latitude_Temperature.png")

# # Show plot
# plt.show()

# %%
# #seed = merged_df[merged_df['Status'] == "Operating"]
# seed = merged_df[merged_df['Status'] == "Was Acquired"]
# seed = merged_df[merged_df['Status'] == "Closed"]
# seed = merged_df[merged_df['Status'] == "IPO"]

# # # x-axis
# seed_operating = seed.groupby(["Status"]).count()["Closed"]
# # #y-axis
# seed_acquired = seed.groupby(["Status"]).count()["Was Acquired"]

# # # x-axis
# seed_closedt = seed.groupby(["Status"]).count()["Closed"]
# # #y-axis
# seed_ips = seed.groupby(["Status"]).count()["IPO"]

# # # # x-axis
# # rural_ride_count = rural_cities.groupby(["city"]).count()["fare"]
# # # #y-axis
# # rural_driver_count = rural_cities.groupby(["city"]).mean()["driver_count"]

# # # # x-axis
# # suburban_ride_count = suburban_cities.groupby(["city"]).count()["fare"]
# # # #y-axis
# # suburban_driver_count = suburban_cities.groupby(["city"]).mean()["driver_count"]

# %%
funding_sum = merged_df.groupby('Funding Type')["Money Raised"].sum()
funding_sum.head(10)
# Out:
# Funding Type
# Seed        $1,750,000 $1,000,000 $1,500,000 $120,000 $120...
# Series A    $13,900,000 $3,000,000 $11,999,347 $4,000,000 ...
# Series B    $55,000,000 $20,000,000 $116,000,000 $30,000,0...
# Series C    $55,000,000 $21,500,000 $11,600,000 $30,000,00...
# Series D    $20,000,000 $29,500,000 $65,000,000 $100,000,0...
# Name: Money Raised, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

types_area = ["Seed", "Series A", "Series B", "Series C","Series D" ]
#numbers = [6030, 2864, 59, 1046, 279,]
numbers = funding_sum
colors = ["gold", "green", "lightskyblue", "blue", "red"]
explode = (0, 0.05, 0, 0, 0)

x_axis = np.arange(0, len(types_area))

ax.set_title("% Average Funding for Startups")
ax.pie(numbers, explode=explode, labels=types_area, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=90)
ax.axis("equal")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-94c30e2b4039> in <module>()
#      12 ax.set_title("% Average Funding for Startups")
#      13 ax.pie(numbers, explode=explode, labels=types_area, colors=colors,
# ---> 14        autopct="%1.1f%%", shadow=True, startangle=90)
#      15 ax.axis("equal")
#      16
#
# C:\Users\Chrisg\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Users\Chrisg\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame)
#    2570         """
#    2571
# -> 2572         x = np.asarray(x).astype(np.float32)
#    2573
#    2574         sx = float(x.sum())
#
# ValueError: could not convert string to float: '$20,000,000 $29,500,000 $65,000,000 $100,000,000 $100,000,000 $100,000,000 $12,000,000 $41,000,000 $41,000,000 $46,000,000 $130,000,000 $100,000,000 $30,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $75,000,000 $64,000,000 $100,000,000 $100,000,000 $140,000,000 $115,000,000 $41,000,000 $72,000,000 $125,000,000 $400,000,000 $10,000,000 $1,250,000 $52,500,000 $16,200,000 $105,000,000 $210,000,000 $33,500,000 $55,000,000 $40,000,000 $40,000,000 $10,000,000 $109,000,000 $109,000,000 $180,000,000 $100,000,000 $19,000,000 $30,000,000 $40,000,000 $16,300,000 $45,000,000 $32,500,000 $35,000,000 $20,000,000 '

# %%
funding_avg = merged_df.groupby('Funding Type')["Money Raised"].count()
funding_avg.head()
# Out:
# Funding Type
# Seed        6030
# Series A    2864
# Series B    1046
# Series C     279
# Series D      59
# Name: Money Raised, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

types_area = ["Seed", "Series A","Series D", "Series B", "Series C", ]
#numbers = [6030, 2864, 59, 1046, 279,]
numbers = funding_avg
colors = ["gold", "lightcoral", "lightskyblue", "blue", "red"]
explode = (0.05, 0, 0, 0, 0)

x_axis = np.arange(0, len(types_area))

ax.set_title("% Average Funding for Startups")
ax.pie(numbers, explode=explode, labels=types_area, colors=colors,
       autopct="%1.1f%%", shadow=True, startangle=45)
ax.axis("equal")

plt.show()

# %%
# funds_pd = fund_df.rename(columns={
#     "uuid": "UUID"   
# })

# funds_pd.head()
