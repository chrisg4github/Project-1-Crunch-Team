# %%
##Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import random as rd
np.random.seed(sum(map(ord, "aesthetics")))

# %%
## Read file and then sort 
csv_file = "companies.csv"
companies_df = pd.read_csv(csv_file, encoding="iso-8859-1",
                           parse_dates=["Founded Date","Closed Date","Last Funding Date"])
companies_df = companies_df.sort_values("Company Name").reset_index(drop=True)
print(len(companies_df.index))
companies_df.head(5)
# Out:
# 8664
#   Company Name                                   Company Name URL  \
# 0     #waywire    https://www.crunchbase.com/organization/waywire
# 1   *gram Labs  https://www.crunchbase.com/organization/gram-labs
# 2          .io  https://www.crunchbase.com/organization/io-rea...
# 3   /dev/color  https://www.crunchbase.com/organization/dev-color
# 4     10 By 10   https://www.crunchbase.com/organization/10-by-10
#
#                                      Category Groups  \
# 0  Media and Entertainment, Government and Milita...
# 1  Science and Engineering, Hardware, Data and An...
# 2                                 Data and Analytics
# 3                                                NaN
# 4                    Software, Professional Services
#
#                       Headquarters Location  \
# 0         New York, New York, United States
# 1         New York, New York, United States
# 2       Alexandria, Virginia, United States
# 3     Menlo Park, California, United States
# 4  San Francisco, California, United States
#
#                                          Description Crunchbase Rank  \
# 0  #waywire is an online community focused on soc...          21,987
# 1  GramLabs is a start up, leveraging deep learni...          11,897
# 2          .io is a real-time intelligence platform.          16,844
# 3  /dev/color is a non-profit organization that a...          35,003
# 4  10by10 builds a marketplace to more quickly ma...          59,822
#
#   Founded Date Closed Date  Number of Funding Rounds Last Funding Date  \
# 0   2012-06-01         NaT                         1        2012-06-30
# 1   2015-08-01         NaT                         1        2016-07-27
# 2   2015-03-01         NaT                         1        2015-10-01
# 3   2015-05-01         NaT                         1        2016-08-23
# 4   2015-01-01         NaT                         1        2017-07-01
#
#   Last Funding Amount Last Funding Type Total Funding Amount        Status
# 0         $1,750,000               Seed          $1,750,000   Was Acquired
# 1         $1,000,000               Seed          $1,000,000      Operating
# 2         $1,500,000               Seed          $1,500,000      Operating
# 3           $120,000               Seed            $120,000      Operating
# 4           $120,000               Seed            $120,000      Operating

# %%
companies_df.columns
# Out:
# Index(['Company Name', 'Company Name URL', 'Category Groups',
#        'Headquarters Location', 'Description', 'Crunchbase Rank',
#        'Founded Date', 'Closed Date', 'Number of Funding Rounds',
#        'Last Funding Date', 'Last Funding Amount', 'Last Funding Type',
#        'Total Funding Amount', 'Status'],
#       dtype='object')

# %%
companies_df = companies_df[["Company Name", "Founded Date", "Closed Date", "Number of Funding Rounds", "Last Funding Date", "Last Funding Amount", "Total Funding Amount", "Status"]]
companies_df.head()
# Out:
#   Company Name Founded Date Closed Date  Number of Funding Rounds  \
# 0     #waywire   2012-06-01         NaT                         1
# 1   *gram Labs   2015-08-01         NaT                         1
# 2          .io   2015-03-01         NaT                         1
# 3   /dev/color   2015-05-01         NaT                         1
# 4     10 By 10   2015-01-01         NaT                         1
#
#   Last Funding Date Last Funding Amount Total Funding Amount        Status
# 0        2012-06-30         $1,750,000           $1,750,000   Was Acquired
# 1        2016-07-27         $1,000,000           $1,000,000      Operating
# 2        2015-10-01         $1,500,000           $1,500,000      Operating
# 3        2016-08-23           $120,000             $120,000      Operating
# 4        2017-07-01           $120,000             $120,000      Operating

# %%
companies_pf = companies_df.rename(columns={
    "Company Name" : "Company",
    "Number of Funding Rounds" : "Funding Rounds"   
})

companies_pf.head()
# Out:
#       Company Founded Date Closed Date  Funding Rounds Last Funding Date  \
# 0    #waywire   2012-06-01         NaT               1        2012-06-30
# 1  *gram Labs   2015-08-01         NaT               1        2016-07-27
# 2         .io   2015-03-01         NaT               1        2015-10-01
# 3  /dev/color   2015-05-01         NaT               1        2016-08-23
# 4    10 By 10   2015-01-01         NaT               1        2017-07-01
#
#   Last Funding Amount Total Funding Amount        Status
# 0         $1,750,000           $1,750,000   Was Acquired
# 1         $1,000,000           $1,000,000      Operating
# 2         $1,500,000           $1,500,000      Operating
# 3           $120,000             $120,000      Operating
# 4           $120,000             $120,000      Operating

# %%
## Read file and then sort 
funding = "Funding_Rounds.csv"
funding_df = pd.read_csv(funding, encoding="iso-8859-1")
funding_df.head(5)
# Out:
#   Company Name                                   Company Name URL  \
# 0    TestMetal  https://www.crunchbase.com/organization/testmetal
# 1   WinApp Inc  https://www.crunchbase.com/organization/winapp...
# 2       Cambly     https://www.crunchbase.com/organization/cambly
# 3       Goboxi     https://www.crunchbase.com/organization/goboxi
# 4     KaChing!  https://www.crunchbase.com/organization/kachin...
#
#   Funding Type Money Raised Announced On Date
# 0     Series A      690,000           7/10/15
# 1         Seed    2,000,000          10/30/15
# 2         Seed  $7,000,000             9/1/16
# 3         Seed  $3,000,000            12/6/13
# 4         Seed   30,000,000           2/24/17

# %%
funding_df = funding_df[["Company Name", "Funding Type", "Money Raised", "Announced On Date"]]
funding_df.head()
# Out:
#   Company Name Funding Type Money Raised Announced On Date
# 0    TestMetal     Series A      690,000           7/10/15
# 1   WinApp Inc         Seed    2,000,000          10/30/15
# 2       Cambly         Seed  $7,000,000             9/1/16
# 3       Goboxi         Seed  $3,000,000            12/6/13
# 4     KaChing!         Seed   30,000,000           2/24/17

# %%
funding_pf = funding_df.rename(columns={
    "Company Name" : "Company"
})

funding_pf.head()
# Out:
#       Company Funding Type Money Raised Announced On Date
# 0   TestMetal     Series A      690,000           7/10/15
# 1  WinApp Inc         Seed    2,000,000          10/30/15
# 2      Cambly         Seed  $7,000,000             9/1/16
# 3      Goboxi         Seed  $3,000,000            12/6/13
# 4    KaChing!         Seed   30,000,000           2/24/17

# %%
merged_data = pd.merge(companies_pf, funding_pf,how="inner",on="Company")
merged_data.head(50)
# Out:
#                     Company Founded Date Closed Date  Funding Rounds  \
# 0                  #waywire   2012-06-01         NaT               1
# 1                *gram Labs   2015-08-01         NaT               1
# 2                       .io   2015-03-01         NaT               1
# 3                /dev/color   2015-05-01         NaT               1
# 4                  10 By 10   2015-01-01         NaT               1
# 5              10-4 Systems   2012-01-01         NaT               1
# 6              10X Genomics   2012-01-01         NaT               3
# 7              10X Genomics   2012-01-01         NaT               3
# 8              10X Genomics   2012-01-01         NaT               3
# 9                     10sec   2013-07-08         NaT               2
# 10                  12 Labs   2014-08-01         NaT               1
# 11               121 Mobile   2012-02-17         NaT               4
# 12           128 Technology   2014-07-07         NaT               4
# 13           128 Technology   2014-07-07         NaT               4
# 14           128 Technology   2014-07-07         NaT               4
# 15           128 Technology   2014-07-07         NaT               4
# 16                   17hats   2014-01-01         NaT               2
# 17                   17hats   2014-01-01         NaT               2
# 18                 18Angles   2015-01-01         NaT               1
# 19                   19Labs   2015-01-01         NaT               1
# 20             1CommMedical   2013-01-01         NaT               1
# 21                  1Huddle   2015-01-01         NaT               2
# 22                  1Huddle   2015-01-01         NaT               2
# 23                     1UPd   2015-08-12         NaT               1
# 24   2020 On-site Optometry   2013-11-01         NaT               3
# 25   2020 On-site Optometry   2013-11-01         NaT               3
# 26                      20n   2013-01-01         NaT               2
# 27                      20n   2013-01-01         NaT               2
# 28                   21 Inc   2013-05-01         NaT               2
# 29                   21 Inc   2013-05-01         NaT               2
# 30                   23VIVI   2015-12-22         NaT               1
# 31                 27 Perry   2012-01-01  2013-01-01               1
# 32               2Hat Media   2012-01-01         NaT               1
# 33                2ULaundry   2015-12-01         NaT               1
# 34       30 Second Showcase   2013-04-01         NaT               1
# 35                  37coins   2014-01-01         NaT               2
# 36                  37coins   2014-01-01         NaT               2
# 37      3D Operations, Inc.   2014-01-01         NaT               1
# 38                3D-SensIR   2016-01-01         NaT               1
# 39            3Derm Systems   2012-01-01         NaT               5
# 40                3Diligent   2014-07-23         NaT               2
# 41             3MayDay Inc.   2013-02-08         NaT               2
# 42             3MayDay Inc.   2013-02-08         NaT               2
# 43                    3TEN8   2013-08-15         NaT               1
# 44                  3blades   2015-09-01         NaT               1
# 45              410 Medical   2013-01-01         NaT               3
# 46              410 Medical   2013-01-01         NaT               3
# 47                   44LAB5   2015-01-05         NaT               1
# 48  46 Degrees Technologies   2015-09-30         NaT               1
# 49            4D Healthware   2012-01-01         NaT               2
#
#    Last Funding Date Last Funding Amount Total Funding Amount        Status  \
# 0         2012-06-30         $1,750,000           $1,750,000   Was Acquired
# 1         2016-07-27         $1,000,000           $1,000,000      Operating
# 2         2015-10-01         $1,500,000           $1,500,000      Operating
# 3         2016-08-23           $120,000             $120,000      Operating
# 4         2017-07-01           $120,000             $120,000      Operating
# 5         2016-06-27        $13,900,000          $13,900,000      Operating
# 6         2016-03-17        $55,000,000         $113,000,000      Operating
# 7         2016-03-17        $55,000,000         $113,000,000      Operating
# 8         2016-03-17        $55,000,000         $113,000,000      Operating
# 9         2014-05-08         $1,600,000           $1,600,000      Operating
# 10        2014-11-26           $935,000             $935,000      Operating
# 11        2015-12-18         $2,200,000           $4,000,000      Operating
# 12        2017-05-31        $21,500,000          $57,499,347      Operating
# 13        2017-05-31        $21,500,000          $57,499,347      Operating
# 14        2017-05-31        $21,500,000          $57,499,347      Operating
# 15        2017-05-31        $21,500,000          $57,499,347      Operating
# 16        2015-10-15         $4,000,000           $5,250,000      Operating
# 17        2015-10-15         $4,000,000           $5,250,000      Operating
# 18        2016-02-01           $500,000             $500,000      Operating
# 19        2016-09-01           $680,000             $680,000      Operating
# 20        2015-04-27         $2,500,000           $2,500,000      Operating
# 21        2017-03-15           $500,000             $625,000      Operating
# 22        2017-03-15           $500,000             $625,000      Operating
# 23        2015-09-09            $30,000              $30,000      Operating
# 24        2016-07-11         $3,000,000           $7,714,965      Operating
# 25        2016-07-11         $3,000,000           $7,714,965      Operating
# 26        2015-05-01         $2,100,000           $2,220,000      Operating
# 27        2015-05-01         $2,100,000           $2,220,000      Operating
# 28        2015-03-10       $116,000,000         $121,050,000      Operating
# 29        2015-03-10       $116,000,000         $121,050,000      Operating
# 30        2016-02-12            $20,000              $20,000      Operating
# 31        2012-05-17           $118,000             $118,000         Closed
# 32        2013-01-01           $150,000             $150,000      Operating
# 33        2016-11-14           $400,000             $400,000      Operating
# 34        2013-05-20            $25,000              $25,000      Operating
# 35        2014-06-01           $500,000             $525,000      Operating
# 36        2014-06-01           $500,000             $525,000      Operating
# 37        2014-05-15             $7,500               $7,500      Operating
# 38        2016-09-26            $75,000              $75,000      Operating
# 39        2016-07-27         $1,655,709           $3,535,709      Operating
# 40        2015-03-15           $900,000           $1,150,000      Operating
# 41        2017-03-21            $80,000             $230,000      Operating
# 42        2017-03-21            $80,000             $230,000      Operating
# 43        2015-04-15         $1,670,000           $1,670,000      Operating
# 44        2015-05-10           $100,000             $100,000      Operating
# 45        2017-06-21         $2,100,000           $7,574,993      Operating
# 46        2017-06-21         $2,100,000           $7,574,993      Operating
# 47        2015-05-31           $450,000             $450,000      Operating
# 48        2016-04-20         $2,000,000           $2,000,000      Operating
# 49        2017-02-27           $800,000           $1,500,000      Operating
#
#    Funding Type   Money Raised Announced On Date
# 0          Seed    $1,750,000            6/30/12
# 1          Seed    $1,000,000            7/27/16
# 2          Seed    $1,500,000            10/1/15
# 3          Seed      $120,000            8/23/16
# 4          Seed      $120,000             7/1/17
# 5      Series A   $13,900,000            6/27/16
# 6      Series C   $55,000,000            3/17/16
# 7      Series B   $55,000,000            1/12/15
# 8      Series A    $3,000,000            10/8/12
# 9          Seed    $1,600,000             5/8/14
# 10         Seed      $935,000           11/26/14
# 11         Seed    $2,200,000           12/18/15
# 12     Series C   $21,500,000            5/31/17
# 13     Series B   $20,000,000            12/8/15
# 14     Series A   $11,999,347            12/4/14
# 15         Seed    $4,000,000             7/7/14
# 16     Series A    $4,000,000           10/15/15
# 17         Seed    $1,250,000            2/18/15
# 18         Seed      $500,000             2/1/16
# 19         Seed      $680,000             9/1/16
# 20     Series A    $2,500,000            4/27/15
# 21         Seed      $500,000            3/15/17
# 22         Seed      $125,000           10/20/15
# 23         Seed       $30,000             9/9/15
# 24     Series A    $3,499,965             6/1/15
# 25     Series A    $3,000,000            7/11/16
# 26         Seed    $2,100,000             5/1/15
# 27         Seed      $120,000            12/1/14
# 28     Series B  $116,000,000            3/10/15
# 29     Series A    $5,050,000           11/17/13
# 30         Seed       $20,000            2/12/16
# 31         Seed      $118,000            5/17/12
# 32         Seed      $150,000             1/1/13
# 33         Seed      $400,000           11/14/16
# 34         Seed       $25,000            5/20/13
# 35         Seed      $500,000             6/1/14
# 36         Seed       $25,000            3/15/14
# 37         Seed        $7,500            5/15/14
# 38         Seed       $75,000            9/26/16
# 39     Series A    $1,655,709            7/27/16
# 40         Seed      $900,000            3/15/15
# 41         Seed      $150,000           11/16/13
# 42         Seed       $80,000            3/21/17
# 43         Seed    $1,670,000            4/15/15
# 44         Seed      $100,000            5/10/15
# 45     Series A    $3,274,993            3/23/17
# 46     Series A    $2,100,000            6/21/17
# 47         Seed      $450,000            5/31/15
# 48         Seed    $2,000,000            4/20/16
# 49         Seed      $800,000            2/27/17

# %%
## Read file and then sort 
org = "organizations.csv"
org_df = pd.read_csv(org, encoding="iso-8859-1")
org_df.head(5)
# Out:
#                         crunchbase_uuid          type primary_role  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Organization      company
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7  Organization      company
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0  Organization      company
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Organization     investor
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb  Organization      company
#
#               name                                     crunchbase_url  \
# 0         Wetpaint  https://www.crunchbase.com/organization/wetpai...
# 1             Zoho  https://www.crunchbase.com/organization/zoho?u...
# 2             Digg  https://www.crunchbase.com/organization/digg?u...
# 3  Omidyar Network  https://www.crunchbase.com/organization/omidya...
# 4         Facebook  https://www.crunchbase.com/organization/facebo...
#
#   homepage_domain              homepage_url  \
# 0    wetpaint.com  http://www.wetpaint.com/
# 1        zoho.com     https://www.zoho.com/
# 2        digg.com       http://www.digg.com
# 3     omidyar.com    http://www.omidyar.com
# 4    facebook.com   http://www.facebook.com
#
#                                    profile_image_url  \
# 0  https://www.crunchbase.com/organization/wetpai...
# 1  https://www.crunchbase.com/organization/zoho/p...
# 2  https://www.crunchbase.com/organization/digg/p...
# 3  https://www.crunchbase.com/organization/omidya...
# 4  https://www.crunchbase.com/organization/facebo...
#
#                              facebook_url                        twitter_url  \
# 0       https://www.facebook.com/Wetpaint     https://twitter.com/wetpainttv
# 1            http://www.facebook.com/zoho            http://twitter.com/zoho
# 2            http://www.facebook.com/digg            http://twitter.com/digg
# 3  http://www.facebook.com/OmidyarNetwork  http://twitter.com/OmidyarNetwork
# 4      https://www.facebook.com/facebook/       https://twitter.com/facebook
#
#                                         linkedin_url stock_symbol  \
# 0          https://www.linkedin.com/company/wetpaint            :
# 1  http://www.linkedin.com/company/zoho-corporati...            :
# 2               http://www.linkedin.com/company/digg            :
# 3              http://www.linkedin.com/company/22806            :
# 4           http://www.linkedin.com/company/facebook    NASDAQ:FB
#
#   location_city location_region location_country_code  \
# 0      New York        New York                   USA
# 1    Pleasanton      California                   USA
# 2      New York        New York                   USA
# 3  Redwood City      California                   USA
# 4    Menlo Park      California                   USA
#
#                                    short_description
# 0  Wetpaint offers an online social publishing pl...
# 1  Zoho offers a suite of business, collaboration...
# 2  Digg Inc. operates a website that enables its ...
# 3             Omidyar Network is an investment firm.
# 4  Facebook is an online social networking servic...

# %%
# Rename columns for readability
new_file = org_df.rename(columns={
    "crunchbase_uuid": "UUID",
    "name" : "Company",
    "homepage_url" : "Homepage"   
})

new_file.head()
# Out:
#                                    UUID          type primary_role  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Organization      company
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7  Organization      company
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0  Organization      company
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Organization     investor
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb  Organization      company
#
#            Company                                     crunchbase_url  \
# 0         Wetpaint  https://www.crunchbase.com/organization/wetpai...
# 1             Zoho  https://www.crunchbase.com/organization/zoho?u...
# 2             Digg  https://www.crunchbase.com/organization/digg?u...
# 3  Omidyar Network  https://www.crunchbase.com/organization/omidya...
# 4         Facebook  https://www.crunchbase.com/organization/facebo...
#
#   homepage_domain                  Homepage  \
# 0    wetpaint.com  http://www.wetpaint.com/
# 1        zoho.com     https://www.zoho.com/
# 2        digg.com       http://www.digg.com
# 3     omidyar.com    http://www.omidyar.com
# 4    facebook.com   http://www.facebook.com
#
#                                    profile_image_url  \
# 0  https://www.crunchbase.com/organization/wetpai...
# 1  https://www.crunchbase.com/organization/zoho/p...
# 2  https://www.crunchbase.com/organization/digg/p...
# 3  https://www.crunchbase.com/organization/omidya...
# 4  https://www.crunchbase.com/organization/facebo...
#
#                              facebook_url                        twitter_url  \
# 0       https://www.facebook.com/Wetpaint     https://twitter.com/wetpainttv
# 1            http://www.facebook.com/zoho            http://twitter.com/zoho
# 2            http://www.facebook.com/digg            http://twitter.com/digg
# 3  http://www.facebook.com/OmidyarNetwork  http://twitter.com/OmidyarNetwork
# 4      https://www.facebook.com/facebook/       https://twitter.com/facebook
#
#                                         linkedin_url stock_symbol  \
# 0          https://www.linkedin.com/company/wetpaint            :
# 1  http://www.linkedin.com/company/zoho-corporati...            :
# 2               http://www.linkedin.com/company/digg            :
# 3              http://www.linkedin.com/company/22806            :
# 4           http://www.linkedin.com/company/facebook    NASDAQ:FB
#
#   location_city location_region location_country_code  \
# 0      New York        New York                   USA
# 1    Pleasanton      California                   USA
# 2      New York        New York                   USA
# 3  Redwood City      California                   USA
# 4    Menlo Park      California                   USA
#
#                                    short_description
# 0  Wetpaint offers an online social publishing pl...
# 1  Zoho offers a suite of business, collaboration...
# 2  Digg Inc. operates a website that enables its ...
# 3             Omidyar Network is an investment firm.
# 4  Facebook is an online social networking servic...

# %%
new_file = new_file[["UUID", "Company", "Homepage"]]
new_file.head()
# Out:
#                                    UUID          Company  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb         Facebook
#
#                    Homepage
# 0  http://www.wetpaint.com/
# 1     https://www.zoho.com/
# 2       http://www.digg.com
# 3    http://www.omidyar.com
# 4   http://www.facebook.com

# %%
new_file.to_csv("Org_Output.csv")

# %%
merged_df = pd.merge(merged_data, new_file,how="inner",on="Company")
merged_df.head()
# Out:
#       Company Founded Date Closed Date  Funding Rounds Last Funding Date  \
# 0    #waywire   2012-06-01         NaT               1        2012-06-30
# 1  *gram Labs   2015-08-01         NaT               1        2016-07-27
# 2         .io   2015-03-01         NaT               1        2015-10-01
# 3  /dev/color   2015-05-01         NaT               1        2016-08-23
# 4    10 By 10   2015-01-01         NaT               1        2017-07-01
#
#   Last Funding Amount Total Funding Amount        Status Funding Type  \
# 0         $1,750,000           $1,750,000   Was Acquired         Seed
# 1         $1,000,000           $1,000,000      Operating         Seed
# 2         $1,500,000           $1,500,000      Operating         Seed
# 3           $120,000             $120,000      Operating         Seed
# 4           $120,000             $120,000      Operating         Seed
#
#   Money Raised Announced On Date                                  UUID  \
# 0  $1,750,000            6/30/12  3ca06819-3ca9-ce42-ce20-f0e150d563a0
# 1  $1,000,000            7/27/16  18e8dd5e-fe1d-5f8e-f2ed-b254171d7f5d
# 2  $1,500,000            10/1/15  cf169e68-c903-c089-8789-bdd557d6a4c1
# 3    $120,000            8/23/16  165f412c-361d-7931-fd3b-cf5e2a1ccef3
# 4    $120,000             7/1/17  e1670a30-4ff5-893d-0ae3-ceb761e1c251
#
#                    Homepage
# 0    http://www.waywire.com
# 1    http://www.gramlabs.ai
# 2          https://onthe.io
# 3  http://www.devcolor.org/
# 4    https://www.10by10.io/

# %%
# didn't work
# merged_pf = merged_df["UUID"].replace("-", "")
# merged_pf.head()

# %%
# didn't work
# merged_df["UUID"].replace("-", "", inplace=True)

# %%
# didn't work BUT replaces dashes but doesn't replace the value
# merged_df['UUID'].apply(lambda x: x.replace("-", ""))
# print('done')

# %%
# works
for i, el in enumerate(merged_df.iterrows()):
    val = el[1]['UUID'].replace("-", "")
    merged_df.set_value(i, "UUID", val)

# %%
# check if dashes are gone in UUID column
merged_df.head()['UUID']
# Out:
# 0    3ca068193ca9ce42ce20f0e150d563a0
# 1    18e8dd5efe1d5f8ef2edb254171d7f5d
# 2    cf169e68c903c0898789bdd557d6a4c1
# 3    165f412c361d7931fd3bcf5e2a1ccef3
# 4    e1670a304ff5893d0ae3ceb761e1c251
# Name: UUID, dtype: object

# %%
merged_df.head(50)
# Out:
#                     Company Founded Date Closed Date  Funding Rounds  \
# 0                  #waywire   2012-06-01         NaT               1
# 1                *gram Labs   2015-08-01         NaT               1
# 2                       .io   2015-03-01         NaT               1
# 3                /dev/color   2015-05-01         NaT               1
# 4                  10 By 10   2015-01-01         NaT               1
# 5              10-4 Systems   2012-01-01         NaT               1
# 6              10X Genomics   2012-01-01         NaT               3
# 7              10X Genomics   2012-01-01         NaT               3
# 8              10X Genomics   2012-01-01         NaT               3
# 9                     10sec   2013-07-08         NaT               2
# 10                  12 Labs   2014-08-01         NaT               1
# 11               121 Mobile   2012-02-17         NaT               4
# 12           128 Technology   2014-07-07         NaT               4
# 13           128 Technology   2014-07-07         NaT               4
# 14           128 Technology   2014-07-07         NaT               4
# 15           128 Technology   2014-07-07         NaT               4
# 16                   17hats   2014-01-01         NaT               2
# 17                   17hats   2014-01-01         NaT               2
# 18                 18Angles   2015-01-01         NaT               1
# 19                   19Labs   2015-01-01         NaT               1
# 20             1CommMedical   2013-01-01         NaT               1
# 21                  1Huddle   2015-01-01         NaT               2
# 22                  1Huddle   2015-01-01         NaT               2
# 23                     1UPd   2015-08-12         NaT               1
# 24   2020 On-site Optometry   2013-11-01         NaT               3
# 25   2020 On-site Optometry   2013-11-01         NaT               3
# 26                      20n   2013-01-01         NaT               2
# 27                      20n   2013-01-01         NaT               2
# 28                   21 Inc   2013-05-01         NaT               2
# 29                   21 Inc   2013-05-01         NaT               2
# 30                   23VIVI   2015-12-22         NaT               1
# 31                 27 Perry   2012-01-01  2013-01-01               1
# 32               2Hat Media   2012-01-01         NaT               1
# 33                2ULaundry   2015-12-01         NaT               1
# 34       30 Second Showcase   2013-04-01         NaT               1
# 35                  37coins   2014-01-01         NaT               2
# 36                  37coins   2014-01-01         NaT               2
# 37      3D Operations, Inc.   2014-01-01         NaT               1
# 38                3D-SensIR   2016-01-01         NaT               1
# 39            3Derm Systems   2012-01-01         NaT               5
# 40                3Diligent   2014-07-23         NaT               2
# 41             3MayDay Inc.   2013-02-08         NaT               2
# 42             3MayDay Inc.   2013-02-08         NaT               2
# 43                    3TEN8   2013-08-15         NaT               1
# 44                  3blades   2015-09-01         NaT               1
# 45              410 Medical   2013-01-01         NaT               3
# 46              410 Medical   2013-01-01         NaT               3
# 47                   44LAB5   2015-01-05         NaT               1
# 48  46 Degrees Technologies   2015-09-30         NaT               1
# 49            4D Healthware   2012-01-01         NaT               2
#
#    Last Funding Date Last Funding Amount Total Funding Amount        Status  \
# 0         2012-06-30         $1,750,000           $1,750,000   Was Acquired
# 1         2016-07-27         $1,000,000           $1,000,000      Operating
# 2         2015-10-01         $1,500,000           $1,500,000      Operating
# 3         2016-08-23           $120,000             $120,000      Operating
# 4         2017-07-01           $120,000             $120,000      Operating
# 5         2016-06-27        $13,900,000          $13,900,000      Operating
# 6         2016-03-17        $55,000,000         $113,000,000      Operating
# 7         2016-03-17        $55,000,000         $113,000,000      Operating
# 8         2016-03-17        $55,000,000         $113,000,000      Operating
# 9         2014-05-08         $1,600,000           $1,600,000      Operating
# 10        2014-11-26           $935,000             $935,000      Operating
# 11        2015-12-18         $2,200,000           $4,000,000      Operating
# 12        2017-05-31        $21,500,000          $57,499,347      Operating
# 13        2017-05-31        $21,500,000          $57,499,347      Operating
# 14        2017-05-31        $21,500,000          $57,499,347      Operating
# 15        2017-05-31        $21,500,000          $57,499,347      Operating
# 16        2015-10-15         $4,000,000           $5,250,000      Operating
# 17        2015-10-15         $4,000,000           $5,250,000      Operating
# 18        2016-02-01           $500,000             $500,000      Operating
# 19        2016-09-01           $680,000             $680,000      Operating
# 20        2015-04-27         $2,500,000           $2,500,000      Operating
# 21        2017-03-15           $500,000             $625,000      Operating
# 22        2017-03-15           $500,000             $625,000      Operating
# 23        2015-09-09            $30,000              $30,000      Operating
# 24        2016-07-11         $3,000,000           $7,714,965      Operating
# 25        2016-07-11         $3,000,000           $7,714,965      Operating
# 26        2015-05-01         $2,100,000           $2,220,000      Operating
# 27        2015-05-01         $2,100,000           $2,220,000      Operating
# 28        2015-03-10       $116,000,000         $121,050,000      Operating
# 29        2015-03-10       $116,000,000         $121,050,000      Operating
# 30        2016-02-12            $20,000              $20,000      Operating
# 31        2012-05-17           $118,000             $118,000         Closed
# 32        2013-01-01           $150,000             $150,000      Operating
# 33        2016-11-14           $400,000             $400,000      Operating
# 34        2013-05-20            $25,000              $25,000      Operating
# 35        2014-06-01           $500,000             $525,000      Operating
# 36        2014-06-01           $500,000             $525,000      Operating
# 37        2014-05-15             $7,500               $7,500      Operating
# 38        2016-09-26            $75,000              $75,000      Operating
# 39        2016-07-27         $1,655,709           $3,535,709      Operating
# 40        2015-03-15           $900,000           $1,150,000      Operating
# 41        2017-03-21            $80,000             $230,000      Operating
# 42        2017-03-21            $80,000             $230,000      Operating
# 43        2015-04-15         $1,670,000           $1,670,000      Operating
# 44        2015-05-10           $100,000             $100,000      Operating
# 45        2017-06-21         $2,100,000           $7,574,993      Operating
# 46        2017-06-21         $2,100,000           $7,574,993      Operating
# 47        2015-05-31           $450,000             $450,000      Operating
# 48        2016-04-20         $2,000,000           $2,000,000      Operating
# 49        2017-02-27           $800,000           $1,500,000      Operating
#
#    Funding Type   Money Raised Announced On Date  \
# 0          Seed    $1,750,000            6/30/12
# 1          Seed    $1,000,000            7/27/16
# 2          Seed    $1,500,000            10/1/15
# 3          Seed      $120,000            8/23/16
# 4          Seed      $120,000             7/1/17
# 5      Series A   $13,900,000            6/27/16
# 6      Series C   $55,000,000            3/17/16
# 7      Series B   $55,000,000            1/12/15
# 8      Series A    $3,000,000            10/8/12
# 9          Seed    $1,600,000             5/8/14
# 10         Seed      $935,000           11/26/14
# 11         Seed    $2,200,000           12/18/15
# 12     Series C   $21,500,000            5/31/17
# 13     Series B   $20,000,000            12/8/15
# 14     Series A   $11,999,347            12/4/14
# 15         Seed    $4,000,000             7/7/14
# 16     Series A    $4,000,000           10/15/15
# 17         Seed    $1,250,000            2/18/15
# 18         Seed      $500,000             2/1/16
# 19         Seed      $680,000             9/1/16
# 20     Series A    $2,500,000            4/27/15
# 21         Seed      $500,000            3/15/17
# 22         Seed      $125,000           10/20/15
# 23         Seed       $30,000             9/9/15
# 24     Series A    $3,499,965             6/1/15
# 25     Series A    $3,000,000            7/11/16
# 26         Seed    $2,100,000             5/1/15
# 27         Seed      $120,000            12/1/14
# 28     Series B  $116,000,000            3/10/15
# 29     Series A    $5,050,000           11/17/13
# 30         Seed       $20,000            2/12/16
# 31         Seed      $118,000            5/17/12
# 32         Seed      $150,000             1/1/13
# 33         Seed      $400,000           11/14/16
# 34         Seed       $25,000            5/20/13
# 35         Seed      $500,000             6/1/14
# 36         Seed       $25,000            3/15/14
# 37         Seed        $7,500            5/15/14
# 38         Seed       $75,000            9/26/16
# 39     Series A    $1,655,709            7/27/16
# 40         Seed      $900,000            3/15/15
# 41         Seed      $150,000           11/16/13
# 42         Seed       $80,000            3/21/17
# 43         Seed    $1,670,000            4/15/15
# 44         Seed      $100,000            5/10/15
# 45     Series A    $3,274,993            3/23/17
# 46     Series A    $2,100,000            6/21/17
# 47         Seed      $450,000            5/31/15
# 48         Seed    $2,000,000            4/20/16
# 49         Seed      $800,000            2/27/17
#
#                                 UUID                         Homepage
# 0   3ca068193ca9ce42ce20f0e150d563a0           http://www.waywire.com
# 1   18e8dd5efe1d5f8ef2edb254171d7f5d           http://www.gramlabs.ai
# 2   cf169e68c903c0898789bdd557d6a4c1                 https://onthe.io
# 3   165f412c361d7931fd3bcf5e2a1ccef3         http://www.devcolor.org/
# 4   e1670a304ff5893d0ae3ceb761e1c251           https://www.10by10.io/
# 5   35ca612cf370d2dfe3db63554192f84a            https://www.10-4.com/
# 6   cf3b00cfffbf0e4f6427a60e5060de39           http://10xgenomics.com
# 7   cf3b00cfffbf0e4f6427a60e5060de39           http://10xgenomics.com
# 8   cf3b00cfffbf0e4f6427a60e5060de39           http://10xgenomics.com
# 9   79fd01f688736282a9ea27622d0bbdcb                  https://10s.ec/
# 10  74a66ef358d3adec5740ae7794dd6dbd      http://www.getapplause.com/
# 11  8d43a7efac3c3977c8d7b62377f1d97a           http://my121mobile.com
# 12  b87dd21c6fbd9c7d43ee3ce97387825e   https://www.128technology.com/
# 13  b87dd21c6fbd9c7d43ee3ce97387825e   https://www.128technology.com/
# 14  b87dd21c6fbd9c7d43ee3ce97387825e   https://www.128technology.com/
# 15  b87dd21c6fbd9c7d43ee3ce97387825e   https://www.128technology.com/
# 16  c852c5d3220d2eb6c78e3c9148430ce4           https://www.17hats.com
# 17  c852c5d3220d2eb6c78e3c9148430ce4           https://www.17hats.com
# 18  124f67d66ab7c706a057d195462e1f87         http://www.18angles.com/
# 19  e2eb4ab910be49f5db644973cc8cb1c3           http://www.19labs.com/
# 20  e794e5f90781eca17e6dc48cdbb89911          http://1commmedical.com
# 21  51e4aae56ad5e054317b7428bffd0870            http://www.1huddle.co
# 22  51e4aae56ad5e054317b7428bffd0870            http://www.1huddle.co
# 23  635991c8bbf873f5e5f99e38bb15f97d           http://www.get1upd.com
# 24  dfc582c6a7ebb0e0a41d62ab94579c73        http://www.2020onsite.com
# 25  dfc582c6a7ebb0e0a41d62ab94579c73        http://www.2020onsite.com
# 26  8f609f34526bf914440a129286c65eef                  http://20n.com/
# 27  8f609f34526bf914440a129286c65eef                  http://20n.com/
# 28  12e72873b63e349fe24b21ad5ad87d47                    https://21.co
# 29  12e72873b63e349fe24b21ad5ad87d47                    https://21.co
# 30  483e69e4de8fb03e1a7b646cd22ab457                http://23vivi.com
# 31  40d8d076df13484162029389201bb1fa           http://www.27perry.com
# 32  f64ffcc2841edb86586e5be472d4ab8c               http://linktub.com
# 33  06585e6725d08d490d93aa6b0a435f86       https://www.2ulaundry.com/
# 34  75495189f525d47eb02ddb83723208f6  http://www.30secondshowcase.com
# 35  7229e2a245595b08ec0c16361b7e80da           http://www.37coins.com
# 36  7229e2a245595b08ec0c16361b7e80da           http://www.37coins.com
# 37  7b9f9d184cd9f8aeea487c69be0d8254              http://www.3dops.co
# 38  f8568bc0ef233c367d2abbf83763aafd        http://www.3d-sensir.com/
# 39  a254a1efa338f962a4887d8270d205c3                 http://3derm.com
# 40  499ac893025aa72429fe6dcd65cd830f         http://www.3diligent.com
# 41  a475e1ef4a5125ce749d09a8bd4b3302           http://www.3mayday.com
# 42  a475e1ef4a5125ce749d09a8bd4b3302           http://www.3mayday.com
# 43  2e4eea40ec8ef51e53f1738ea28afb47            http://www.3ten8.com/
# 44  3cd81f93bfedda6704328c67eeb0e52b           https://www.3blades.io
# 45  0fa81e3222ea0995da52f0cffd0f9e65           http://410medical.com/
# 46  0fa81e3222ea0995da52f0cffd0f9e65           http://410medical.com/
# 47  8309fd71c274096ff5f9618d3d083e0d                http://44lab5.com
# 48  35913f7231b2cea5048114477d831818        http://www.46degrees.net/
# 49  7c5c85fcd5e9c5f447ef6caf3e4e3bfe         http://4dhealthware.com/

# %%
merged_df.dtypes
# Out:
# Company Name                        object
# Company Name URL                    object
# Category Groups                     object
# Headquarters Location               object
# Description                         object
# Crunchbase Rank                     object
# Founded Date                datetime64[ns]
# Closed Date                 datetime64[ns]
# Number of Funding Rounds             int64
# Last Funding Date           datetime64[ns]
# Last Funding Amount                 object
# Last Funding Type                   object
# Total Funding Amount                object
# Status                              object
# UUID                                object
# Homepage                            object
# Funding Type                        object
# Money Raised                        object
# Announced On                        object
# dtype: object

# %%
import json
import requests as req

# Created my api key for Crunchbase
url = "https://api.crunchbase.com/v/3/funding-rounds/?user_key="
api_key = "8a3efb5b5136f95bff0593ebb94994e3"

# Build query URL
query_url = url + api_key

# Get Crunchbase data
org_json = req.get(query_url).json()

# Get the temperature from the response
print("The Crunchbase API responded with: " + json.dumps(org_json, indent=2) + ".")
print("org_json keys: ", org_json.keys())
print(len(org_json))
# Out:
# The Crunchbase API responded with: {
#   "metadata": {
#     "version": 3,
#     "www_path_prefix": "https://www.crunchbase.com",
#     "api_path_prefix": "https://api.crunchbase.com",
#     "image_path_prefix": "http://public.crunchbase.com/t_api_images/"
#   },
#   "data": {
#     "paging": {
#       "total_items": 182368,
#       "number_of_pages": 1824,
#       "current_page": 1,
#       "sort_order": "created_at DESC",
#       "items_per_page": 100,
#       "next_page_url": "https://api.crunchbase.com/v/3/funding-rounds?page=2",
#       "prev_page_url": null
#     },
#     "items": [
#       {
#         "type": "FundingRound",
#         "uuid": "5110bfc4466f72a17a213425faf9a57e",
#         "properties": {
#           "permalink": "5110bfc4466f72a17a213425faf9a57e",
#           "api_path": "funding-rounds/5110bfc4466f72a17a213425faf9a57e",
#           "web_path": "funding-round/5110bfc4466f72a17a213425faf9a57e",
#           "funding_type": "post_ipo_equity",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 3200000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 3200000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504075215,
#           "updated_at": 1504075215
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "6d35c05e4f9f20c951e73f4bb9917ec0",
#         "properties": {
#           "permalink": "6d35c05e4f9f20c951e73f4bb9917ec0",
#           "api_path": "funding-rounds/6d35c05e4f9f20c951e73f4bb9917ec0",
#           "web_path": "funding-round/6d35c05e4f9f20c951e73f4bb9917ec0",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2013-07-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504074996,
#           "updated_at": 1504075008
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "0c2e8b517b0272d6075024ce3a42473d",
#         "properties": {
#           "permalink": "0c2e8b517b0272d6075024ce3a42473d",
#           "api_path": "funding-rounds/0c2e8b517b0272d6075024ce3a42473d",
#           "web_path": "funding-round/0c2e8b517b0272d6075024ce3a42473d",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-09-15",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 2999998,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 2999998,
#           "target_money_raised": 2999998,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": 2999998,
#           "created_at": 1504074935,
#           "updated_at": 1504075063
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "8e7c528fa36c86150bbbd9cdfe4a6394",
#         "properties": {
#           "permalink": "8e7c528fa36c86150bbbd9cdfe4a6394",
#           "api_path": "funding-rounds/8e7c528fa36c86150bbbd9cdfe4a6394",
#           "web_path": "funding-round/8e7c528fa36c86150bbbd9cdfe4a6394",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-09-14",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 140000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 140000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504074290,
#           "updated_at": 1504074317
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "56f73d740648f4f89ae357d49ffce01e",
#         "properties": {
#           "permalink": "56f73d740648f4f89ae357d49ffce01e",
#           "api_path": "funding-rounds/56f73d740648f4f89ae357d49ffce01e",
#           "web_path": "funding-round/56f73d740648f4f89ae357d49ffce01e",
#           "funding_type": "venture",
#           "series": "B",
#           "series_qualifier": null,
#           "announced_on": "2012-06-27",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 2500000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 2500000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504074114,
#           "updated_at": 1504074301
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "49f42cc91b9ba065502fb6ff08c19647",
#         "properties": {
#           "permalink": "49f42cc91b9ba065502fb6ff08c19647",
#           "api_path": "funding-rounds/49f42cc91b9ba065502fb6ff08c19647",
#           "web_path": "funding-round/49f42cc91b9ba065502fb6ff08c19647",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2008-12-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504073829,
#           "updated_at": 1504073871
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "d93eb1aa50e8568a58c495251d6971bf",
#         "properties": {
#           "permalink": "d93eb1aa50e8568a58c495251d6971bf",
#           "api_path": "funding-rounds/d93eb1aa50e8568a58c495251d6971bf",
#           "web_path": "funding-round/d93eb1aa50e8568a58c495251d6971bf",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2008-03-02",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504072976,
#           "updated_at": 1504073046
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "61fc225f88b285382982567fd087f30e",
#         "properties": {
#           "permalink": "61fc225f88b285382982567fd087f30e",
#           "api_path": "funding-rounds/61fc225f88b285382982567fd087f30e",
#           "web_path": "funding-round/61fc225f88b285382982567fd087f30e",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2006-08-08",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 4500000,
#           "money_raised_currency_code": "AUD",
#           "money_raised_usd": 3435114.5038167937,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "AUD",
#           "target_money_raised_usd": null,
#           "created_at": 1504072738,
#           "updated_at": 1504072826
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "07d8317db4ccac4bb837b6782cf89e85",
#         "properties": {
#           "permalink": "07d8317db4ccac4bb837b6782cf89e85",
#           "api_path": "funding-rounds/07d8317db4ccac4bb837b6782cf89e85",
#           "web_path": "funding-round/07d8317db4ccac4bb837b6782cf89e85",
#           "funding_type": "venture",
#           "series": "B",
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 21000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 21000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504072729,
#           "updated_at": 1504072765
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "17651916443f32ae566e76547c685ab9",
#         "properties": {
#           "permalink": "17651916443f32ae566e76547c685ab9",
#           "api_path": "funding-rounds/17651916443f32ae566e76547c685ab9",
#           "web_path": "funding-round/17651916443f32ae566e76547c685ab9",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-09-15",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 1000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 1000000,
#           "target_money_raised": 1000000,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": 1000000,
#           "created_at": 1504072490,
#           "updated_at": 1504072512
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "6878a4f5b0aa38499df02b9da30839bb",
#         "properties": {
#           "permalink": "6878a4f5b0aa38499df02b9da30839bb",
#           "api_path": "funding-rounds/6878a4f5b0aa38499df02b9da30839bb",
#           "web_path": "funding-round/6878a4f5b0aa38499df02b9da30839bb",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-09-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504072489,
#           "updated_at": 1504073152
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "397ccebf46f3f512e6881276bca10c1b",
#         "properties": {
#           "permalink": "397ccebf46f3f512e6881276bca10c1b",
#           "api_path": "funding-rounds/397ccebf46f3f512e6881276bca10c1b",
#           "web_path": "funding-round/397ccebf46f3f512e6881276bca10c1b",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-02-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504072121,
#           "updated_at": 1504073119
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "4cabb13e438f5eeee8566fa2103a84f0",
#         "properties": {
#           "permalink": "4cabb13e438f5eeee8566fa2103a84f0",
#           "api_path": "funding-rounds/4cabb13e438f5eeee8566fa2103a84f0",
#           "web_path": "funding-round/4cabb13e438f5eeee8566fa2103a84f0",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-03-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 1100000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 1100000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504071854,
#           "updated_at": 1504073092
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "49b7ddcbdbf4018aa593cf55bddb981f",
#         "properties": {
#           "permalink": "49b7ddcbdbf4018aa593cf55bddb981f",
#           "api_path": "funding-rounds/49b7ddcbdbf4018aa593cf55bddb981f",
#           "web_path": "funding-round/49b7ddcbdbf4018aa593cf55bddb981f",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-06-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504071429,
#           "updated_at": 1504073048
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "f39e60a367849b39a1cb9ca64624717d",
#         "properties": {
#           "permalink": "f39e60a367849b39a1cb9ca64624717d",
#           "api_path": "funding-rounds/f39e60a367849b39a1cb9ca64624717d",
#           "web_path": "funding-round/f39e60a367849b39a1cb9ca64624717d",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-06-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504071201,
#           "updated_at": 1504073017
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "9f74905db43e9ce78b268fbb79b9d87d",
#         "properties": {
#           "permalink": "9f74905db43e9ce78b268fbb79b9d87d",
#           "api_path": "funding-rounds/9f74905db43e9ce78b268fbb79b9d87d",
#           "web_path": "funding-round/9f74905db43e9ce78b268fbb79b9d87d",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2015-01-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504070792,
#           "updated_at": 1504070814
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "f7aed34fe1f3b1e2bf00f71756613eeb",
#         "properties": {
#           "permalink": "f7aed34fe1f3b1e2bf00f71756613eeb",
#           "api_path": "funding-rounds/f7aed34fe1f3b1e2bf00f71756613eeb",
#           "web_path": "funding-round/f7aed34fe1f3b1e2bf00f71756613eeb",
#           "funding_type": "venture",
#           "series": "A",
#           "series_qualifier": null,
#           "announced_on": "2016-02-20",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504070347,
#           "updated_at": 1504070480
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "f5cc413c0c698ed6f80cd880ad4fa6e9",
#         "properties": {
#           "permalink": "f5cc413c0c698ed6f80cd880ad4fa6e9",
#           "api_path": "funding-rounds/f5cc413c0c698ed6f80cd880ad4fa6e9",
#           "web_path": "funding-round/f5cc413c0c698ed6f80cd880ad4fa6e9",
#           "funding_type": "venture",
#           "series": "A",
#           "series_qualifier": null,
#           "announced_on": "2015-03-19",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 33000000,
#           "money_raised_currency_code": "CNY",
#           "money_raised_usd": 5315108.060441906,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "CNY",
#           "target_money_raised_usd": null,
#           "created_at": 1504070317,
#           "updated_at": 1504071155
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "e992c405e47b9d678533aad0ff7ccaa7",
#         "properties": {
#           "permalink": "e992c405e47b9d678533aad0ff7ccaa7",
#           "api_path": "funding-rounds/e992c405e47b9d678533aad0ff7ccaa7",
#           "web_path": "funding-round/e992c405e47b9d678533aad0ff7ccaa7",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2014-01-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504070298,
#           "updated_at": 1504070360
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "16d53d6514ef35158056c72c4b80f43c",
#         "properties": {
#           "permalink": "16d53d6514ef35158056c72c4b80f43c",
#           "api_path": "funding-rounds/16d53d6514ef35158056c72c4b80f43c",
#           "web_path": "funding-round/16d53d6514ef35158056c72c4b80f43c",
#           "funding_type": "venture",
#           "series": "B",
#           "series_qualifier": null,
#           "announced_on": "2016-06-22",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 100000000,
#           "money_raised_currency_code": "CNY",
#           "money_raised_usd": 15197329.727851283,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "CNY",
#           "target_money_raised_usd": null,
#           "created_at": 1504070148,
#           "updated_at": 1504070223
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "031fe623dbf2d47eb17fddc9995ba285",
#         "properties": {
#           "permalink": "031fe623dbf2d47eb17fddc9995ba285",
#           "api_path": "funding-rounds/031fe623dbf2d47eb17fddc9995ba285",
#           "web_path": "funding-round/031fe623dbf2d47eb17fddc9995ba285",
#           "funding_type": "venture",
#           "series": "C",
#           "series_qualifier": null,
#           "announced_on": "2017-08-30",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 29000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 29000000,
#           "target_money_raised": 171000000,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": 171000000,
#           "created_at": 1504069913,
#           "updated_at": 1504071223
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "b89c7396a56a81711152995dea1f33ea",
#         "properties": {
#           "permalink": "b89c7396a56a81711152995dea1f33ea",
#           "api_path": "funding-rounds/b89c7396a56a81711152995dea1f33ea",
#           "web_path": "funding-round/b89c7396a56a81711152995dea1f33ea",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 3000000,
#           "money_raised_currency_code": "EUR",
#           "money_raised_usd": 3589447.0257443115,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "EUR",
#           "target_money_raised_usd": null,
#           "created_at": 1504069728,
#           "updated_at": 1504069810
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "6d5d98287f4460025ce96f6538f74898",
#         "properties": {
#           "permalink": "6d5d98287f4460025ce96f6538f74898",
#           "api_path": "funding-rounds/6d5d98287f4460025ce96f6538f74898",
#           "web_path": "funding-round/6d5d98287f4460025ce96f6538f74898",
#           "funding_type": "post_ipo_equity",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-28",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 7000000,
#           "money_raised_currency_code": "GBP",
#           "money_raised_usd": 9026434.558349451,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "GBP",
#           "target_money_raised_usd": null,
#           "created_at": 1504069678,
#           "updated_at": 1504070106
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "5368584b6d3b4e34a2fca9dc303b35a6",
#         "properties": {
#           "permalink": "5368584b6d3b4e34a2fca9dc303b35a6",
#           "api_path": "funding-rounds/5368584b6d3b4e34a2fca9dc303b35a6",
#           "web_path": "funding-round/5368584b6d3b4e34a2fca9dc303b35a6",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-30",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 5000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 5000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504069307,
#           "updated_at": 1504069475
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "27b32f3a1af129044bd4aa65504d7818",
#         "properties": {
#           "permalink": "27b32f3a1af129044bd4aa65504d7818",
#           "api_path": "funding-rounds/27b32f3a1af129044bd4aa65504d7818",
#           "web_path": "funding-round/27b32f3a1af129044bd4aa65504d7818",
#           "funding_type": "private_equity",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-28",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": null,
#           "target_money_raised_usd": null,
#           "created_at": 1504069045,
#           "updated_at": 1504069618
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "f2493f816483b7e308d87bbe666e9688",
#         "properties": {
#           "permalink": "f2493f816483b7e308d87bbe666e9688",
#           "api_path": "funding-rounds/f2493f816483b7e308d87bbe666e9688",
#           "web_path": "funding-round/f2493f816483b7e308d87bbe666e9688",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2010-12-24",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504068778,
#           "updated_at": 1504068869
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "088811c215a6d79228c66f241e2dd324",
#         "properties": {
#           "permalink": "088811c215a6d79228c66f241e2dd324",
#           "api_path": "funding-rounds/088811c215a6d79228c66f241e2dd324",
#           "web_path": "funding-round/088811c215a6d79228c66f241e2dd324",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-28",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 2300000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 2300000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504068204,
#           "updated_at": 1504068241
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "c2415becec04b07819da95fc71d670a5",
#         "properties": {
#           "permalink": "c2415becec04b07819da95fc71d670a5",
#           "api_path": "funding-rounds/c2415becec04b07819da95fc71d670a5",
#           "web_path": "funding-round/c2415becec04b07819da95fc71d670a5",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2014-09-10",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504068173,
#           "updated_at": 1504068217
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "f6d7c54b13ee69d4de94d19830edfd78",
#         "properties": {
#           "permalink": "f6d7c54b13ee69d4de94d19830edfd78",
#           "api_path": "funding-rounds/f6d7c54b13ee69d4de94d19830edfd78",
#           "web_path": "funding-round/f6d7c54b13ee69d4de94d19830edfd78",
#           "funding_type": "private_equity",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-25",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": null,
#           "target_money_raised_usd": null,
#           "created_at": 1504068050,
#           "updated_at": 1504068100
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "2c4ce280cef3dd69a95819ab693d9714",
#         "properties": {
#           "permalink": "2c4ce280cef3dd69a95819ab693d9714",
#           "api_path": "funding-rounds/2c4ce280cef3dd69a95819ab693d9714",
#           "web_path": "funding-round/2c4ce280cef3dd69a95819ab693d9714",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 15000000,
#           "money_raised_currency_code": "CNY",
#           "money_raised_usd": 2264774.254851524,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "CNY",
#           "target_money_raised_usd": null,
#           "created_at": 1504067940,
#           "updated_at": 1504068059
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "515c357eec35abc28ea359a3857c842e",
#         "properties": {
#           "permalink": "515c357eec35abc28ea359a3857c842e",
#           "api_path": "funding-rounds/515c357eec35abc28ea359a3857c842e",
#           "web_path": "funding-round/515c357eec35abc28ea359a3857c842e",
#           "funding_type": "venture",
#           "series": "B",
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 28000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 28000000,
#           "target_money_raised": 180000000,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": 180000000,
#           "created_at": 1504067920,
#           "updated_at": 1504068008
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "9d68b80dd1953dfa49ce0c12fd6b5928",
#         "properties": {
#           "permalink": "9d68b80dd1953dfa49ce0c12fd6b5928",
#           "api_path": "funding-rounds/9d68b80dd1953dfa49ce0c12fd6b5928",
#           "web_path": "funding-round/9d68b80dd1953dfa49ce0c12fd6b5928",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2014-01-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504067798,
#           "updated_at": 1504067810
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "e62efae3987e601be94214b24e547d8c",
#         "properties": {
#           "permalink": "e62efae3987e601be94214b24e547d8c",
#           "api_path": "funding-rounds/e62efae3987e601be94214b24e547d8c",
#           "web_path": "funding-round/e62efae3987e601be94214b24e547d8c",
#           "funding_type": "venture",
#           "series": "D",
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 26300000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 26300000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504067602,
#           "updated_at": 1504067770
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "17d6b461e1b5844ab2c8897b78c2d7c5",
#         "properties": {
#           "permalink": "17d6b461e1b5844ab2c8897b78c2d7c5",
#           "api_path": "funding-rounds/17d6b461e1b5844ab2c8897b78c2d7c5",
#           "web_path": "funding-round/17d6b461e1b5844ab2c8897b78c2d7c5",
#           "funding_type": "venture",
#           "series": "B",
#           "series_qualifier": null,
#           "announced_on": "2017-05-10",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 2500000000,
#           "money_raised_currency_code": "CNY",
#           "money_raised_usd": 361946926.99820036,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "CNY",
#           "target_money_raised_usd": null,
#           "created_at": 1504067477,
#           "updated_at": 1504067844
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "d4eb907a46eb6a7333ea4464f4bb7683",
#         "properties": {
#           "permalink": "d4eb907a46eb6a7333ea4464f4bb7683",
#           "api_path": "funding-rounds/d4eb907a46eb6a7333ea4464f4bb7683",
#           "web_path": "funding-round/d4eb907a46eb6a7333ea4464f4bb7683",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-28",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 4600000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 4600000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504067269,
#           "updated_at": 1504067321
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "860e3959283f517e07071352f034d332",
#         "properties": {
#           "permalink": "860e3959283f517e07071352f034d332",
#           "api_path": "funding-rounds/860e3959283f517e07071352f034d332",
#           "web_path": "funding-round/860e3959283f517e07071352f034d332",
#           "funding_type": "grant",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 225000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 225000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": null,
#           "target_money_raised_usd": null,
#           "created_at": 1504067112,
#           "updated_at": 1504067194
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "191faf5175d8c1825062b3704db5c642",
#         "properties": {
#           "permalink": "191faf5175d8c1825062b3704db5c642",
#           "api_path": "funding-rounds/191faf5175d8c1825062b3704db5c642",
#           "web_path": "funding-round/191faf5175d8c1825062b3704db5c642",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2015-01-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504067085,
#           "updated_at": 1504067094
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "a5d0cd4047a38dfcd04ce8cf77c8cf36",
#         "properties": {
#           "permalink": "a5d0cd4047a38dfcd04ce8cf77c8cf36",
#           "api_path": "funding-rounds/a5d0cd4047a38dfcd04ce8cf77c8cf36",
#           "web_path": "funding-round/a5d0cd4047a38dfcd04ce8cf77c8cf36",
#           "funding_type": "grant",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-30",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 1000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 1000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": null,
#           "target_money_raised_usd": null,
#           "created_at": 1504066910,
#           "updated_at": 1504070254
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "eb89feff6b8f31a403cd991cd1c93b55",
#         "properties": {
#           "permalink": "eb89feff6b8f31a403cd991cd1c93b55",
#           "api_path": "funding-rounds/eb89feff6b8f31a403cd991cd1c93b55",
#           "web_path": "funding-round/eb89feff6b8f31a403cd991cd1c93b55",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2015-09-16",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 355000,
#           "money_raised_currency_code": "AUD",
#           "money_raised_usd": 253945.69615695515,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "AUD",
#           "target_money_raised_usd": null,
#           "created_at": 1504066660,
#           "updated_at": 1504066728
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "4d95394ad380608618eef4016fe959f0",
#         "properties": {
#           "permalink": "4d95394ad380608618eef4016fe959f0",
#           "api_path": "funding-rounds/4d95394ad380608618eef4016fe959f0",
#           "web_path": "funding-round/4d95394ad380608618eef4016fe959f0",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 3000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 3000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504066618,
#           "updated_at": 1504068848
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "3c7f48b9c15b98e271d3079b53fadab5",
#         "properties": {
#           "permalink": "3c7f48b9c15b98e271d3079b53fadab5",
#           "api_path": "funding-rounds/3c7f48b9c15b98e271d3079b53fadab5",
#           "web_path": "funding-round/3c7f48b9c15b98e271d3079b53fadab5",
#           "funding_type": "angel",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-22",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504066291,
#           "updated_at": 1504066458
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "46e05396204f8998d76972cb6c213c02",
#         "properties": {
#           "permalink": "46e05396204f8998d76972cb6c213c02",
#           "api_path": "funding-rounds/46e05396204f8998d76972cb6c213c02",
#           "web_path": "funding-round/46e05396204f8998d76972cb6c213c02",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 30000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 30000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504066287,
#           "updated_at": 1504073254
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "3b51a0e41605f0ed3a344b422809f4f3",
#         "properties": {
#           "permalink": "3b51a0e41605f0ed3a344b422809f4f3",
#           "api_path": "funding-rounds/3b51a0e41605f0ed3a344b422809f4f3",
#           "web_path": "funding-round/3b51a0e41605f0ed3a344b422809f4f3",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 3600000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 3600000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504066273,
#           "updated_at": 1504066456
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "fd28e8ebc8d36408d4f59483a0afb435",
#         "properties": {
#           "permalink": "fd28e8ebc8d36408d4f59483a0afb435",
#           "api_path": "funding-rounds/fd28e8ebc8d36408d4f59483a0afb435",
#           "web_path": "funding-round/fd28e8ebc8d36408d4f59483a0afb435",
#           "funding_type": "venture",
#           "series": "E",
#           "series_qualifier": null,
#           "announced_on": "2017-08-30",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 1000000000,
#           "money_raised_currency_code": "CNY",
#           "money_raised_usd": 151251835.81915727,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "CNY",
#           "target_money_raised_usd": null,
#           "created_at": 1504066196,
#           "updated_at": 1504066314
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "c5e06db552dec48e0cab5c4701013f5a",
#         "properties": {
#           "permalink": "c5e06db552dec48e0cab5c4701013f5a",
#           "api_path": "funding-rounds/c5e06db552dec48e0cab5c4701013f5a",
#           "web_path": "funding-round/c5e06db552dec48e0cab5c4701013f5a",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2013-01-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504065806,
#           "updated_at": 1504065818
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "c3e287fc71d776794d6688fb8128a4f5",
#         "properties": {
#           "permalink": "c3e287fc71d776794d6688fb8128a4f5",
#           "api_path": "funding-rounds/c3e287fc71d776794d6688fb8128a4f5",
#           "web_path": "funding-round/c3e287fc71d776794d6688fb8128a4f5",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 75000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 75000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504065679,
#           "updated_at": 1504065709
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "16bef35383fd7dd69649e64ac4bcf447",
#         "properties": {
#           "permalink": "16bef35383fd7dd69649e64ac4bcf447",
#           "api_path": "funding-rounds/16bef35383fd7dd69649e64ac4bcf447",
#           "web_path": "funding-round/16bef35383fd7dd69649e64ac4bcf447",
#           "funding_type": "venture",
#           "series": "A",
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 5000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 5000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504065409,
#           "updated_at": 1504065652
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "2b05f6c90c0d7042f6147f6e98f85cb3",
#         "properties": {
#           "permalink": "2b05f6c90c0d7042f6147f6e98f85cb3",
#           "api_path": "funding-rounds/2b05f6c90c0d7042f6147f6e98f85cb3",
#           "web_path": "funding-round/2b05f6c90c0d7042f6147f6e98f85cb3",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2015-01-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504065395,
#           "updated_at": 1504065410
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "04624bd9dfa59f985ae4cdff65685c14",
#         "properties": {
#           "permalink": "04624bd9dfa59f985ae4cdff65685c14",
#           "api_path": "funding-rounds/04624bd9dfa59f985ae4cdff65685c14",
#           "web_path": "funding-round/04624bd9dfa59f985ae4cdff65685c14",
#           "funding_type": "venture",
#           "series": "D",
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 90000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 90000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504065015,
#           "updated_at": 1504065118
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "b5578ecd955fafe9551019f91e6efdbd",
#         "properties": {
#           "permalink": "b5578ecd955fafe9551019f91e6efdbd",
#           "api_path": "funding-rounds/b5578ecd955fafe9551019f91e6efdbd",
#           "web_path": "funding-round/b5578ecd955fafe9551019f91e6efdbd",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 140000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 140000000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504064762,
#           "updated_at": 1504064988
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "682522bd9c5a3b310aa171a42444ce15",
#         "properties": {
#           "permalink": "682522bd9c5a3b310aa171a42444ce15",
#           "api_path": "funding-rounds/682522bd9c5a3b310aa171a42444ce15",
#           "web_path": "funding-round/682522bd9c5a3b310aa171a42444ce15",
#           "funding_type": "venture",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-06-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504064738,
#           "updated_at": 1504064903
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "35ccf573af98bdef115968c11645feef",
#         "properties": {
#           "permalink": "35ccf573af98bdef115968c11645feef",
#           "api_path": "funding-rounds/35ccf573af98bdef115968c11645feef",
#           "web_path": "funding-round/35ccf573af98bdef115968c11645feef",
#           "funding_type": "venture",
#           "series": "C",
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 67000000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 67000000,
#           "target_money_raised": null,
# ...
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": 1500000,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": 1500000,
#           "created_at": 1504031922,
#           "updated_at": 1504031922
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "368b04a0c4db709cf630b33927024ab7",
#         "properties": {
#           "permalink": "368b04a0c4db709cf630b33927024ab7",
#           "api_path": "funding-rounds/368b04a0c4db709cf630b33927024ab7",
#           "web_path": "funding-round/368b04a0c4db709cf630b33927024ab7",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-11-15",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "BRL",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "BRL",
#           "target_money_raised_usd": null,
#           "created_at": 1504031636,
#           "updated_at": 1504031636
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "3759079038b654f201ab06f4afe25ed4",
#         "properties": {
#           "permalink": "3759079038b654f201ab06f4afe25ed4",
#           "api_path": "funding-rounds/3759079038b654f201ab06f4afe25ed4",
#           "web_path": "funding-round/3759079038b654f201ab06f4afe25ed4",
#           "funding_type": "convertible_note",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-12-15",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504030547,
#           "updated_at": 1504030547
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "15f7deb8b1743a35be1c18cbd144f17d",
#         "properties": {
#           "permalink": "15f7deb8b1743a35be1c18cbd144f17d",
#           "api_path": "funding-rounds/15f7deb8b1743a35be1c18cbd144f17d",
#           "web_path": "funding-round/15f7deb8b1743a35be1c18cbd144f17d",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-26",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504028201,
#           "updated_at": 1504028278
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "ed5b72e43c4dcb239840210ddbf3b767",
#         "properties": {
#           "permalink": "ed5b72e43c4dcb239840210ddbf3b767",
#           "api_path": "funding-rounds/ed5b72e43c4dcb239840210ddbf3b767",
#           "web_path": "funding-round/ed5b72e43c4dcb239840210ddbf3b767",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-28",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 4099999,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 4099999,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504027656,
#           "updated_at": 1504032223
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "df87d5f4b2ca5e5082c850a71f9ccac1",
#         "properties": {
#           "permalink": "df87d5f4b2ca5e5082c850a71f9ccac1",
#           "api_path": "funding-rounds/df87d5f4b2ca5e5082c850a71f9ccac1",
#           "web_path": "funding-round/df87d5f4b2ca5e5082c850a71f9ccac1",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-05-01",
#           "announced_on_trust_code": 7,
#           "closed_on": "2017-05-01",
#           "closed_on_trust_code": 7,
#           "money_raised": 1500000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 1500000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504026943,
#           "updated_at": 1504027017
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "1c973949ca936fff06e8ce6279709d36",
#         "properties": {
#           "permalink": "1c973949ca936fff06e8ce6279709d36",
#           "api_path": "funding-rounds/1c973949ca936fff06e8ce6279709d36",
#           "web_path": "funding-round/1c973949ca936fff06e8ce6279709d36",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-28",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 400000,
#           "money_raised_currency_code": "CHF",
#           "money_raised_usd": 418588.1023308381,
#           "target_money_raised": 400000,
#           "target_money_raised_currency_code": "CHF",
#           "target_money_raised_usd": 418588.1023308381,
#           "created_at": 1504026805,
#           "updated_at": 1504037302
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "3aab2260f71efac03e115b09afcd18df",
#         "properties": {
#           "permalink": "3aab2260f71efac03e115b09afcd18df",
#           "api_path": "funding-rounds/3aab2260f71efac03e115b09afcd18df",
#           "web_path": "funding-round/3aab2260f71efac03e115b09afcd18df",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-05-22",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504025623,
#           "updated_at": 1504025623
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "d4b6b8f5f52ff30a007e38d22d64ecbf",
#         "properties": {
#           "permalink": "d4b6b8f5f52ff30a007e38d22d64ecbf",
#           "api_path": "funding-rounds/d4b6b8f5f52ff30a007e38d22d64ecbf",
#           "web_path": "funding-round/d4b6b8f5f52ff30a007e38d22d64ecbf",
#           "funding_type": "venture",
#           "series": "A",
#           "series_qualifier": null,
#           "announced_on": "2017-08-24",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 1500000,
#           "money_raised_currency_code": "GBP",
#           "money_raised_usd": 1920770.3569645002,
#           "target_money_raised": 1200000,
#           "target_money_raised_currency_code": "GBP",
#           "target_money_raised_usd": 1536616.2855716,
#           "created_at": 1504024908,
#           "updated_at": 1504024908
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "42cc36c04265b6511a0d37be17a0784f",
#         "properties": {
#           "permalink": "42cc36c04265b6511a0d37be17a0784f",
#           "api_path": "funding-rounds/42cc36c04265b6511a0d37be17a0784f",
#           "web_path": "funding-round/42cc36c04265b6511a0d37be17a0784f",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-05-31",
#           "announced_on_trust_code": 7,
#           "closed_on": "2016-05-31",
#           "closed_on_trust_code": 7,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504024796,
#           "updated_at": 1504025572
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "bce50beca887b6da83934e990b204541",
#         "properties": {
#           "permalink": "bce50beca887b6da83934e990b204541",
#           "api_path": "funding-rounds/bce50beca887b6da83934e990b204541",
#           "web_path": "funding-round/bce50beca887b6da83934e990b204541",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-08-01",
#           "announced_on_trust_code": 7,
#           "closed_on": "2017-08-01",
#           "closed_on_trust_code": 7,
#           "money_raised": 1032000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 1032000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504024768,
#           "updated_at": 1504025411
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "7dabbac60607307a5cb988c828fe10ec",
#         "properties": {
#           "permalink": "7dabbac60607307a5cb988c828fe10ec",
#           "api_path": "funding-rounds/7dabbac60607307a5cb988c828fe10ec",
#           "web_path": "funding-round/7dabbac60607307a5cb988c828fe10ec",
#           "funding_type": "venture",
#           "series": "B",
#           "series_qualifier": null,
#           "announced_on": "2017-08-29",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 8250000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 8250000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504022839,
#           "updated_at": 1504059017
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "7a74671a29c353e14b66567ca6d73c95",
#         "properties": {
#           "permalink": "7a74671a29c353e14b66567ca6d73c95",
#           "api_path": "funding-rounds/7a74671a29c353e14b66567ca6d73c95",
#           "web_path": "funding-round/7a74671a29c353e14b66567ca6d73c95",
#           "funding_type": "angel",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-03-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 40000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 40000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504022685,
#           "updated_at": 1504022708
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "861767e268da68582ae26626e07b70ea",
#         "properties": {
#           "permalink": "861767e268da68582ae26626e07b70ea",
#           "api_path": "funding-rounds/861767e268da68582ae26626e07b70ea",
#           "web_path": "funding-round/861767e268da68582ae26626e07b70ea",
#           "funding_type": "angel",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2016-02-01",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 40000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 40000,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504022542,
#           "updated_at": 1504022557
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "e9dc7e8edf0f4b6a39379c28b91455b9",
#         "properties": {
#           "permalink": "e9dc7e8edf0f4b6a39379c28b91455b9",
#           "api_path": "funding-rounds/e9dc7e8edf0f4b6a39379c28b91455b9",
#           "web_path": "funding-round/e9dc7e8edf0f4b6a39379c28b91455b9",
#           "funding_type": "seed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2003-01-02",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 0,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 0,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504022487,
#           "updated_at": 1504022530
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "0e0e52c17a9828a55eeb637664342d84",
#         "properties": {
#           "permalink": "0e0e52c17a9828a55eeb637664342d84",
#           "api_path": "funding-rounds/0e0e52c17a9828a55eeb637664342d84",
#           "web_path": "funding-round/0e0e52c17a9828a55eeb637664342d84",
#           "funding_type": "venture",
#           "series": "A",
#           "series_qualifier": null,
#           "announced_on": "2017-06-05",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": 10097973,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 10097973,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504021392,
#           "updated_at": 1504021392
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "70d038843713c53e0eb8ae1b7db6064a",
#         "properties": {
#           "permalink": "70d038843713c53e0eb8ae1b7db6064a",
#           "api_path": "funding-rounds/70d038843713c53e0eb8ae1b7db6064a",
#           "web_path": "funding-round/70d038843713c53e0eb8ae1b7db6064a",
#           "funding_type": "undisclosed",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-08-28",
#           "announced_on_trust_code": 7,
#           "closed_on": "2017-12-31",
#           "closed_on_trust_code": 7,
#           "money_raised": 5000,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": 5000,
#           "target_money_raised": 100000,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": 100000,
#           "created_at": 1504018847,
#           "updated_at": 1504019193
#         }
#       },
#       {
#         "type": "FundingRound",
#         "uuid": "ccf1ce5a781254b3312a990469a3969f",
#         "properties": {
#           "permalink": "ccf1ce5a781254b3312a990469a3969f",
#           "api_path": "funding-rounds/ccf1ce5a781254b3312a990469a3969f",
#           "web_path": "funding-round/ccf1ce5a781254b3312a990469a3969f",
#           "funding_type": "convertible_note",
#           "series": null,
#           "series_qualifier": null,
#           "announced_on": "2017-07-21",
#           "announced_on_trust_code": 7,
#           "closed_on": null,
#           "closed_on_trust_code": null,
#           "money_raised": null,
#           "money_raised_currency_code": "USD",
#           "money_raised_usd": null,
#           "target_money_raised": null,
#           "target_money_raised_currency_code": "USD",
#           "target_money_raised_usd": null,
#           "created_at": 1504016334,
#           "updated_at": 1504016334
#         }
#       }
#     ]
#   }
# }.
# org_json keys:  dict_keys(['metadata', 'data'])
# 2

# %%
#creates a new dataframe that's empty
fund_df = pd.DataFrame() 
fund_df["uuid"] = ""
fund_df["Funding Type"] = ""
fund_df["Money Raised"] = ""
fund_df["Announced On"] = ""

index = 0

# Created my api key for Crunchbase
url = "https://api.crunchbase.com/v/3/funding-rounds/?user_key="
api_key = "8a3efb5b5136f95bff0593ebb94994e3"

# get 10 pages of org items
for x in range(1,11):
    # Build query URL
    query_url = url + api_key + "&page=" + str(x)
    # Get Crunchbase data
    funding_json = req.get(query_url).json()
    print(query_url)

    # Loop through a page of items 
    for i in range(0,len(funding_json["data"]["items"])):
        # Save the user class info into variables
        uuid  = funding_json["data"]["items"][i]["uuid"]
        fundingtype  = funding_json["data"]["items"][i]["properties"]["funding_type"]
        raised  = funding_json["data"]["items"][i]["properties"]["money_raised"]
        date = funding_json["data"]["items"][i]["properties"]["announced_on"]
        
               
        # Set the cell info for Real Name, Tweets, Followers, Following, Favorites Count
        fund_df.set_value(index, "uuid", uuid)
        fund_df.set_value(index, "Funding Type", fundingtype)
        fund_df.set_value(index, "Money Raised", raised)
        fund_df.set_value(index, "Announced On", date)
        index += 1

fund_df.sort_values("uuid")    
fund_df.head(10)
# Out:
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=1
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=2
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=3
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=4
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=5
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=6
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=7
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=8
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=9
# https://api.crunchbase.com/v/3/funding-rounds/?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=10
#                                uuid     Funding Type Money Raised Announced On
# 0  5110bfc4466f72a17a213425faf9a57e  post_ipo_equity      3200000   2017-08-29
# 1  6d35c05e4f9f20c951e73f4bb9917ec0             seed         None   2013-07-01
# 2  0c2e8b517b0272d6075024ce3a42473d          venture      2999998   2016-09-15
# 3  8e7c528fa36c86150bbbd9cdfe4a6394             seed       140000   2016-09-14
# 4  56f73d740648f4f89ae357d49ffce01e          venture      2500000   2012-06-27
# 5  49f42cc91b9ba065502fb6ff08c19647             seed         None   2008-12-01
# 6  d93eb1aa50e8568a58c495251d6971bf          venture         None   2008-03-02
# 7  61fc225f88b285382982567fd087f30e          venture      4500000   2006-08-08
# 8  07d8317db4ccac4bb837b6782cf89e85          venture     21000000   2017-08-29
# 9  17651916443f32ae566e76547c685ab9          venture      1000000   2016-09-15

# %%
funds_pd = fund_df.rename(columns={
    "uuid": "UUID"   
})

funds_pd.head()
# Out:
#                                UUID     Funding Type Money Raised Announced On
# 0  5110bfc4466f72a17a213425faf9a57e  post_ipo_equity      3200000   2017-08-29
# 1  6d35c05e4f9f20c951e73f4bb9917ec0             seed         None   2013-07-01
# 2  0c2e8b517b0272d6075024ce3a42473d          venture      2999998   2016-09-15
# 3  8e7c528fa36c86150bbbd9cdfe4a6394             seed       140000   2016-09-14
# 4  56f73d740648f4f89ae357d49ffce01e          venture      2500000   2012-06-27

# %%
data_set = pd.merge(merged_df, funds_pd,how="inner", on="UUID")
data_set.head()
# Out:
# Empty DataFrame
# Columns: [Company, Founded Date, Closed Date, Funding Rounds, Last Funding Date, Last Funding Amount, Total Funding Amount, Status, Funding Type_x, Money Raised_x, Announced On Date, UUID, Homepage, Funding Type_y, Money Raised_y, Announced On]
# Index: []
