# %%
##Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import random as rd

np.random.seed(sum(map(ord, "aesthetics")))

##
## https://data.crunchbase.com/v3/reference - Crunchbase endpoint documenation
##

# %%
## odm-organizations  Single request to view json structure
## Basic request.get to https://api.crunchbase.com/v/3/odm-organizations?
import json
import requests as req

# Created my api key for Crunchbase
url = "https://api.crunchbase.com/v/3/odm-organizations?user_key="
api_key = "8a3efb5b5136f95bff0593ebb94994e3"

# Build query URL
query_url = url + api_key

# Get Crunchbase data
org_json = req.get(query_url).json()

# Get the temperature from the response
print("The Crunchbase API responded with: " + json.dumps(org_json, indent=2) + ".")
print("org_json keys: ", org_json.keys())
print(len(org_json))
# Out:
# The Crunchbase API responded with: {
#   "metadata": {
#     "version": 3,
#     "www_path_prefix": "https://www.crunchbase.com",
#     "api_path_prefix": "https://api.crunchbase.com",
#     "image_path_prefix": "http://public.crunchbase.com/t_api_images/"
#   },
#   "data": {
#     "paging": {
#       "total_items": 535707,
#       "number_of_pages": 5358,
#       "current_page": 1,
#       "sort_order": "created_at DESC",
#       "items_per_page": 100,
#       "next_page_url": "https://api.crunchbase.com/v/3/organizations?page=2",
#       "prev_page_url": null
#     },
#     "items": [
#       {
#         "type": "OrganizationSummary",
#         "uuid": "ba6475aa360f4a6933be300bda5c4a35",
#         "properties": {
#           "permalink": "bovlabs-inc",
#           "api_path": "organizations/bovlabs-inc",
#           "web_path": "organization/bovlabs-inc",
#           "name": "Bovlabs Inc",
#           "primary_role": "company",
#           "short_description": "Empowering community for self-reliant energy by creating a market place to trade peer to peer, with low transaction cost and high security",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503708112/rjeizmst8r6za5co9kbe.jpg",
#           "domain": "bovlabs.com",
#           "homepage_url": "http://www.bovlabs.com",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503708384,
#           "updated_at": 1503708629
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "fc529aadcbbabee0a6e58f1f74351fc3",
#         "properties": {
#           "permalink": "halberdcross",
#           "api_path": "organizations/halberdcross",
#           "web_path": "organization/halberdcross",
#           "name": "HalberdCross",
#           "primary_role": "investor",
#           "short_description": "Venture Investment Firm",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503707234/k23ymsjusonxgxalqeuv.jpg",
#           "domain": "halberdcross.com",
#           "homepage_url": "http://halberdcross.com/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503707413,
#           "updated_at": 1503707413
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "efb36dde21a8722868bdc4c2d28cdbca",
#         "properties": {
#           "permalink": "resconte-capital-gp-llc",
#           "api_path": "organizations/resconte-capital-gp-llc",
#           "web_path": "organization/resconte-capital-gp-llc",
#           "name": "Resconte Capital GP LLC",
#           "primary_role": "investor",
#           "short_description": "Private Equity Holding Vehicle",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503703576,
#           "updated_at": 1503703576
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "4f2106e951327d0eea8e1d2550e8f7c7",
#         "properties": {
#           "permalink": "babysparks-llc",
#           "api_path": "organizations/babysparks-llc",
#           "web_path": "organization/babysparks-llc",
#           "name": "BabySparks LLC",
#           "primary_role": "company",
#           "short_description": "We build tools and programs to help parents engage their babies and toddlers in the critical areas of early development.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503701504/bkibdoauajpplsgv7bil.png",
#           "domain": "babysparks.com",
#           "homepage_url": "http://babysparks.com/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503701713,
#           "updated_at": 1503701993
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "52f30ed723259b995d80227c9981d01e",
#         "properties": {
#           "permalink": "hacking-the-core",
#           "api_path": "organizations/hacking-the-core",
#           "web_path": "organization/hacking-the-core",
#           "name": "HACKING THE CORE",
#           "primary_role": "company",
#           "short_description": "Book series about technology startups and Silicon Valley",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503700428/ko0kjorqbvg2wlmz6gv7.jpg",
#           "domain": "itunes.apple.com",
#           "homepage_url": "https://itunes.apple.com/us/book/hacking-the-core/id1211788911?mt=11",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503700360,
#           "updated_at": 1503700431
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "4145c1a3a1690713187359b5312905e7",
#         "properties": {
#           "permalink": "palm-creek-university",
#           "api_path": "organizations/palm-creek-university",
#           "web_path": "organization/palm-creek-university",
#           "name": "Palm Creek University",
#           "primary_role": "company",
#           "short_description": "Palm Creek University is a comprehensive university where we continuously strive to bring innovations in education",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503700290/i0yr6avksjgylp3ivsww.png",
#           "domain": "palmcreekuniversity.com",
#           "homepage_url": "http://www.palmcreekuniversity.com/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503700295,
#           "updated_at": 1503700295
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "4028de914ee73b414682d2f87bf32533",
#         "properties": {
#           "permalink": "regulusia-inc",
#           "api_path": "organizations/regulusia-inc",
#           "web_path": "organization/regulusia-inc",
#           "name": "regulusia Inc.",
#           "primary_role": "company",
#           "short_description": "Ecommerce Marketplace Fintech",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503699655/qvuw6ogrgowokqnb2r5z.png",
#           "domain": "regulusia.com",
#           "homepage_url": "https://www.regulusia.com",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503699707,
#           "updated_at": 1503699708
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "93538f8726e8fb05034c5521d34c35e9",
#         "properties": {
#           "permalink": "south-east-pacific-university",
#           "api_path": "organizations/south-east-pacific-university",
#           "web_path": "organization/south-east-pacific-university",
#           "name": "South East Pacific University",
#           "primary_role": "company",
#           "short_description": "Southeast Pacific University is an institution of higher education committed to provide the best online education in undergraduate.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503698603/gqxssk0ohlxrrnoxcwyv.png",
#           "domain": "southeastpacificuniversity.com",
#           "homepage_url": "http://www.southeastpacificuniversity.com",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503698552,
#           "updated_at": 1503698680
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "e6e0537cc56b0ee5d679966c2e001f33",
#         "properties": {
#           "permalink": "bluebox-labs",
#           "api_path": "organizations/bluebox-labs",
#           "web_path": "organization/bluebox-labs",
#           "name": "Bluebox",
#           "primary_role": "company",
#           "short_description": "We build blue boxes.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503697482/w4yb302fpzvtzlj3goyg.png",
#           "domain": "bluebox.io",
#           "homepage_url": "https://bluebox.io/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503697492,
#           "updated_at": 1503697812
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "4b2ce9bcb6272e96d76904d9116fa8db",
#         "properties": {
#           "permalink": "polysync-technologies",
#           "api_path": "organizations/polysync-technologies",
#           "web_path": "organization/polysync-technologies",
#           "name": "PolySync Technologies",
#           "primary_role": "company",
#           "short_description": "PolySync Technologies singular vision is to simplify and accelerate the development of self-driving cars.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503697405/tuu0eyoxqjdghiivjesg.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503697407,
#           "updated_at": 1503697408
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "89e9e17b12664481823799839d67a68c",
#         "properties": {
#           "permalink": "clavis-inc",
#           "api_path": "organizations/clavis-inc",
#           "web_path": "organization/clavis-inc",
#           "name": "Clavis Inc",
#           "primary_role": "company",
#           "short_description": "Executive, Financial and Technology Consultancy",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503697267/fkqd4ckph0bbci29hwwa.png",
#           "domain": "claviscg.com",
#           "homepage_url": "http://claviscg.com/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503697274,
#           "updated_at": 1503697291
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "d4194fd0d5efc20873faa9e254b9f17c",
#         "properties": {
#           "permalink": "condelo",
#           "api_path": "organizations/condelo",
#           "web_path": "organization/condelo",
#           "name": "Condelo",
#           "primary_role": "company",
#           "short_description": "Chatbot powered customer support for your website",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503697151/xnosuimzmvjgpq87stw4.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503697152,
#           "updated_at": 1503697153
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "354fe5dde0f291c2dc9fcfe7abef649e",
#         "properties": {
#           "permalink": "keepcoding-2",
#           "api_path": "organizations/keepcoding-2",
#           "web_path": "organization/keepcoding-2",
#           "name": "Keepcoding",
#           "primary_role": "company",
#           "short_description": "Executive education for software developers",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503696996/r3nztmcgjlnkp5w8mbxu.png",
#           "domain": "keepcoding.io",
#           "homepage_url": "https://www.keepcoding.io",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Alcobendas",
#           "region_name": "Madrid",
#           "country_code": "Spain",
#           "created_at": 1503697045,
#           "updated_at": 1503697198
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "3ffd2b9b8e3f94417b6cc992cfb33823",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-contact-facebook-support-facebook-support-number",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-contact-facebook-support-facebook-support-number",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-contact-facebook-support-facebook-support-number",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 contact facebook support facebook support number",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 contact facebook support facebook support number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503696403/qqcngqxlqzi787cwxjkq.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503696407,
#           "updated_at": 1503696453
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "ec87e5668f494bea14a3bfeb06917a6c",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-how-to-contact-facebook-facebook-contact-number",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-how-to-contact-facebook-facebook-contact-number",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-how-to-contact-facebook-facebook-contact-number",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 how to contact facebook facebook contact number",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 how to contact facebook facebook contact number",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503696399,
#           "updated_at": 1503696449
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "eabfbf06a090617e5e1e93d40604ad3f",
#         "properties": {
#           "permalink": "buffalo-router-1-855-770-7740-buffalo-router-email-support",
#           "api_path": "organizations/buffalo-router-1-855-770-7740-buffalo-router-email-support",
#           "web_path": "organization/buffalo-router-1-855-770-7740-buffalo-router-email-support",
#           "name": "Buffalo router (1_+855 _770_7740)@ Buffalo router email support",
#           "primary_role": "company",
#           "short_description": "Buffalo router (1_+855 _770_7740)@ Buffalo router email support",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503696221/sakkmkarccvkht0kbsoj.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503696331,
#           "updated_at": 1503696373
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "f3c52605668b7cbbd3f7dbe307875d3b",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-facebook-support-number-facebook-helpdesk-number",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-facebook-support-number-facebook-helpdesk-number",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-facebook-support-number-facebook-helpdesk-number",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook support number facebook helpdesk number",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook support number facebook helpdesk number",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503696223,
#           "updated_at": 1503696445
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "8616df348c5b4f2aa14f5f1b6e6eba3f",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-facebook-help-number-facebook-help-number",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-facebook-help-number-facebook-help-number",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-facebook-help-number-facebook-help-number",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook help number facebook help number",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook help number facebook help number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503696216/gyygbmcvl5ssg4secwlj.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503696218,
#           "updated_at": 1503696390
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "4b2350640c58b8826b67de21ec4c1859",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-facebook-tech-support",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-facebook-tech-support",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-facebook-tech-support",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook tech support",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook tech support",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503696198,
#           "updated_at": 1503696442
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "441b7f8cc80f8c82d1c43c1ed9c5d25d",
#         "properties": {
#           "permalink": "ap-online-business-solution",
#           "api_path": "organizations/ap-online-business-solution",
#           "web_path": "organization/ap-online-business-solution",
#           "name": "AP Online Business Solution",
#           "primary_role": "company",
#           "short_description": "AP Online Business is the world\u2019s leading authority in debuting revolutionary startups, introducing game-changing technologies,",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695112/kbj8pstl3fbnk1o2sc20.jpg",
#           "domain": "linkedin.com",
#           "homepage_url": "https://www.linkedin.com/company/13391419",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695594,
#           "updated_at": 1503695594
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "4484052bd638ccc43128cba9971a4d14",
#         "properties": {
#           "permalink": "creekford-university",
#           "api_path": "organizations/creekford-university",
#           "web_path": "organization/creekford-university",
#           "name": "Creekford University",
#           "primary_role": "school",
#           "short_description": "Providing Financial Assistance to Deserving Students Through Scholarships, Grants & Various Other Funding Programs.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695676/qyhzctdvorxporrr03x5.png",
#           "domain": "creekforduniversity.com",
#           "homepage_url": "http://www.creekforduniversity.com/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695581,
#           "updated_at": 1503695684
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "ac6cd666540e08560c22f4286fb38d87",
#         "properties": {
#           "permalink": "fluxa",
#           "api_path": "organizations/fluxa",
#           "web_path": "organization/fluxa",
#           "name": "Fluxa",
#           "primary_role": "company",
#           "short_description": "Fluxa is an intelligent app company that packages the best of AI, big data, and UX technologies for bio-pharmaceutical companies",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503701406/izfkg6s0vnjhnnzmzr2g.png",
#           "domain": "fluxa.ai",
#           "homepage_url": "http://www.fluxa.ai",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695467,
#           "updated_at": 1503701819
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "9a29bd8c778c2d0a937bb262bf479043",
#         "properties": {
#           "permalink": "buffalol-1-855-770-7740-buffalo-help-center-phone-number",
#           "api_path": "organizations/buffalol-1-855-770-7740-buffalo-help-center-phone-number",
#           "web_path": "organization/buffalol-1-855-770-7740-buffalo-help-center-phone-number",
#           "name": "Buffalol (1 _855 _770_7740)@ Buffalo help center phone number",
#           "primary_role": "company",
#           "short_description": "Buffalol (1 _855 _770_7740)@ Buffalo help center phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695392/q6boal0f25inqsqso3f4.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695396,
#           "updated_at": 1503695471
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "a38bc4b63eeaf7385a2dbfba41415e16",
#         "properties": {
#           "permalink": "buffalol-1-855-770-7740-contact-buffalo-email-buffalo-help-number",
#           "api_path": "organizations/buffalol-1-855-770-7740-contact-buffalo-email-buffalo-help-number",
#           "web_path": "organization/buffalol-1-855-770-7740-contact-buffalo-email-buffalo-help-number",
#           "name": "Buffalol (1 _855 _770_7740)@ contact Buffalo email Buffalo help number",
#           "primary_role": "company",
#           "short_description": "Buffalol (1 _855 _770_7740)@ contact Buffalo email Buffalo help number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695352/r2p0l6eui8p0rbkk4fs8.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695354,
#           "updated_at": 1503695462
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "d7349366d0a96b5db05b91df46f29619",
#         "properties": {
#           "permalink": "buffalo-1-855-770-7740-phone-number-for-buffalo-delete-buffalo-account",
#           "api_path": "organizations/buffalo-1-855-770-7740-phone-number-for-buffalo-delete-buffalo-account",
#           "web_path": "organization/buffalo-1-855-770-7740-phone-number-for-buffalo-delete-buffalo-account",
#           "name": "Buffalo|(1 _855 _770_7740)@ phone number for Buffalo delete Buffalo account",
#           "primary_role": "company",
#           "short_description": "Buffalo|(1 _855 _770_7740)@ phone number for Buffalo delete Buffalo account",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695347,
#           "updated_at": 1503695459
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "bf342a297cbf5dcce65bc362b871621b",
#         "properties": {
#           "permalink": "buffalol-1-855-770-7740-buffalo-technical-support-phone-number-buffalo-tech-support",
#           "api_path": "organizations/buffalol-1-855-770-7740-buffalo-technical-support-phone-number-buffalo-tech-support",
#           "web_path": "organization/buffalol-1-855-770-7740-buffalo-technical-support-phone-number-buffalo-tech-support",
#           "name": "Buffalol (1 _855 _770_7740)@ Buffalo technical support phone number Buffalo tech support",
#           "primary_role": "company",
#           "short_description": "Buffalol (1 _855 _770_7740)@ Buffalo technical support phone number Buffalo tech support",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695335/nnt3a5p0jgquzv3zbt4l.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695338,
#           "updated_at": 1503695453
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "8a4fa1074a7315eda0675fdacdc1e48a",
#         "properties": {
#           "permalink": "buffalol-1-855-770-7740-buffalo-support-email",
#           "api_path": "organizations/buffalol-1-855-770-7740-buffalo-support-email",
#           "web_path": "organization/buffalol-1-855-770-7740-buffalo-support-email",
#           "name": "Buffalol (1 _855 _770_7740)@ Buffalo support email",
#           "primary_role": "company",
#           "short_description": "Buffalol (1 _855 _770_7740)@ Buffalo support email",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695321/krxchcztejltkkdtqgvx.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695326,
#           "updated_at": 1503695450
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "fc3d5a191ece0049b39645eb6ede020e",
#         "properties": {
#           "permalink": "buffalol-1-855-770-7740-buffalo-help-phone-number",
#           "api_path": "organizations/buffalol-1-855-770-7740-buffalo-help-phone-number",
#           "web_path": "organization/buffalol-1-855-770-7740-buffalo-help-phone-number",
#           "name": "Buffalol (1 _855 _770_7740)@ Buffalo help phone number",
#           "primary_role": "company",
#           "short_description": "Buffalol (1 _855 _770_7740)@ Buffalo help phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695306/qapvxqlof9milbkaj9py.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695308,
#           "updated_at": 1503695446
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "f2ef5b97a696509e75520058d47b1459",
#         "properties": {
#           "permalink": "buffalol-1-855-770-7740-buffalo-customer-service-phone-number",
#           "api_path": "organizations/buffalol-1-855-770-7740-buffalo-customer-service-phone-number",
#           "web_path": "organization/buffalol-1-855-770-7740-buffalo-customer-service-phone-number",
#           "name": "Buffalol (1 _855 _770_7740)@ Buffalo customer service phone number",
#           "primary_role": "company",
#           "short_description": "Buffalol (1 _855 _770_7740)@ Buffalo customer service phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695285/jz0j5g17dagjydxwplnv.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695297,
#           "updated_at": 1503695442
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "77bc04d9d5f291476d6572e210ea8f49",
#         "properties": {
#           "permalink": "buffalol-1-855-770-7740-contact-buffalo-customer-service",
#           "api_path": "organizations/buffalol-1-855-770-7740-contact-buffalo-customer-service",
#           "web_path": "organization/buffalol-1-855-770-7740-contact-buffalo-customer-service",
#           "name": "Buffalol (1 _855 _770_7740)@ contact Buffalo customer service",
#           "primary_role": "company",
#           "short_description": "Buffalol (1 _855 _770_7740)@ contact Buffalo customer service",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695270/benaypqef69hrlpoflvt.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695277,
#           "updated_at": 1503695443
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "b702bf2706792789bf48d6c278d43976",
#         "properties": {
#           "permalink": "buffalol-1-855-770-7740-buffalo-tech-support-number",
#           "api_path": "organizations/buffalol-1-855-770-7740-buffalo-tech-support-number",
#           "web_path": "organization/buffalol-1-855-770-7740-buffalo-tech-support-number",
#           "name": "Buffalol (1_855 _770_7740)@ Buffalo tech support number",
#           "primary_role": "company",
#           "short_description": "Buffalol (1_855 _770_7740)@ Buffalo tech support number",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695264,
#           "updated_at": 1503695434
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "b8ff0c6021ed2fa073e2933fd2e0cf32",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-facebook-phone-number",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-facebook-phone-number",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-facebook-phone-number",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook phone number",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695080/r4cvcrrlzkhu1kjeeo2q.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695107,
#           "updated_at": 1503695196
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "e1425ef8eeb046fd14177914f8fac76c",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-contact-facebook-facebook-support",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-contact-facebook-facebook-support",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-contact-facebook-facebook-support",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 contact facebook facebook support",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 contact facebook facebook support",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695087,
#           "updated_at": 1503695176
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "154d8fcff046b8a4993b5ab1bcc43eec",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-facebook-contact-number",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-facebook-contact-number",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-facebook-contact-number",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook contact number",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook contact number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695074/ydhdafvkal9jesscwrgt.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695078,
#           "updated_at": 1503695171
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "ea646a0ce1f92239133ab12103aaddb8",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-facebook-customer-service",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-facebook-customer-service",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-facebook-customer-service",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook customer service",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook customer service",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695069/jdq5ywys0bzgyi2nyodb.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695072,
#           "updated_at": 1503695167
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "b8de0d499b47edae789930434175572b",
#         "properties": {
#           "permalink": "how-do-i-contact-facebook-1-855-580-1808-facebook-customer-service-number",
#           "api_path": "organizations/how-do-i-contact-facebook-1-855-580-1808-facebook-customer-service-number",
#           "web_path": "organization/how-do-i-contact-facebook-1-855-580-1808-facebook-customer-service-number",
#           "name": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook customer service number",
#           "primary_role": "company",
#           "short_description": "how do i Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook customer service number",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503695064,
#           "updated_at": 1503695166
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "b6a9d0143434f5fa1567eabfcf09f94a",
#         "properties": {
#           "permalink": "africasokoni",
#           "api_path": "organizations/africasokoni",
#           "web_path": "organization/africasokoni",
#           "name": "AfricaSokoni",
#           "primary_role": "company",
#           "short_description": "AfricaSokoni Ltd is an e-commerce company bringing African consumers and retailers together by exploring the opportunities of the internet.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694013/ipcsg4jzvplnpncydyep.png",
#           "domain": "africasokoni.com",
#           "homepage_url": "http://www.africasokoni.com/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694934,
#           "updated_at": 1503695541
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "c33195c1ab2830ca3311ac004a92f1ef",
#         "properties": {
#           "permalink": "celerem-now",
#           "api_path": "organizations/celerem-now",
#           "web_path": "organization/celerem-now",
#           "name": "Celerem Now",
#           "primary_role": "company",
#           "short_description": "Creating predictive analytic technology and integrated services to make same day delivery a reality for all vendors",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694609/he6rnvjce2775r8eqrv7.jpg",
#           "domain": "celeremnow.com",
#           "homepage_url": "https://celeremnow.com",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694921,
#           "updated_at": 1503695047
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "e9fc61af678adab8f877dab04cfe4ab4",
#         "properties": {
#           "permalink": "linksys-routerl-1-855-770-7740-linksys-router-help-desk-phone-number",
#           "api_path": "organizations/linksys-routerl-1-855-770-7740-linksys-router-help-desk-phone-number",
#           "web_path": "organization/linksys-routerl-1-855-770-7740-linksys-router-help-desk-phone-number",
#           "name": "Linksys routerl (1 _855 _770_7740)@ Linksys router help desk phone number",
#           "primary_role": "company",
#           "short_description": "Linksys routerl (1 _855 _770_7740)@ Linksys router help desk phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694687/ptimcyurkuostlwbomlb.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694689,
#           "updated_at": 1503694716
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "e41351d7f39508169e8fad1cca0fc8de",
#         "properties": {
#           "permalink": "linksys-routerl-1-855-770-7740-linksys-router-phone-support",
#           "api_path": "organizations/linksys-routerl-1-855-770-7740-linksys-router-phone-support",
#           "web_path": "organization/linksys-routerl-1-855-770-7740-linksys-router-phone-support",
#           "name": "Linksys routerl (1 _855 _770_7740)@ Linksys router phone support",
#           "primary_role": "company",
#           "short_description": "Linksys routerl (1 _855 _770_7740)@ Linksys router phone support",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694651/d5fx8tgtisjdmayuyu8b.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694655,
#           "updated_at": 1503694721
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "3b6f609bc0b47a31550c4ebfccba334b",
#         "properties": {
#           "permalink": "contact-facebook-by-phone-1-855-580-1808-call-facebook-customer-service",
#           "api_path": "organizations/contact-facebook-by-phone-1-855-580-1808-call-facebook-customer-service",
#           "web_path": "organization/contact-facebook-by-phone-1-855-580-1808-call-facebook-customer-service",
#           "name": "Contact Facebook by phone@!!!@!!1(855)*580*(1808)\u2122 call facebook customer service",
#           "primary_role": "company",
#           "short_description": "Contact Facebook by phone@!!!@!!1(855)*580*(1808)\u2122 call facebook customer service",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694578/gkakzry6mcasqautsn9l.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694583,
#           "updated_at": 1503694636
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "1bbfae8ee44aba7999b054d7f25bf318",
#         "properties": {
#           "permalink": "contact-facebook-by-phone-1-855-580-1808-contact-facebook-phone-number",
#           "api_path": "organizations/contact-facebook-by-phone-1-855-580-1808-contact-facebook-phone-number",
#           "web_path": "organization/contact-facebook-by-phone-1-855-580-1808-contact-facebook-phone-number",
#           "name": "Contact Facebook by phone@!!!@!!1(855)*580*(1808)\u2122 contact facebook phone number",
#           "primary_role": "company",
#           "short_description": "Contact Facebook by phone@!!!@!!1(855)*580*(1808)\u2122 contact facebook phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694559/kikuftxhbrujoj6zanx1.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694570,
#           "updated_at": 1503694632
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "aaaecd67b4ff8457448410b801abb705",
#         "properties": {
#           "permalink": "contact-facebook-1-855-580-1808-facebook-helpdesk-no-call-facebook-customer-service",
#           "api_path": "organizations/contact-facebook-1-855-580-1808-facebook-helpdesk-no-call-facebook-customer-service",
#           "web_path": "organization/contact-facebook-1-855-580-1808-facebook-helpdesk-no-call-facebook-customer-service",
#           "name": "Contact Facebook @!!!@!!1(855)*580*(1808)\u2122 facebook helpdesk no call facebook customer service",
#           "primary_role": "company",
#           "short_description": "Contact Facebook @!!!@!!1(855)*580*(1808)\u2122 facebook helpdesk no call facebook customer service",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694545/ivjsxpntkmoupfnxh6ei.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694553,
#           "updated_at": 1503694602
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "abe63b1b5fb565e721554a9004475090",
#         "properties": {
#           "permalink": "contact-facebook-by-phone-1-855-580-1808-facebook-services-phone-number-for-facebook-help",
#           "api_path": "organizations/contact-facebook-by-phone-1-855-580-1808-facebook-services-phone-number-for-facebook-help",
#           "web_path": "organization/contact-facebook-by-phone-1-855-580-1808-facebook-services-phone-number-for-facebook-help",
#           "name": "Contact Facebook by phone@!!!@!!1(855)*580*(1808)\u2122 facebook services phone number for facebook help",
#           "primary_role": "company",
#           "short_description": "Contact Facebook by phone@!!!@!!1(855)*580*(1808)\u2122 facebook services phone number for facebook help",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694520/qwcrbwyjr3ypcejm8q7f.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694522,
#           "updated_at": 1503694600
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "1feef8ed5e3ff357b23f67cfa3febf3f",
#         "properties": {
#           "permalink": "contact-facebook-by-phone-1-855-580-1808-facebook-help-desk-phone-number",
#           "api_path": "organizations/contact-facebook-by-phone-1-855-580-1808-facebook-help-desk-phone-number",
#           "web_path": "organization/contact-facebook-by-phone-1-855-580-1808-facebook-help-desk-phone-number",
#           "name": "Contact Facebook by phone@!!!@!!1(855)*580*(1808)\u2122 facebook help desk phone number",
#           "primary_role": "company",
#           "short_description": "Contact Facebook by phone@!!!@!!1(855)*580*(1808)\u2122 facebook help desk phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503694380/qnqreepxkcczsslqw6t4.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503694391,
#           "updated_at": 1503694413
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "f65eec9e61c6c5616dccee7f3b266f7f",
#         "properties": {
#           "permalink": "linksys-routerl-1-855-770-7740-linksys-router-help-center-phone-number",
# ...
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690622/b82kknqtwunkwv4bthxr.png",
#           "domain": "sigtec.com",
#           "homepage_url": "http://www.sigtec.com/",
#           "facebook_url": null,
#           "twitter_url": "https://twitter.com/sigtecgroup",
#           "linkedin_url": "https://www.linkedin.com/company-beta/85865/",
#           "city_name": "Braeside",
#           "region_name": "Victoria",
#           "country_code": "Australia",
#           "created_at": 1503690635,
#           "updated_at": 1503690987
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "2e77c446219904f3024c80c6ce87ad47",
#         "properties": {
#           "permalink": "how-to-contact-facebook-1-855-580-1808-contact-facebook-email-how-do-i-contact-facebook",
#           "api_path": "organizations/how-to-contact-facebook-1-855-580-1808-contact-facebook-email-how-do-i-contact-facebook",
#           "web_path": "organization/how-to-contact-facebook-1-855-580-1808-contact-facebook-email-how-do-i-contact-facebook",
#           "name": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 contact facebook email how do i contact facebook",
#           "primary_role": "company",
#           "short_description": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 contact facebook email how do i contact facebook",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690262/drywviwoiykgxnt9dwim.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690265,
#           "updated_at": 1503690265
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "e606be62ef606c19b5554f2d13860b06",
#         "properties": {
#           "permalink": "ruthinium-group",
#           "api_path": "organizations/ruthinium-group",
#           "web_path": "organization/ruthinium-group",
#           "name": "Ruthinium Group",
#           "primary_role": "company",
#           "short_description": "Ruthinium Group provides dental products and services.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690223/hs0rrfazy8t25orale0c.png",
#           "domain": "ruthinium.it",
#           "homepage_url": "http://www.ruthinium.it/",
#           "facebook_url": "https://www.facebook.com/pg/ruthinium/",
#           "twitter_url": "https://twitter.com/ruthinium",
#           "linkedin_url": "https://www.linkedin.com/company-beta/574456/",
#           "city_name": "Badia Polesine",
#           "region_name": "Veneto",
#           "country_code": "Italy",
#           "created_at": 1503690254,
#           "updated_at": 1503690449
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "534d07f54a13986f73198ae638207954",
#         "properties": {
#           "permalink": "lovethecool",
#           "api_path": "organizations/lovethecool",
#           "web_path": "organization/lovethecool",
#           "name": "LoveTheCool",
#           "primary_role": "company",
#           "short_description": "We build community for brands using strategy, photography, + creative direction.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690191/dz6wjemzjmsgmd1qzf0m.png",
#           "domain": "lovethecool.net",
#           "homepage_url": "http://lovethecool.net",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690223,
#           "updated_at": 1503690224
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "3576ca9571583791374e7596b8816c9e",
#         "properties": {
#           "permalink": "how-to-contact-facebook-1-855-580-1808-how-do-i-contact-facebook-phone-number-for-facebook",
#           "api_path": "organizations/how-to-contact-facebook-1-855-580-1808-how-do-i-contact-facebook-phone-number-for-facebook",
#           "web_path": "organization/how-to-contact-facebook-1-855-580-1808-how-do-i-contact-facebook-phone-number-for-facebook",
#           "name": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 how do i contact facebook phone number for facebook",
#           "primary_role": "company",
#           "short_description": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 how do i contact facebook phone number for facebook",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690209,
#           "updated_at": 1503690250
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "2f37dea002be9456911b2abf320556af",
#         "properties": {
#           "permalink": "how-to-contact-facebook-1-855-580-1808-facebook-technical-support-phone-number",
#           "api_path": "organizations/how-to-contact-facebook-1-855-580-1808-facebook-technical-support-phone-number",
#           "web_path": "organization/how-to-contact-facebook-1-855-580-1808-facebook-technical-support-phone-number",
#           "name": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook technical support phone number",
#           "primary_role": "company",
#           "short_description": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook technical support phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690179/lnulergx7b2ngd8vtlbi.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690193,
#           "updated_at": 1503690242
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "4b6ee847f46da4dad4029b4748b815cd",
#         "properties": {
#           "permalink": "how-to-contact-facebook-1-855-580-1808-facebook-helpdesk-number-facebook-support-email",
#           "api_path": "organizations/how-to-contact-facebook-1-855-580-1808-facebook-helpdesk-number-facebook-support-email",
#           "web_path": "organization/how-to-contact-facebook-1-855-580-1808-facebook-helpdesk-number-facebook-support-email",
#           "name": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook helpdesk number facebook support email",
#           "primary_role": "company",
#           "short_description": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook helpdesk number facebook support email",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690174/fjlul3tixo5cksekwdss.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690177,
#           "updated_at": 1503690371
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "0a9d349cd6b95c172397b9e81cabfb5f",
#         "properties": {
#           "permalink": "how-to-contact-facebook-1-855-580-1808-facebook-support-email-facebook-help-phone-number",
#           "api_path": "organizations/how-to-contact-facebook-1-855-580-1808-facebook-support-email-facebook-help-phone-number",
#           "web_path": "organization/how-to-contact-facebook-1-855-580-1808-facebook-support-email-facebook-help-phone-number",
#           "name": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook support email facebook help phone number",
#           "primary_role": "company",
#           "short_description": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook support email facebook help phone number",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690173,
#           "updated_at": 1503690239
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "b515079e878a65d97c453a9ca66a5e76",
#         "properties": {
#           "permalink": "how-to-contact-facebook-1-855-580-1808-facebook-help-phone-number-facebook-help-email",
#           "api_path": "organizations/how-to-contact-facebook-1-855-580-1808-facebook-help-phone-number-facebook-help-email",
#           "web_path": "organization/how-to-contact-facebook-1-855-580-1808-facebook-help-phone-number-facebook-help-email",
#           "name": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook help phone number facebook help email",
#           "primary_role": "company",
#           "short_description": "How To Contact Facebook@!!!@!!1(855)*580*(1808)\u2122 facebook help phone number facebook help email",
#           "profile_image_url": null,
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690166,
#           "updated_at": 1503690235
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "fe9e9cfe3d2c6c41a935dab0d3473257",
#         "properties": {
#           "permalink": "microsoft-office-2016l-x420-1-855-770-7740-phone-number-for-microsoft-office-2016",
#           "api_path": "organizations/microsoft-office-2016l-x420-1-855-770-7740-phone-number-for-microsoft-office-2016",
#           "web_path": "organization/microsoft-office-2016l-x420-1-855-770-7740-phone-number-for-microsoft-office-2016",
#           "name": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ phone number for Microsoft office 2016",
#           "primary_role": "company",
#           "short_description": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ phone number for Microsoft office 2016",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690110/nezfaoski0vzzc0ahx85.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690114,
#           "updated_at": 1503690220
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "a6757d91d7103bd0e5e9b00f7a4c6cab",
#         "properties": {
#           "permalink": "microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-technical-support",
#           "api_path": "organizations/microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-technical-support",
#           "web_path": "organization/microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-technical-support",
#           "name": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ Microsoft office 2016 technical support",
#           "primary_role": "company",
#           "short_description": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ Microsoft office 2016 technical support phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690098/oxp9jl9l8yudy8vvcw5i.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690106,
#           "updated_at": 1503690215
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "9ed82220b1d432b95702ea57c2c35deb",
#         "properties": {
#           "permalink": "microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-helpdesk-number",
#           "api_path": "organizations/microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-helpdesk-number",
#           "web_path": "organization/microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-helpdesk-number",
#           "name": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ Microsoft office 2016 helpdesk number",
#           "primary_role": "company",
#           "short_description": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ Microsoft office 2016 helpdesk number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690091/usmk2u5mbia5ldhufqib.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690093,
#           "updated_at": 1503690211
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "2c7e8c3c56cb1f5041e6dc70a1e58e60",
#         "properties": {
#           "permalink": "microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-support-email",
#           "api_path": "organizations/microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-support-email",
#           "web_path": "organization/microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-support-email",
#           "name": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ Microsoft office 2016 support email",
#           "primary_role": "company",
#           "short_description": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ Microsoft office 2016 support email",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690066/rmoaa1ti3vfjlxjiyrpi.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690087,
#           "updated_at": 1503690208
#         }
#       },
#       {
#         "type": "OrganizationSummary",
#         "uuid": "286e548b82771ffdfbfcf8430c346534",
#         "properties": {
#           "permalink": "microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-help-phone-number",
#           "api_path": "organizations/microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-help-phone-number",
#           "web_path": "organization/microsoft-office-2016l-x420-1-855-770-7740-microsoft-office-2016-help-phone-number",
#           "name": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ Microsoft office 2016 help phone number",
#           "primary_role": "company",
#           "short_description": "Microsoft office 2016l!!\u2122~$X\u0305420'==@(1 _855 _770_7740)@ Microsoft office 2016 help phone number",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503690055/cjuesashhchxapfkikzc.png",
#           "domain": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503690059,
#           "updated_at": 1503690205
#         }
#       }
#     ]
#   }
# }.
# org_json keys:  dict_keys(['metadata', 'data'])
# 2

# %%
#creates a new dataframe that's empty
org_df = pd.DataFrame() 
org_df["name"] = ""
org_df["short_description"] = ""
org_df["homepage_url"] = ""
org_df["uuid"] = ""

index = 0

#org_json["data"]["items"][0 ]["properties"]["name"]
#print(len(org_json["data"]["paging"]))
#print(len(org_json["data"]["items"]))
#print(org_json["data"]["paging"])
#print(org_json["data"]["items"])
#print(len(org_json["data"]["items"]))

# Created my api key for Crunchbase
url = "https://api.crunchbase.com/v/3/odm-organizations?user_key="
api_key = "8a3efb5b5136f95bff0593ebb94994e3"

# get 10 pages of org items
for x in range(1,11):
    # Build query URL
    query_url = url + api_key + "&page=" + str(x)
    # Get Crunchbase data
    org_json = req.get(query_url).json()
    print(query_url)

    # Loop through a page of items 
    for i in range(0,len(people_json["data"]["items"])):
        # Save the user class info into variables
        oname  = org_json["data"]["items"][i]["properties"]["name"]
        sdesc  = org_json["data"]["items"][i]["properties"]["short_description"]
        hp_url = org_json["data"]["items"][i]["properties"]["homepage_url"]
        ouuid  = org_json["data"]["items"][i]["uuid"]
               
        # Set the cell info for Real Name, Tweets, Followers, Following, Favorites Count
        org_df.set_value(index, "name", oname)
        org_df.set_value(index, "short_description", sdesc)
        org_df.set_value(index, "homepage_url", hp_url)
        org_df.set_value(index, "uuid", ouuid)
        index += 1

org_df.sort_values("uuid")    
org_df.head(10)
# Out:
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=1
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=2
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=3
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=4
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=5
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=6
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=7
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=8
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=9
# https://api.crunchbase.com/v/3/odm-organizations?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=10
#                             name  \
# 0                  Doer Services
# 1                    Bovlabs Inc
# 2                   HalberdCross
# 3        Resconte Capital GP LLC
# 4                 BabySparks LLC
# 5               HACKING THE CORE
# 6          Palm Creek University
# 7                 regulusia Inc.
# 8  South East Pacific University
# 9                        Bluebox
#
#                                    short_description  \
# 0                   Doers - On-Demand and as Desired
# 1  Empowering community for self-reliant energy b...
# 2                            Venture Investment Firm
# 3                     Private Equity Holding Vehicle
# 4  We build tools and programs to help parents en...
# 5  Book series about technology startups and Sili...
# 6  Palm Creek University is a comprehensive unive...
# 7                      Ecommerce Marketplace Fintech
# 8  Southeast Pacific University is an institution...
# 9                               We build blue boxes.
#
#                                         homepage_url  \
# 0                        http://www.doerservices.com
# 1                             http://www.bovlabs.com
# 2                           http://halberdcross.com/
# 3                                               None
# 4                             http://babysparks.com/
# 5  https://itunes.apple.com/us/book/hacking-the-c...
# 6                http://www.palmcreekuniversity.com/
# 7                          https://www.regulusia.com
# 8          http://www.southeastpacificuniversity.com
# 9                                https://bluebox.io/
#
#                                uuid
# 0  b835be4b3408d2ab7a3e2c354cde3a30
# 1  ba6475aa360f4a6933be300bda5c4a35
# 2  fc529aadcbbabee0a6e58f1f74351fc3
# 3  efb36dde21a8722868bdc4c2d28cdbca
# 4  4f2106e951327d0eea8e1d2550e8f7c7
# 5  52f30ed723259b995d80227c9981d01e
# 6  4145c1a3a1690713187359b5312905e7
# 7  4028de914ee73b414682d2f87bf32533
# 8  93538f8726e8fb05034c5521d34c35e9
# 9  e6e0537cc56b0ee5d679966c2e001f33

# %%
print(len(org_df.index))
# Out:
# 1000

# %%
## odm-people  Single request to view json structure
## Basic request.get to https://api.crunchbase.com/v/3/odm-people?
import json
import requests as req

# Created my api key for Crunchbase
url = "https://api.crunchbase.com/v/3/odm-people?user_key="
api_key = "8a3efb5b5136f95bff0593ebb94994e3"

# Build query URL
query_url = url + api_key

# Get weather data
people_json = req.get(query_url).json()

# Get the temperature from the response
print("The Crunchbase API responded with: " + json.dumps(people_json, indent=2) + ".")
print("people_json keys: ", people_json.keys())
print(len(people_json))
# Out:
# The Crunchbase API responded with: {
#   "metadata": {
#     "version": 3,
#     "www_path_prefix": "https://www.crunchbase.com",
#     "api_path_prefix": "https://api.crunchbase.com",
#     "image_path_prefix": "http://public.crunchbase.com/t_api_images/"
#   },
#   "data": {
#     "paging": {
#       "total_items": 659990,
#       "number_of_pages": 6600,
#       "current_page": 1,
#       "sort_order": "created_at DESC",
#       "items_per_page": 100,
#       "next_page_url": "https://api.crunchbase.com/v/3/people?page=2",
#       "prev_page_url": null
#     },
#     "items": [
#       {
#         "type": "Person",
#         "uuid": "342b705176c2ea4544fe5d1c76c06791",
#         "properties": {
#           "permalink": "howard-chiao",
#           "api_path": "people/howard-chiao",
#           "web_path": "person/howard-chiao",
#           "first_name": "Howard",
#           "last_name": "Chiao",
#           "gender": "Not Provided",
#           "title": "Director of Product",
#           "organization_permalink": "savings-com",
#           "organization_api_path": "organizations/savings-com",
#           "organization_web_path": "organization/savings-com",
#           "organization_name": "Savings.com",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Los Angeles",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503709864,
#           "updated_at": 1503709864
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "f9b96c0e4cb3acf1d30e4a504954c315",
#         "properties": {
#           "permalink": "james-tu",
#           "api_path": "people/james-tu",
#           "web_path": "person/james-tu",
#           "first_name": "James",
#           "last_name": "Tu",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503706805,
#           "updated_at": 1503706805
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "56c96efb15967def19764159317bb08c",
#         "properties": {
#           "permalink": "izak-mutlu",
#           "api_path": "people/izak-mutlu",
#           "web_path": "person/izak-mutlu",
#           "first_name": "Izak",
#           "last_name": "Mutlu",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503706709,
#           "updated_at": 1503706709
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "33d019bfa25a03d54cddab76b21d8a79",
#         "properties": {
#           "permalink": "steve-shead",
#           "api_path": "people/steve-shead",
#           "web_path": "person/steve-shead",
#           "first_name": "Steve",
#           "last_name": "Shead",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503706582,
#           "updated_at": 1503706582
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "a5ef052e8d500f5055ff0405d5311a9f",
#         "properties": {
#           "permalink": "randy-barr",
#           "api_path": "people/randy-barr",
#           "web_path": "person/randy-barr",
#           "first_name": "Randy",
#           "last_name": "Barr",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503706519,
#           "updated_at": 1503706519
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "57fa4fc1df8899564e0ef520a7f08c64",
#         "properties": {
#           "permalink": "anupam-sahai",
#           "api_path": "people/anupam-sahai",
#           "web_path": "person/anupam-sahai",
#           "first_name": "Anupam",
#           "last_name": "Sahai",
#           "gender": "Male",
#           "title": "VP Product Management",
#           "organization_permalink": "cavirin-systems",
#           "organization_api_path": "organizations/cavirin-systems",
#           "organization_web_path": "organization/cavirin-systems",
#           "organization_name": "Cavirin Systems",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503706105/bbjq2bgtjhnob2dsxnwd.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503706131,
#           "updated_at": 1503706131
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "d17c4ee5205aad52cf29406156e55016",
#         "properties": {
#           "permalink": "jerry-liu-3",
#           "api_path": "people/jerry-liu-3",
#           "web_path": "person/jerry-liu-3",
#           "first_name": "Jerry",
#           "last_name": "Liu",
#           "gender": "Male",
#           "title": "Mobile Development",
#           "organization_permalink": "tradove-inc",
#           "organization_api_path": "organizations/tradove-inc",
#           "organization_web_path": "organization/tradove-inc",
#           "organization_name": "TraDove, Inc.",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503705209,
#           "updated_at": 1503705209
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "831b3bf3cc40e9d5aadf45aa483ff818",
#         "properties": {
#           "permalink": "thomas-zheng",
#           "api_path": "people/thomas-zheng",
#           "web_path": "person/thomas-zheng",
#           "first_name": "Thomas",
#           "last_name": "Zheng",
#           "gender": "Male",
#           "title": "Product Development",
#           "organization_permalink": "tradove-inc",
#           "organization_api_path": "organizations/tradove-inc",
#           "organization_web_path": "organization/tradove-inc",
#           "organization_name": "TraDove, Inc.",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503705147,
#           "updated_at": 1503705147
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "33884bef0a3e99fcf9b30e810fe4ba33",
#         "properties": {
#           "permalink": "rick-roux",
#           "api_path": "people/rick-roux",
#           "web_path": "person/rick-roux",
#           "first_name": "Rick",
#           "last_name": "Roux",
#           "gender": "Not Provided",
#           "title": "Web Marketing",
#           "organization_permalink": "tradove-inc",
#           "organization_api_path": "organizations/tradove-inc",
#           "organization_web_path": "organization/tradove-inc",
#           "organization_name": "TraDove, Inc.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503705096/tjiautrhzm4xfzxj07md.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503705107,
#           "updated_at": 1503705108
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "6330ee1401fb0e3edd0440b788bc60ed",
#         "properties": {
#           "permalink": "albert-wang-6",
#           "api_path": "people/albert-wang-6",
#           "web_path": "person/albert-wang-6",
#           "first_name": "Albert",
#           "last_name": "Wang",
#           "gender": "Male",
#           "title": "UX/UI Design",
#           "organization_permalink": "tradove-inc",
#           "organization_api_path": "organizations/tradove-inc",
#           "organization_web_path": "organization/tradove-inc",
#           "organization_name": "TraDove, Inc.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503704994/w5crivpx8josxyt9yhk5.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503705025,
#           "updated_at": 1503705025
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "02a8dfc59ae98f380e541108ed2bc158",
#         "properties": {
#           "permalink": "igor-gustincic",
#           "api_path": "people/igor-gustincic",
#           "web_path": "person/igor-gustincic",
#           "first_name": "Igor",
#           "last_name": "Gustincic",
#           "gender": "Not Provided",
#           "title": "Sales and Business Development, Europe",
#           "organization_permalink": "tradove-inc",
#           "organization_api_path": "organizations/tradove-inc",
#           "organization_web_path": "organization/tradove-inc",
#           "organization_name": "TraDove, Inc.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503704866/dhggnzqlsppceaqhdzbt.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503704897,
#           "updated_at": 1503704897
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "7766471a26e815f9f231012f47887e73",
#         "properties": {
#           "permalink": "george-cheng-2",
#           "api_path": "people/george-cheng-2",
#           "web_path": "person/george-cheng-2",
#           "first_name": "George",
#           "last_name": "Cheng",
#           "gender": "Male",
#           "title": "Infrastructure, Big Data, Security",
#           "organization_permalink": "tradove-inc",
#           "organization_api_path": "organizations/tradove-inc",
#           "organization_web_path": "organization/tradove-inc",
#           "organization_name": "TraDove, Inc.",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503704751/knnnehhrom2cm7iga3id.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503704782,
#           "updated_at": 1503704783
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "64ce81de487d5ee15e9f874bac90aa3c",
#         "properties": {
#           "permalink": "jeremy-starns",
#           "api_path": "people/jeremy-starns",
#           "web_path": "person/jeremy-starns",
#           "first_name": "Jeremy",
#           "last_name": "Starns",
#           "gender": "Male",
#           "title": "President",
#           "organization_permalink": "roz",
#           "organization_api_path": "organizations/roz",
#           "organization_web_path": "organization/roz",
#           "organization_name": "roz",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503703108/wlxvztgih1jqogpdyg8n.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503703130,
#           "updated_at": 1503703130
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "885d4795edb965ff1a331417a7a219f1",
#         "properties": {
#           "permalink": "john-miller-21",
#           "api_path": "people/john-miller-21",
#           "web_path": "person/john-miller-21",
#           "first_name": "John",
#           "last_name": "Miller",
#           "gender": "Not Provided",
#           "title": "Co-Founder",
#           "organization_permalink": "fluxa",
#           "organization_api_path": "organizations/fluxa",
#           "organization_web_path": "organization/fluxa",
#           "organization_name": "Fluxa",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Los Angeles",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503701758,
#           "updated_at": 1503701758
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "3c3a8ba20f096ebc35097fae06448506",
#         "properties": {
#           "permalink": "thomas-scott-2",
#           "api_path": "people/thomas-scott-2",
#           "web_path": "person/thomas-scott-2",
#           "first_name": "Thomas",
#           "last_name": "Scott",
#           "gender": "Male",
#           "title": "Counsel",
#           "organization_permalink": "cruise",
#           "organization_api_path": "organizations/cruise",
#           "organization_web_path": "organization/cruise",
#           "organization_name": "Cruise Automation",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503701455/tbmojcowyr96rl9m8pas.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "San Francisco",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503701517,
#           "updated_at": 1503701517
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "e6905a6538ecc979de0250fd65a0a71c",
#         "properties": {
#           "permalink": "suraj-pai",
#           "api_path": "people/suraj-pai",
#           "web_path": "person/suraj-pai",
#           "first_name": "Suraj",
#           "last_name": "Pai",
#           "gender": "Not Provided",
#           "title": "Co-Founder",
#           "organization_permalink": "fluxa",
#           "organization_api_path": "organizations/fluxa",
#           "organization_web_path": "organization/fluxa",
#           "organization_name": "Fluxa",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503701363/yiudrlextkw6nguqxczj.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Los Angeles",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503701397,
#           "updated_at": 1503701397
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "1ea42adb660b07709e4baffece195547",
#         "properties": {
#           "permalink": "jonathan-falker",
#           "api_path": "people/jonathan-falker",
#           "web_path": "person/jonathan-falker",
#           "first_name": "Jonathan",
#           "last_name": "Falker",
#           "gender": "Male",
#           "title": "Director of Lifecycle Marketing",
#           "organization_permalink": "homesuite",
#           "organization_api_path": "organizations/homesuite",
#           "organization_web_path": "organization/homesuite",
#           "organization_name": "Homesuite",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503701315/ovihwjkcnva26zvadnt1.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "San Francisco",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503701379,
#           "updated_at": 1503701952
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "7954b283f62651d9aa79b7813e7eded7",
#         "properties": {
#           "permalink": "gavan-stewart-2",
#           "api_path": "people/gavan-stewart-2",
#           "web_path": "person/gavan-stewart-2",
#           "first_name": "Gavan",
#           "last_name": "Stewart",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Melbourne",
#           "region_name": "Victoria",
#           "country_code": "AUS",
#           "created_at": 1503701234,
#           "updated_at": 1503701234
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "09183065f83e8464f70f5b013974e6e5",
#         "properties": {
#           "permalink": "ash-farrugia",
#           "api_path": "people/ash-farrugia",
#           "web_path": "person/ash-farrugia",
#           "first_name": "Ash",
#           "last_name": "Farrugia",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Melbourne",
#           "region_name": "Victoria",
#           "country_code": "AUS",
#           "created_at": 1503701160,
#           "updated_at": 1503701160
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "19a6c1bd7038598fbd24dbce33719a42",
#         "properties": {
#           "permalink": "luis-medeiros",
#           "api_path": "people/luis-medeiros",
#           "web_path": "person/luis-medeiros",
#           "first_name": "Lu\u00eds",
#           "last_name": "Medeiros",
#           "gender": "Male",
#           "title": "Co-founder & CMO",
#           "organization_permalink": "shuteye",
#           "organization_api_path": "organizations/shuteye",
#           "organization_web_path": "organization/shuteye",
#           "organization_name": "Shuteye",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Lisboa",
#           "region_name": "Lisboa",
#           "country_code": "PRT",
#           "created_at": 1503699672,
#           "updated_at": 1503699672
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "d4a283b96b9d2ed042f9185f3b5c5d0c",
#         "properties": {
#           "permalink": "steve-gustafson",
#           "api_path": "people/steve-gustafson",
#           "web_path": "person/steve-gustafson",
#           "first_name": "Steve",
#           "last_name": "Gustafson",
#           "gender": "Not Provided",
#           "title": "Chief Scientist",
#           "organization_permalink": "maana",
#           "organization_api_path": "organizations/maana",
#           "organization_web_path": "organization/maana",
#           "organization_name": "Maana",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503699234/ji0mvzkoaair0gmdhx6o.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Bellevue",
#           "region_name": "Washington",
#           "country_code": "USA",
#           "created_at": 1503699288,
#           "updated_at": 1503699288
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "8e50443a0ce0c2ef4678af3bae1cda84",
#         "properties": {
#           "permalink": "talya-elitzer",
#           "api_path": "people/talya-elitzer",
#           "web_path": "person/talya-elitzer",
#           "first_name": "Talya",
#           "last_name": "Elitzer",
#           "gender": "Female",
#           "title": "Co-Founder, CEO",
#           "organization_permalink": "bounce-3",
#           "organization_api_path": "organizations/bounce-3",
#           "organization_web_path": "organization/bounce-3",
#           "organization_name": "Bounce",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503699045/llftoctpfshnukg1ph7c.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Los Angeles",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503699054,
#           "updated_at": 1503699054
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "611770044dde69afed8392a1c5b78495",
#         "properties": {
#           "permalink": "nick-sylvester",
#           "api_path": "people/nick-sylvester",
#           "web_path": "person/nick-sylvester",
#           "first_name": "Nick",
#           "last_name": "Sylvester",
#           "gender": "Male",
#           "title": "Co-Founder, CCO",
#           "organization_permalink": "bounce-3",
#           "organization_api_path": "organizations/bounce-3",
#           "organization_web_path": "organization/bounce-3",
#           "organization_name": "Bounce",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503699109/zqfqkxstzgsvveyoq0qe.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Los Angeles",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503698966,
#           "updated_at": 1503699113
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "ee947a4459a331f4f1f9b1196ba2ae60",
#         "properties": {
#           "permalink": "raquel-fernandes",
#           "api_path": "people/raquel-fernandes",
#           "web_path": "person/raquel-fernandes",
#           "first_name": "Raquel",
#           "last_name": "Fernandes",
#           "gender": "Female",
#           "title": "Co-founder & Legal",
#           "organization_permalink": "shuteye",
#           "organization_api_path": "organizations/shuteye",
#           "organization_web_path": "organization/shuteye",
#           "organization_name": "Shuteye",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Lisbon",
#           "region_name": "Lisboa",
#           "country_code": "PRT",
#           "created_at": 1503698939,
#           "updated_at": 1503698939
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "b373454db2ab47e1fee4576a0ceec7f6",
#         "properties": {
#           "permalink": "azita-martin-3",
#           "api_path": "people/azita-martin-3",
#           "web_path": "person/azita-martin-3",
#           "first_name": "Azita",
#           "last_name": "Martin",
#           "gender": "Not Provided",
#           "title": "Chief Marketing Officer",
#           "organization_permalink": "maana",
#           "organization_api_path": "organizations/maana",
#           "organization_web_path": "organization/maana",
#           "organization_name": "Maana",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503698869/clqsbfrql9pwtf2vwalm.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Palo Alto",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503698886,
#           "updated_at": 1503698886
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "655eda867e239a7e36ec6351b50b4135",
#         "properties": {
#           "permalink": "len-emmick-2",
#           "api_path": "people/len-emmick-2",
#           "web_path": "person/len-emmick-2",
#           "first_name": "Len",
#           "last_name": "Emmick",
#           "gender": "Not Provided",
#           "title": "Chief Sales Officer",
#           "organization_permalink": "maana",
#           "organization_api_path": "organizations/maana",
#           "organization_web_path": "organization/maana",
#           "organization_name": "Maana",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503698671/elhggrtslpa6hgubgedy.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Palo Alto",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503698755,
#           "updated_at": 1503698756
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "64a72544c9a2a05d2875cbb263ead161",
#         "properties": {
#           "permalink": "francois-schuers",
#           "api_path": "people/francois-schuers",
#           "web_path": "person/francois-schuers",
#           "first_name": "Francois",
#           "last_name": "Schuers",
#           "gender": "Not Provided",
#           "title": "Co-founder",
#           "organization_permalink": "beemble-2",
#           "organization_api_path": "organizations/beemble-2",
#           "organization_web_path": "organization/beemble-2",
#           "organization_name": "Beemble",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503701409/tzv8khq9o0enxkbmabor.jpg",
#           "homepage_url": "http://beemble.com/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/francoisschuers/",
#           "city_name": "Paris",
#           "region_name": "Ile-de-France",
#           "country_code": "FRA",
#           "created_at": 1503697617,
#           "updated_at": 1503702780
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "853601d85ecef1cf211caa74a4b3d25f",
#         "properties": {
#           "permalink": "romain-pierre-cacheux",
#           "api_path": "people/romain-pierre-cacheux",
#           "web_path": "person/romain-pierre-cacheux",
#           "first_name": "Romain-Pierre",
#           "last_name": "Cacheux",
#           "gender": "Not Provided",
#           "title": "Co-founder",
#           "organization_permalink": "beemble-2",
#           "organization_api_path": "organizations/beemble-2",
#           "organization_web_path": "organization/beemble-2",
#           "organization_name": "Beemble",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503697458/cvowzzxn5dharll9i9qo.jpg",
#           "homepage_url": "http://beemble.com/",
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/rpcacheux/",
#           "city_name": "Melbourne",
#           "region_name": "Victoria",
#           "country_code": "AUS",
#           "created_at": 1503697517,
#           "updated_at": 1503702868
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "0722f2c129d016c2d888ebf8686e5782",
#         "properties": {
#           "permalink": "alan-contreras",
#           "api_path": "people/alan-contreras",
#           "web_path": "person/alan-contreras",
#           "first_name": "Alan",
#           "last_name": "Contreras",
#           "gender": "Male",
#           "title": "Software Engineer",
#           "organization_permalink": "underground-elephant",
#           "organization_api_path": "organizations/underground-elephant",
#           "organization_web_path": "organization/underground-elephant",
#           "organization_name": "Underground Elephant",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503697335/igs8tkgpoki80vmeabx1.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503697349,
#           "updated_at": 1503697350
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "78b986ce4b3aaa1cc173b731e528978d",
#         "properties": {
#           "permalink": "john-churchwell",
#           "api_path": "people/john-churchwell",
#           "web_path": "person/john-churchwell",
#           "first_name": "John",
#           "last_name": "Churchwell",
#           "gender": "Male",
#           "title": "Sr. Quality Assurance Engineer",
#           "organization_permalink": "underground-elephant",
#           "organization_api_path": "organizations/underground-elephant",
#           "organization_web_path": "organization/underground-elephant",
#           "organization_name": "Underground Elephant",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503697246/wzf92o5oveqgcla4kpxq.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "San Diego",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503697273,
#           "updated_at": 1503697274
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "521ce51290888905f675b33262255c5f",
#         "properties": {
#           "permalink": "armando-castenada",
#           "api_path": "people/armando-castenada",
#           "web_path": "person/armando-castenada",
#           "first_name": "Armando",
#           "last_name": "Castenada",
#           "gender": "Female",
#           "title": "Client Support Specialist",
#           "organization_permalink": "underground-elephant",
#           "organization_api_path": "organizations/underground-elephant",
#           "organization_web_path": "organization/underground-elephant",
#           "organization_name": "Underground Elephant",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "San Diego",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503697139,
#           "updated_at": 1503697139
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "19b62f5c76cda34dc6a8b6f922daf969",
#         "properties": {
#           "permalink": "kevin-cho-5",
#           "api_path": "people/kevin-cho-5",
#           "web_path": "person/kevin-cho-5",
#           "first_name": "Kevin",
#           "last_name": "Cho",
#           "gender": "Male",
#           "title": "Manager, Sales Operatios",
#           "organization_permalink": "underground-elephant",
#           "organization_api_path": "organizations/underground-elephant",
#           "organization_web_path": "organization/underground-elephant",
#           "organization_name": "Underground Elephant",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503696703/ued1h9goj87q51zlowgc.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "San Diego",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503696970,
#           "updated_at": 1503696970
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "43f041b366716bae933633fc2840e259",
#         "properties": {
#           "permalink": "mike-ott",
#           "api_path": "people/mike-ott",
#           "web_path": "person/mike-ott",
#           "first_name": "Mike",
#           "last_name": "Ott",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503696628,
#           "updated_at": 1503696628
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "48e0c702edd2c6bb0465dc6800fc8573",
#         "properties": {
#           "permalink": "gregory-stavrou",
#           "api_path": "people/gregory-stavrou",
#           "web_path": "person/gregory-stavrou",
#           "first_name": "Gregory",
#           "last_name": "Stavrou",
#           "gender": "Male",
#           "title": "Finance",
#           "organization_permalink": "my-bodega-online",
#           "organization_api_path": "organizations/my-bodega-online",
#           "organization_web_path": "organization/my-bodega-online",
#           "organization_name": "My Bodega Online",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Miami",
#           "region_name": "Florida",
#           "country_code": "USA",
#           "created_at": 1503696341,
#           "updated_at": 1503696341
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "0240ebb2b1f53d97806d54b82e1ec364",
#         "properties": {
#           "permalink": "patrick-carreon",
#           "api_path": "people/patrick-carreon",
#           "web_path": "person/patrick-carreon",
#           "first_name": "Patrick",
#           "last_name": "Carreon",
#           "gender": "Male",
#           "title": "Senior Software Engineer",
#           "organization_permalink": "underground-elephant",
#           "organization_api_path": "organizations/underground-elephant",
#           "organization_web_path": "organization/underground-elephant",
#           "organization_name": "Underground Elephant",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503696036/x888rdiou4fuzgiuvlhy.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503696273,
#           "updated_at": 1503696273
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "429a256b28cb3e4bf96614b443cc6edc",
#         "properties": {
#           "permalink": "rahi-islam",
#           "api_path": "people/rahi-islam",
#           "web_path": "person/rahi-islam",
#           "first_name": "Rahi",
#           "last_name": "Islam",
#           "gender": "Male",
#           "title": "Asian Markets",
#           "organization_permalink": "my-bodega-online",
#           "organization_api_path": "organizations/my-bodega-online",
#           "organization_web_path": "organization/my-bodega-online",
#           "organization_name": "My Bodega Online",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": "SGP",
#           "created_at": 1503695758,
#           "updated_at": 1503695758
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "4784260a69766ba6e1495010fea4b29f",
#         "properties": {
#           "permalink": "freddy-restrepo",
#           "api_path": "people/freddy-restrepo",
#           "web_path": "person/freddy-restrepo",
#           "first_name": "Freddy",
#           "last_name": "Restrepo",
#           "gender": "Male",
#           "title": "New York Market",
#           "organization_permalink": "my-bodega-online",
#           "organization_api_path": "organizations/my-bodega-online",
#           "organization_web_path": "organization/my-bodega-online",
#           "organization_name": "My Bodega Online",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "New York",
#           "region_name": "New York",
#           "country_code": "USA",
#           "created_at": 1503695682,
#           "updated_at": 1503695682
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "80d2e039d23fba94b300ce26e0d49907",
#         "properties": {
#           "permalink": "elder-crisostomo",
#           "api_path": "people/elder-crisostomo",
#           "web_path": "person/elder-crisostomo",
#           "first_name": "Elder",
#           "last_name": "Crisostomo",
#           "gender": "Male",
#           "title": "Senior Software Engineer",
#           "organization_permalink": "my-bodega-online",
#           "organization_api_path": "organizations/my-bodega-online",
#           "organization_web_path": "organization/my-bodega-online",
#           "organization_name": "My Bodega Online",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Miami",
#           "region_name": "Florida",
#           "country_code": "USA",
#           "created_at": 1503695623,
#           "updated_at": 1503695623
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "aa944cfd653845e18b15563e627faae6",
#         "properties": {
#           "permalink": "ebrima-fatty",
#           "api_path": "people/ebrima-fatty",
#           "web_path": "person/ebrima-fatty",
#           "first_name": "Ebrima",
#           "last_name": "Fatty",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503695921/eipfd0hzxpejnk8bkvwu.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Jeddah",
#           "region_name": "Makkah",
#           "country_code": "SAU",
#           "created_at": 1503695540,
#           "updated_at": 1503695928
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "06eef3e8eb1a60695c11a6ab5c0de52a",
#         "properties": {
#           "permalink": "ian-hadwin",
#           "api_path": "people/ian-hadwin",
#           "web_path": "person/ian-hadwin",
#           "first_name": "Ian",
#           "last_name": "Hadwin",
#           "gender": "Male",
#           "title": "CFO",
#           "organization_permalink": "tru-test-group",
#           "organization_api_path": "organizations/tru-test-group",
#           "organization_web_path": "organization/tru-test-group",
#           "organization_name": "Tru-Test Group",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503692334/nqpngurggjizcumziqpm.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/ian-hadwin-57858711/",
#           "city_name": "Auckland",
#           "region_name": "Auckland",
#           "country_code": "NZL",
#           "created_at": 1503692343,
#           "updated_at": 1503692358
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "7a471b48a7993d0702874f374aac1557",
#         "properties": {
#           "permalink": "greg-muir",
#           "api_path": "people/greg-muir",
#           "web_path": "person/greg-muir",
#           "first_name": "Greg",
#           "last_name": "Muir",
#           "gender": "Male",
#           "title": "Managing Director",
#           "organization_permalink": "tru-test-group",
#           "organization_api_path": "organizations/tru-test-group",
#           "organization_web_path": "organization/tru-test-group",
#           "organization_name": "Tru-Test Group",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503692211/jbudmob3drfnbrucxovw.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/greg-muir-b6174039/",
#           "city_name": "Auckland",
#           "region_name": "Auckland",
#           "country_code": "NZL",
#           "created_at": 1503692222,
#           "updated_at": 1503692266
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "54d3f64d75066c5b2d60a99ea9d54ebd",
#         "properties": {
#           "permalink": "kimberly-little",
#           "api_path": "people/kimberly-little",
#           "web_path": "person/kimberly-little",
#           "first_name": "Kimberly",
#           "last_name": "Little",
#           "gender": "Female",
#           "title": "Digital Marketing Manager",
#           "organization_permalink": "first-dry-clean-inc-3",
#           "organization_api_path": "organizations/first-dry-clean-inc-3",
#           "organization_web_path": "organization/first-dry-clean-inc-3",
#           "organization_name": "First Dry Clean, Inc.",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Charlotte",
#           "region_name": "North Carolina",
#           "country_code": "USA",
#           "created_at": 1503692154,
#           "updated_at": 1503692154
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "d671507f3ac16546a39940a2d85e5c60",
#         "properties": {
#           "permalink": "dan-maier-2",
#           "api_path": "people/dan-maier-2",
#           "web_path": "person/dan-maier-2",
#           "first_name": "Dan",
#           "last_name": "Maier",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503692113/h4usiba01k7kjgjm5go9.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503692117,
#           "updated_at": 1503692118
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "f37ea4ad784584402d72b549b398f227",
#         "properties": {
#           "permalink": "tenia-brown",
#           "api_path": "people/tenia-brown",
#           "web_path": "person/tenia-brown",
#           "first_name": "Tenia",
#           "last_name": "Brown",
#           "gender": "Female",
#           "title": "Sales Manager",
#           "organization_permalink": "first-dry-clean-inc-3",
#           "organization_api_path": "organizations/first-dry-clean-inc-3",
#           "organization_web_path": "organization/first-dry-clean-inc-3",
#           "organization_name": "First Dry Clean, Inc.",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Charlotte",
#           "region_name": "North Carolina",
#           "country_code": "USA",
#           "created_at": 1503691621,
#           "updated_at": 1503691621
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "baf14685488270496cd9480ad3e586c6",
#         "properties": {
#           "permalink": "bryan-bergstrom",
#           "api_path": "people/bryan-bergstrom",
#           "web_path": "person/bryan-bergstrom",
#           "first_name": "Bryan",
#           "last_name": "Bergstrom",
#           "gender": "Male",
#           "title": "Sales Director",
#           "organization_permalink": "first-dry-clean-inc-3",
#           "organization_api_path": "organizations/first-dry-clean-inc-3",
#           "organization_web_path": "organization/first-dry-clean-inc-3",
#           "organization_name": "First Dry Clean, Inc.",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Charlotte",
#           "region_name": "North Carolina",
#           "country_code": "USA",
#           "created_at": 1503691556,
#           "updated_at": 1503691556
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "fbbc40465f92aed92b0001fc28a9e360",
#         "properties": {
#           "permalink": "benjamin-seer",
#           "api_path": "people/benjamin-seer",
#           "web_path": "person/benjamin-seer",
#           "first_name": "Benjamin",
#           "last_name": "Seer",
#           "gender": "Male",
#           "title": "Founder & CEO",
#           "organization_permalink": "hummingbird-australia",
#           "organization_api_path": "organizations/hummingbird-australia",
#           "organization_web_path": "organization/hummingbird-australia",
#           "organization_name": "Hummingbird Australia",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503691514/f5c5rrhs81jqapmkkr1g.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/benjamin-seer-35643567/",
#           "city_name": "Berlin",
#           "region_name": "Berlin",
#           "country_code": "DEU",
#           "created_at": 1503691531,
#           "updated_at": 1503691546
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "a97bcaf34fe7ab6bd3304f6007f1afe5",
#         "properties": {
#           "permalink": "abby-reed-wheeler",
#           "api_path": "people/abby-reed-wheeler",
#           "web_path": "person/abby-reed-wheeler",
#           "first_name": "Abby",
#           "last_name": "Reed Wheeler",
#           "gender": "Female",
#           "title": "Director of Merchandising",
#           "organization_permalink": "the-tie-bar",
#           "organization_api_path": "organizations/the-tie-bar",
#           "organization_web_path": "organization/the-tie-bar",
#           "organization_name": "The Tie Bar",
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Chicago",
#           "region_name": "Illinois",
#           "country_code": "USA",
#           "created_at": 1503691523,
#           "updated_at": 1503691636
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "b2e0ffb8b0bbc255b41a821638c9df96",
#         "properties": {
#           "permalink": "adam-silverman",
#           "api_path": "people/adam-silverman",
#           "web_path": "person/adam-silverman",
#           "first_name": "Adam",
#           "last_name": "Silverman",
#           "gender": "Not Provided",
#           "title": "SVP Marketing",
#           "organization_permalink": "theatro",
#           "organization_api_path": "organizations/theatro",
# ...
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/peterworn/",
#           "city_name": "Melbourne",
#           "region_name": "Victoria",
#           "country_code": "AUS",
#           "created_at": 1503686023,
#           "updated_at": 1503686088
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "922bf9a9147a6de4cfa76c2f92f92a47",
#         "properties": {
#           "permalink": "jena-antrobus",
#           "api_path": "people/jena-antrobus",
#           "web_path": "person/jena-antrobus",
#           "first_name": "Jena",
#           "last_name": "Antrobus",
#           "gender": "Female",
#           "title": "Marketing Coordinator",
#           "organization_permalink": "enzumo",
#           "organization_api_path": "organizations/enzumo",
#           "organization_web_path": "organization/enzumo",
#           "organization_name": "Enzumo",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685807/fi58qy6lcgjkt3eegviu.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/jenaantrobus/?lipi=urn%3Ali%3Apage%3Ad_flagship3_search_srp_people%3BZ9p0umhsR7ecHvh%2FCXph8Q%3D%3D&licu=urn%3Ali%3Acontrol%3Ad_flagship3_search_srp_people-search_srp_result",
#           "city_name": "Brisbane",
#           "region_name": "Queensland",
#           "country_code": "AUS",
#           "created_at": 1503685819,
#           "updated_at": 1503685885
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "815721cd75521a03b75acb820f260731",
#         "properties": {
#           "permalink": "aron-satchell",
#           "api_path": "people/aron-satchell",
#           "web_path": "person/aron-satchell",
#           "first_name": "Aron",
#           "last_name": "Satchell",
#           "gender": "Male",
#           "title": "Head of Operations",
#           "organization_permalink": "enzumo",
#           "organization_api_path": "organizations/enzumo",
#           "organization_web_path": "organization/enzumo",
#           "organization_name": "Enzumo",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685731/smskxtvrczvpgj0lerji.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/aronsatchell/?lipi=urn%3Ali%3Apage%3Ad_flagship3_search_srp_people%3BZ9p0umhsR7ecHvh%2FCXph8Q%3D%3D&licu=urn%3Ali%3Acontrol%3Ad_flagship3_search_srp_people-search_srp_result",
#           "city_name": "Brisbane",
#           "region_name": "Queensland",
#           "country_code": "AUS",
#           "created_at": 1503685752,
#           "updated_at": 1503685768
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "d5bf4e2ca7313e4ba69df07622439a12",
#         "properties": {
#           "permalink": "alex-rothwell",
#           "api_path": "people/alex-rothwell",
#           "web_path": "person/alex-rothwell",
#           "first_name": "Alex",
#           "last_name": "Rothwell",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685716/kzjgaonmbvnigsaer16v.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Victoria",
#           "region_name": "British Columbia",
#           "country_code": "CAN",
#           "created_at": 1503685747,
#           "updated_at": 1503685747
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "22355ff88c168653f1897cac19f047f4",
#         "properties": {
#           "permalink": "russell-howard",
#           "api_path": "people/russell-howard",
#           "web_path": "person/russell-howard",
#           "first_name": "Russell",
#           "last_name": "Howard",
#           "gender": "Male",
#           "title": "Executive Chairman",
#           "organization_permalink": "neuclone",
#           "organization_api_path": "organizations/neuclone",
#           "organization_web_path": "organization/neuclone",
#           "organization_name": "NeuClone",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685675/jyp4vcerbc2bytwmmral.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": "https://www.linkedin.com/in/russell-j-howard-36376416/",
#           "city_name": "Sydney",
#           "region_name": "New South Wales",
#           "country_code": "AUS",
#           "created_at": 1503685694,
#           "updated_at": 1503685733
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "0ac44ab636dec21912854ed6c9b7c975",
#         "properties": {
#           "permalink": "jean-leblond",
#           "api_path": "people/jean-leblond",
#           "web_path": "person/jean-leblond",
#           "first_name": "Jean",
#           "last_name": "Leblond",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685583/mbxxrr2mejeah1tawkph.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Montr\u00e9al",
#           "region_name": "Quebec",
#           "country_code": "CAN",
#           "created_at": 1503685614,
#           "updated_at": 1503685615
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "83d4a95e83fcfe827e61ae97a4da9e80",
#         "properties": {
#           "permalink": "mario-jacob",
#           "api_path": "people/mario-jacob",
#           "web_path": "person/mario-jacob",
#           "first_name": "Mario",
#           "last_name": "Jacob",
#           "gender": "Male",
#           "title": "Managing Director",
#           "organization_permalink": "ncp-capital-partners",
#           "organization_api_path": "organizations/ncp-capital-partners",
#           "organization_web_path": "organization/ncp-capital-partners",
#           "organization_name": "NCP Capital Partners",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685496/wlbjivkrgumb2wbarkag.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Quebec",
#           "region_name": "Quebec",
#           "country_code": "CAN",
#           "created_at": 1503685537,
#           "updated_at": 1503685538
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "9ef7efe87fda658ac7d9e955d552d501",
#         "properties": {
#           "permalink": "joe-boyle-2",
#           "api_path": "people/joe-boyle-2",
#           "web_path": "person/joe-boyle-2",
#           "first_name": "Joe",
#           "last_name": "Boyle",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503685475,
#           "updated_at": 1503685476
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "02984f5ac56d6c514a7042a1cf0a50db",
#         "properties": {
#           "permalink": "christian-gagnon",
#           "api_path": "people/christian-gagnon",
#           "web_path": "person/christian-gagnon",
#           "first_name": "Christian",
#           "last_name": "Gagnon",
#           "gender": "Male",
#           "title": "Managing Director & CIO",
#           "organization_permalink": "ncp-capital-partners",
#           "organization_api_path": "organizations/ncp-capital-partners",
#           "organization_web_path": "organization/ncp-capital-partners",
#           "organization_name": "NCP Capital Partners",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685413/l2nplyp6bfp7t85nnmh1.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Montr\u00e9al",
#           "region_name": "Quebec",
#           "country_code": "CAN",
#           "created_at": 1503685456,
#           "updated_at": 1503685457
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "da1a6e363c6e7bcbd28f4ab5f3925e2c",
#         "properties": {
#           "permalink": "jeff-wallace-3",
#           "api_path": "people/jeff-wallace-3",
#           "web_path": "person/jeff-wallace-3",
#           "first_name": "Jeff",
#           "last_name": "Wallace",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503685344,
#           "updated_at": 1503685344
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "2dc5c0c8e03b2d4369f668d939fd0225",
#         "properties": {
#           "permalink": "yan-wang-3",
#           "api_path": "people/yan-wang-3",
#           "web_path": "person/yan-wang-3",
#           "first_name": "Yan",
#           "last_name": "Wang",
#           "gender": "Female",
#           "title": "Senior Hardware Engineer",
#           "organization_permalink": "metawave-corporation",
#           "organization_api_path": "organizations/metawave-corporation",
#           "organization_web_path": "organization/metawave-corporation",
#           "organization_name": "Metawave Corporation",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685274/jcd9blwpmywkohizsygk.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Palo Alto",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503685289,
#           "updated_at": 1503685289
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "a6dad14989f40735cf01ecbed0cf8d29",
#         "properties": {
#           "permalink": "edwin-marcial",
#           "api_path": "people/edwin-marcial",
#           "web_path": "person/edwin-marcial",
#           "first_name": "Edwin",
#           "last_name": "Marcial",
#           "gender": "Not Provided",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685247/bkujxpwvgmrzjruli4vj.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503685273,
#           "updated_at": 1503685442
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "f94db23eb84f62e25aba5c92eca17105",
#         "properties": {
#           "permalink": "chiara-pelletti",
#           "api_path": "people/chiara-pelletti",
#           "web_path": "person/chiara-pelletti",
#           "first_name": "Chiara",
#           "last_name": "Pelletti",
#           "gender": "Female",
#           "title": "Senior Staff Engineer",
#           "organization_permalink": "metawave-corporation",
#           "organization_api_path": "organizations/metawave-corporation",
#           "organization_web_path": "organization/metawave-corporation",
#           "organization_name": "Metawave Corporation",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685204/flfwy9izotrkncjvpz2m.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Palo Alto",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503685235,
#           "updated_at": 1503685236
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "2d8ad253a33f257424ed763ee09e5c82",
#         "properties": {
#           "permalink": "jeremy-ward-2",
#           "api_path": "people/jeremy-ward-2",
#           "web_path": "person/jeremy-ward-2",
#           "first_name": "Jeremy",
#           "last_name": "Ward",
#           "gender": "Male",
#           "title": "Principal Engineer - Wireless Communications Systems",
#           "organization_permalink": "metawave-corporation",
#           "organization_api_path": "organizations/metawave-corporation",
#           "organization_web_path": "organization/metawave-corporation",
#           "organization_name": "Metawave Corporation",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685117/bcoxt3aynkjexabdxnbe.png",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "San Diego",
#           "region_name": "California",
#           "country_code": "USA",
#           "created_at": 1503685163,
#           "updated_at": 1503685164
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "8621547695b2fa60c12be3aba26e476e",
#         "properties": {
#           "permalink": "wade-luders",
#           "api_path": "people/wade-luders",
#           "web_path": "person/wade-luders",
#           "first_name": "Wade",
#           "last_name": "Luders",
#           "gender": "Male",
#           "title": null,
#           "organization_permalink": null,
#           "organization_api_path": "organizations/",
#           "organization_web_path": "organization/",
#           "organization_name": null,
#           "profile_image_url": null,
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": null,
#           "region_name": null,
#           "country_code": null,
#           "created_at": 1503685125,
#           "updated_at": 1503685126
#         }
#       },
#       {
#         "type": "Person",
#         "uuid": "fcca0d8eb794859b33db1b1d3f561ab5",
#         "properties": {
#           "permalink": "eric-silva-2",
#           "api_path": "people/eric-silva-2",
#           "web_path": "person/eric-silva-2",
#           "first_name": "Eric",
#           "last_name": "Silva",
#           "gender": "Not Provided",
#           "title": "Product Manager",
#           "organization_permalink": "google",
#           "organization_api_path": "organizations/google",
#           "organization_web_path": "organization/google",
#           "organization_name": "Google",
#           "profile_image_url": "http://public.crunchbase.com/t_api_images/v1503685108/rlack3yzlvw2xjs9iu9a.jpg",
#           "homepage_url": null,
#           "facebook_url": null,
#           "twitter_url": null,
#           "linkedin_url": null,
#           "city_name": "Boston",
#           "region_name": "Massachusetts",
#           "country_code": "USA",
#           "created_at": 1503685115,
#           "updated_at": 1503685467
#         }
#       }
#     ]
#   }
# }.
# people_json keys:  dict_keys(['metadata', 'data'])
# 2

# %%
#creates a new dataframe that's empty
people_df = pd.DataFrame() 
people_df["first_name"] = ""
people_df["last_name"] = ""
people_df["title"] = ""
people_df["organization_name"] = ""
people_df["uuid"] = ""

index = 0

# people_json["data"]["items"][0 ]["properties"]["first_name"]

# Created my api key for Crunchbase
url = "https://api.crunchbase.com/v/3/odm-people?user_key="
api_key = "8a3efb5b5136f95bff0593ebb94994e3"

# get 10 pages of people items
for x in range(1,11):
    # Build query URL
    query_url = url + api_key + "&page=" + str(x)
    # Get Crunchbase data
    people_json = req.get(query_url).json()
    print(query_url)

    # Loop through elements
    for i in range(0,len(people_json["data"]["items"])):
        # Save the user class info into variables
        fname  = people_json["data"]["items"][i]["properties"]["first_name"]
        lname  = people_json["data"]["items"][i]["properties"]["last_name"]
        ptitle = people_json["data"]["items"][i]["properties"]["title"]
        oname  = people_json["data"]["items"][i]["properties"]["organization_name"]
        puuid  = people_json["data"]["items"][i]["uuid"]
               
        # Set the cell info for Real Name, Tweets, Followers, Following, Favorites Count
        people_df.set_value(index, "first_name", fname)
        people_df.set_value(index, "last_name", lname)
        people_df.set_value(index, "title", ptitle)
        people_df.set_value(index, "organization_name", oname)
        people_df.set_value(index, "uuid", puuid)
        index += 1
    
people_df.sort_values("uuid")
people_df.head(10)
# Out:
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=1
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=2
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=3
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=4
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=5
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=6
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=7
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=8
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=9
# https://api.crunchbase.com/v/3/odm-people?user_key=8a3efb5b5136f95bff0593ebb94994e3&page=10
#   first_name last_name                  title organization_name  \
# 0     Howard     Chiao    Director of Product       Savings.com
# 1      James        Tu                   None              None
# 2       Izak     Mutlu                   None              None
# 3      Steve     Shead                   None              None
# 4      Randy      Barr                   None              None
# 5     Anupam     Sahai  VP Product Management   Cavirin Systems
# 6      Jerry       Liu     Mobile Development     TraDove, Inc.
# 7     Thomas     Zheng    Product Development     TraDove, Inc.
# 8       Rick      Roux          Web Marketing     TraDove, Inc.
# 9     Albert      Wang           UX/UI Design     TraDove, Inc.
#
#                                uuid
# 0  342b705176c2ea4544fe5d1c76c06791
# 1  f9b96c0e4cb3acf1d30e4a504954c315
# 2  56c96efb15967def19764159317bb08c
# 3  33d019bfa25a03d54cddab76b21d8a79
# 4  a5ef052e8d500f5055ff0405d5311a9f
# 5  57fa4fc1df8899564e0ef520a7f08c64
# 6  d17c4ee5205aad52cf29406156e55016
# 7  831b3bf3cc40e9d5aadf45aa483ff818
# 8  33884bef0a3e99fcf9b30e810fe4ba33
# 9  6330ee1401fb0e3edd0440b788bc60ed

# %%
print(len(people_df.index))
# Out:
# 1000
