# %%
##Dependencies
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime
import random as rd
np.random.seed(sum(map(ord, "aesthetics")))

##
## https://data.crunchbase.com/v3/reference - Crunchbase endpoint documenation
## 

## https://git-lfs.github.com/ GitHub Large file storage

# %%
## Read file and then sort 
## 
csv_file = "../Companies.csv"
companies_df = pd.read_csv(csv_file, encoding="iso-8859-1", 
                           parse_dates=["Founded Date","Closed Date","Last Funding Date"])
companies_df = companies_df.sort_values("Company Name").reset_index(drop=True)
print(len(companies_df.index))
companies_df.head(5)
# Out:
# 8664
#   Company Name                                   Company Name URL  \
# 0     #waywire    https://www.crunchbase.com/organization/waywire
# 1   *gram Labs  https://www.crunchbase.com/organization/gram-labs
# 2          .io  https://www.crunchbase.com/organization/io-rea...
# 3   /dev/color  https://www.crunchbase.com/organization/dev-color
# 4     10 By 10   https://www.crunchbase.com/organization/10-by-10
#
#                                      Category Groups  \
# 0  Media and Entertainment, Government and Milita...
# 1  Science and Engineering, Hardware, Data and An...
# 2                                 Data and Analytics
# 3                                                NaN
# 4                    Software, Professional Services
#
#                       Headquarters Location  \
# 0         New York, New York, United States
# 1         New York, New York, United States
# 2       Alexandria, Virginia, United States
# 3     Menlo Park, California, United States
# 4  San Francisco, California, United States
#
#                                          Description Crunchbase Rank  \
# 0  #waywire is an online community focused on soc...          21,987
# 1  GramLabs is a start up, leveraging deep learni...          11,897
# 2          .io is a real-time intelligence platform.          16,844
# 3  /dev/color is a non-profit organization that a...          35,003
# 4  10by10 builds a marketplace to more quickly ma...          59,822
#
#   Founded Date Closed Date  Number of Funding Rounds Last Funding Date  \
# 0   2012-06-01         NaT                         1        2012-06-30
# 1   2015-08-01         NaT                         1        2016-07-27
# 2   2015-03-01         NaT                         1        2015-10-01
# 3   2015-05-01         NaT                         1        2016-08-23
# 4   2015-01-01         NaT                         1        2017-07-01
#
#   Last Funding Amount Last Funding Type Total Funding Amount        Status
# 0         $1,750,000               Seed          $1,750,000   Was Acquired
# 1         $1,000,000               Seed          $1,000,000      Operating
# 2         $1,500,000               Seed          $1,500,000      Operating
# 3           $120,000               Seed            $120,000      Operating
# 4           $120,000               Seed            $120,000      Operating

# %%
# convert this to a number and fill NaN with zeros
#crunch_df["Number of Funding Rounds"] = crunch_df["Number of Funding Rounds"].fillna(value= 0).astype(int)


# convert these to a float - fails due to unreadable characters
companies_df["Last Funding Amount"] = companies_df["Last Funding Amount"].str.strip() \
                                                   .replace('[\$,]','', regex=True ).astype(np.float64)

# convert these to a float
companies_df["Total Funding Amount"] = companies_df["Total Funding Amount"].str.strip() \
                                                    .replace('[\$,]','', regex=True ).astype(np.float64)
companies_df
#print(len(companies_df.index))
# Out:
#                                 Company Name  \
# 0                                   #waywire
# 1                                 *gram Labs
# 2                                        .io
# 3                                 /dev/color
# 4                                   10 By 10
# 5                               10-4 Systems
# 6                               10X Genomics
# 7                                      10sec
# 8                                    12 Labs
# 9                                 121 Mobile
# 10                            128 Technology
# 11                                    17hats
# 12                                  18Angles
# 13                                    19Labs
# 14                              1CommMedical
# 15                                   1Huddle
# 16                                      1UPd
# 17                    2020 On-site Optometry
# 18                                       20n
# 19                                    21 Inc
# 20                                    23VIVI
# 21                                  27 Perry
# 22                                2Hat Media
# 23                                 2ULaundry
# 24                        30 Second Showcase
# 25                                   37coins
# 26                       3D Operations, Inc.
# 27                                 3D-SensIR
# 28                             3Derm Systems
# 29                                 3Diligent
# ...                                      ...
# 8634                                   uBack
# 8635                                  uBiome
# 8636                                   uMake
# 8637                                 uMix.TV
# 8638                                   uSens
# 8639                               udiospace
# 8640                                  unGlue
# 8641                              uniRow Inc
# 8642                               upurskill
# 8643                                   vDice
# 8644                                 venVelo
# 8645                                   vidIQ
# 8646                                    voie
# 8647                                vushaper
# 8648                                  walkby
# 8649                          weBounty, Inc.
# 8650                                wpXtreme
# 8651                             wrkbench.io
# 8652                        www.pixxpros.com
# 8653                                    x.ai
# 8654                                  xendit
# 8655                                     xiQ
# 8656                                  yaBeam
# 8657                                   yoPay
# 8658                               youarrive
# 8659                                zEconomy
# 8660  zPREDICTA (formerly Ixchel Scientific)
# 8661                                   zanda
# 8662                                 zipster
# 8663                                   zurvu
#
#                                        Company Name URL  \
# 0       https://www.crunchbase.com/organization/waywire
# 1     https://www.crunchbase.com/organization/gram-labs
# 2     https://www.crunchbase.com/organization/io-rea...
# 3     https://www.crunchbase.com/organization/dev-color
# 4      https://www.crunchbase.com/organization/10-by-10
# 5     https://www.crunchbase.com/organization/10-4-s...
# 6     https://www.crunchbase.com/organization/10x-ge...
# 7         https://www.crunchbase.com/organization/10sec
# 8       https://www.crunchbase.com/organization/12-labs
# 9     https://www.crunchbase.com/organization/121-mo...
# 10    https://www.crunchbase.com/organization/128-te...
# 11       https://www.crunchbase.com/organization/17hats
# 12     https://www.crunchbase.com/organization/18angles
# 13       https://www.crunchbase.com/organization/19labs
# 14    https://www.crunchbase.com/organization/1commm...
# 15    https://www.crunchbase.com/organization/sales-...
# 16         https://www.crunchbase.com/organization/1upd
# 17    https://www.crunchbase.com/organization/projec...
# 18          https://www.crunchbase.com/organization/20n
# 19         https://www.crunchbase.com/organization/21e6
# 20       https://www.crunchbase.com/organization/23vivi
# 21     https://www.crunchbase.com/organization/27-perry
# 22    https://www.crunchbase.com/organization/2hat-m...
# 23    https://www.crunchbase.com/organization/2u-lau...
# 24    https://www.crunchbase.com/organization/30-sec...
# 25      https://www.crunchbase.com/organization/37coins
# 26    https://www.crunchbase.com/organization/3d-ope...
# 27    https://www.crunchbase.com/organization/3d-sensir
# 28    https://www.crunchbase.com/organization/3derm-...
# 29    https://www.crunchbase.com/organization/3diligent
# ...                                                 ...
# 8634      https://www.crunchbase.com/organization/uback
# 8635     https://www.crunchbase.com/organization/ubiome
# 8636      https://www.crunchbase.com/organization/umake
# 8637    https://www.crunchbase.com/organization/umix-tv
# 8638  https://www.crunchbase.com/organization/usens-...
# 8639  https://www.crunchbase.com/organization/udiospace
# 8640     https://www.crunchbase.com/organization/unglue
# 8641     https://www.crunchbase.com/organization/unirow
# 10    128 Technology is a software company on a miss...           3,862
# 11    17hats is the simple business management app f...          10,633
# 12    Virtual and Augmented Reality (VR/AR) will tra...          33,279
# 13    19Labs builds smart and portable health care c...          26,225
# 14    1COMM Medical is a complete care model, struct...          36,581
# 15                  Game Platform for Employee Training          11,813
# 16    1UPd is a gaming app that allows users to crea...          56,525
# 17    2020 delivers on-site eye care and comprehensi...          11,428
# 18           A computational synthetic biology company.          17,955
# 19              21 makes Bitcoin useful for developers.           1,607
# 20    23VIVIäó»s online marketplace offers rare and ...          48,756
# 21    27 Perry provides a curated online marketplace...          46,891
# 22             Search and Social Media Affiliate Networ          49,233
# 23    2ULaundry is the new way to do laundry and dry...          19,625
# 24    30 Second Showcase develops a mobile applicati...          55,678
# 25    We are committed to making bitcoin easy, secur...          26,786
# 26    3D Ops is a medical modeling company that util...          60,371
# 27    3D-SensIR Inc., a sensor hardware startup comp...          37,852
# 28    3Derm is a cost-effective, skin imaging system...          15,138
# 29    3Diligent is a network-driven digital manufact...          28,468
# ...                                                 ...             ...
# 8634  uBack offers a mobile application that is focu...          19,248
# 8635  uBiome is the worldäó»s first effort to map th...           1,789
# 8636  uMake offers an application that enables iPad ...          16,427
# 8637  CONSUMERS Personalized TV experience from soci...          51,002
# 8638  uSens develops inside-out hand and position tr...           3,307
# 8639  A website which helps connect musicians with q...          54,230
# 8640  unGlue helps kids better manage their time on ...          10,824
# 8641  Unirow Inc, the Training Cloud Company, is tra...          33,286
# 8642                           digital dowloads startup          61,039
# 8643                       vDice is a gambling platform          23,192
# 8644  venVelo is a venture fund and business acceler...          25,632
# 8645  vidIQ is a YouTube audience development and ma...          20,606
# 8646  On Demand Real Estate Services, simply no comm...          59,218
# 8647  Vushaper is a company that develops software t...          56,984
# 8648  Walkby is an online network of retailers that ...          39,333
# 8649     A platform for creating crowd-funded bounties.          56,495
# 8650                 Your extreme toolbox for WordPress          54,496
# 8651      The world's first idea construction platform.          36,453
# 8652  The Ultimate Fantasy Sportsbook Contest Experi...          50,180
# 8653  x.ai is an artificial intelligence driven pers...             673
# 8654  XENDIT provides payment infrastructure to Sout...          19,550
# 8655  The xiQ platform collects data from the intern...          20,694
# 8656  yaBeam delivers contextually relevant multimed...          46,460
# 8657  A Comprehensive Digital Economy Platform for t...          36,527
# 8658  The only marketplace that delivers to where yo...          33,623
# 8659  zEconomy is a liquidity marketplace that enabl...          30,111
# 8660  The mission of zPREDICTA is to fully automate ...          29,954
# 8661  Zanda is a social rating site that allows its ...          65,140
# 8662  Curated Food Delivery Platform that provides a...          12,501
# 8663    Exclusive reservations at the best restaurants.          31,559
#
#      Founded Date Closed Date  Number of Funding Rounds Last Funding Date  \
# 0      2012-06-01         NaT                         1        2012-06-30
# 1      2015-08-01         NaT                         1        2016-07-27
# 2      2015-03-01         NaT                         1        2015-10-01
# 3      2015-05-01         NaT                         1        2016-08-23
# 4      2015-01-01         NaT                         1        2017-07-01
# 5      2012-01-01         NaT                         1        2016-06-27
# 6      2012-01-01         NaT                         3        2016-03-17
# 7      2013-07-08         NaT                         2        2014-05-08
# 8      2014-08-01         NaT                         1        2014-11-26
# 9      2012-02-17         NaT                         4        2015-12-18
# 10     2014-07-07         NaT                         4        2017-05-31
# 11     2014-01-01         NaT                         2        2015-10-15
# 12     2015-01-01         NaT                         1        2016-02-01
# 13     2015-01-01         NaT                         1        2016-09-01
# 14     2013-01-01         NaT                         1        2015-04-27
# 15     2015-01-01         NaT                         2        2017-03-15
# 16     2015-08-12         NaT                         1        2015-09-09
# 17     2013-11-01         NaT                         3        2016-07-11
# 18     2013-01-01         NaT                         2        2015-05-01
# 19     2013-05-01         NaT                         2        2015-03-10
# 20     2015-12-22         NaT                         1        2016-02-12
# 21     2012-01-01  2013-01-01                         1        2012-05-17
# 22     2012-01-01         NaT                         1        2013-01-01
# 23     2015-12-01         NaT                         1        2016-11-14
# 24     2013-04-01         NaT                         1        2013-05-20
# 25     2014-01-01         NaT                         2        2014-06-01
# 26     2014-01-01         NaT                         1        2014-05-15
# 27     2016-01-01         NaT                         1        2016-09-26
# 28     2012-01-01         NaT                         5        2016-07-27
# 29     2014-07-23         NaT                         2        2015-03-15
# ...           ...         ...                       ...               ...
# 8634   2014-10-01         NaT                         1        2017-02-08
# 8635   2012-01-01         NaT                         6        2016-11-01
# 8636   2014-04-01         NaT                         3        2015-12-03
# 8637   2013-01-01         NaT                         1        2013-04-01
# 8638   2013-01-01         NaT                         3        2016-06-01
# 8639   2014-01-01         NaT                         1        2016-05-15
# 8640   2015-01-01         NaT                         2        2017-03-02
# 8641   2013-06-15         NaT                         2        2014-05-06
# 8642   2013-09-01         NaT                         1        2013-12-16
# 8643   2016-01-01         NaT                         1        2016-12-08
# 8644   2012-01-01         NaT                         1        2015-01-06
# 8645   2012-01-01         NaT                         3        2013-02-26
# 8646   2016-07-21         NaT                         1        2016-07-21
# 8647   2012-01-01         NaT                         1        2012-03-01
# 8648   2012-08-01  2013-01-01                         2        2013-04-10
# 8649   2015-01-14         NaT                         1        2015-02-28
# 8650   2012-08-01         NaT                         2        2013-11-10
# 8651   2013-01-01         NaT                         2        2015-03-12
# 8652   2015-09-15         NaT                         1        2017-08-01
# 8653   2014-04-14         NaT                         4        2017-08-14
# 8654   2014-11-01         NaT                         2        2015-09-01
# 8655   2013-09-01         NaT                         1        2014-11-18
# 8656   2013-08-01         NaT                         1        2013-06-01
# 8657   2016-01-01         NaT                         1        2016-01-29
# 8658   2016-01-01         NaT                         1        2016-01-01
# 8659   2013-01-01         NaT                         1        2014-06-18
# 8660   2014-01-01         NaT                         1        2015-09-01
# 8661   2013-01-01         NaT                         1        2013-01-21
# 8662   2014-04-01         NaT                         2        2016-08-12
# 8663   2012-01-01         NaT                         1        2014-03-20
#
#       Last Funding Amount Last Funding Type  Total Funding Amount  \
# 0               1750000.0              Seed             1750000.0
# 1               1000000.0              Seed             1000000.0
# 2               1500000.0              Seed             1500000.0
# 3                120000.0              Seed              120000.0
# 4                120000.0              Seed              120000.0
# 5              13900000.0          Series A            13900000.0
# 6              55000000.0          Series C           113000000.0
# 7               1600000.0              Seed             1600000.0
# 8                935000.0              Seed              935000.0
# 9               2200000.0              Seed             4000000.0
# 10             21500000.0          Series C            57499347.0
# 11              4000000.0          Series A             5250000.0
# 12               500000.0              Seed              500000.0
# 13               680000.0              Seed              680000.0
# 14              2500000.0          Series A             2500000.0
# 15               500000.0              Seed              625000.0
# 16                30000.0              Seed               30000.0
# 17              3000000.0          Series A             7714965.0
# 18              2100000.0              Seed             2220000.0
# 19            116000000.0          Series B           121050000.0
# 20                20000.0              Seed               20000.0
# 21               118000.0              Seed              118000.0
# 22               150000.0              Seed              150000.0
# 23               400000.0              Seed              400000.0
# 24                25000.0              Seed               25000.0
# 25               500000.0              Seed              525000.0
# 26                 7500.0              Seed                7500.0
# 27                75000.0              Seed               75000.0
# 28              1655709.0          Series A             3535709.0
# 29               900000.0              Seed             1150000.0
# ...                   ...               ...                   ...
# 8634            2000000.0              Seed             2000000.0
# 8635           22000000.0          Series B            26971193.0
# 8636            4500000.0          Series A             5200000.0
# 8637             130000.0              Seed              130000.0
# 8638           20000000.0          Series A            26700000.0
# 8639              50000.0              Seed               50000.0
# 8640            1500000.0              Seed             1500000.0
# 8641             214471.0              Seed             1214471.0
# 8642              40000.0              Seed               40000.0
# 8643            1800000.0              Seed             1800000.0
# 8644            1300000.0              Seed             1300000.0
# 8645            2000000.0              Seed             4000000.0
# 8646             160000.0              Seed              160000.0
# 8647             200000.0              Seed              200000.0
# 8648             650000.0              Seed              650000.0
# 8649              20000.0              Seed               20000.0
# 8650             100000.0              Seed              132000.0
# 8651             975000.0              Seed             1035000.0
# 8652             100000.0              Seed              100000.0
# 8653           10000000.0          Series B            44300000.0
# 8654             120000.0              Seed              120000.0
# 8655             725000.0              Seed              725000.0
# 8656             150000.0              Seed              150000.0
# 8657             550000.0              Seed              550000.0
# 8658             250000.0              Seed              250000.0
# 8659            1550000.0              Seed             1550000.0
# 8660             120000.0              Seed              120000.0
# 8661              10000.0              Seed               10000.0
# 8662            2000000.0              Seed             4200000.0
# 8663            1200000.0              Seed             1200000.0
#
#             Status
# 0     Was Acquired
# 1        Operating
# 2        Operating
# 3        Operating
# 4        Operating
# 5        Operating
# 6        Operating
# 7        Operating
# 8        Operating
# 9        Operating
# 10       Operating
# 11       Operating
# 12       Operating
# 13       Operating
# 14       Operating
# 15       Operating
# 16       Operating
# 17       Operating
# 18       Operating
# 19       Operating
# 20       Operating
# 21          Closed
# 22       Operating
# 23       Operating
# 24       Operating
# 25       Operating
# 26       Operating
# 27       Operating
# 28       Operating
# 29       Operating
# ...            ...
# 8634     Operating
# 8635     Operating
# 8636     Operating
# 8637     Operating
# 8638     Operating
# 8639     Operating
# 8640     Operating
# 8641     Operating
# 8642     Operating
# 8643     Operating
# 8644     Operating
# 8645     Operating
# 8646     Operating
# 8647     Operating
# 8648        Closed
# 8649     Operating
# 8650     Operating
# 8651     Operating
# 8652     Operating
# 8653     Operating
# 8654     Operating
# 8655     Operating
# 8656     Operating
# 8657     Operating
# 8658     Operating
# 8659     Operating
# 8660     Operating
# 8661     Operating
# 8662     Operating
# 8663  Was Acquired
#
# [8664 rows x 14 columns]

# %%
## Read file and then sort 
## 
csv_file = "../Funding_Rounds.csv"
fundrds_df = pd.read_csv(csv_file, encoding="iso-8859-1", parse_dates=["Announced On Date"])
fundrds_df = fundrds_df.sort_values("Company Name").reset_index(drop=True)
print(len(fundrds_df.index))
fundrds_df.head(5)
# Out:
# 10901
#   Company Name                                   Company Name URL  \
# 0     #waywire    https://www.crunchbase.com/organization/waywire
# 1   *gram Labs  https://www.crunchbase.com/organization/gram-labs
# 2          .io  https://www.crunchbase.com/organization/io-rea...
# 3   /dev/color  https://www.crunchbase.com/organization/dev-color
# 4     10 By 10   https://www.crunchbase.com/organization/10-by-10
#
#   Funding Type Money Raised Announced On Date
# 0         Seed  $1,750,000         2012-06-30
# 1         Seed  $1,000,000         2016-07-27
# 2         Seed  $1,500,000         2015-10-01
# 3         Seed    $120,000         2016-08-23
# 4         Seed    $120,000         2017-07-01

# %%
# convert these to a float
fundrds_df["Money Raised"] = fundrds_df["Money Raised"].replace('[\$,]','', regex=True ).astype(np.float64)


fundrds_df
#print(len(fundrds_df.index))
# Out:
#                                  Company Name  \
# 0                                    #waywire
# 1                                  *gram Labs
# 2                                         .io
# 3                                  /dev/color
# 4                                    10 By 10
# 5                                10-4 Systems
# 6                                10X Genomics
# 7                                10X Genomics
# 8                                10X Genomics
# 9                                       10sec
# 10                                    12 Labs
# 11                                 121 Mobile
# 12                             128 Technology
# 13                             128 Technology
# 14                             128 Technology
# 15                             128 Technology
# 16                                     17hats
# 17                                     17hats
# 18                                   18Angles
# 19                                     19Labs
# 20                               1CommMedical
# 21                                    1Huddle
# 22                                    1Huddle
# 23                                       1UPd
# 24                     2020 On-site Optometry
# 25                     2020 On-site Optometry
# 26                                        20n
# 27                                        20n
# 28                                     21 Inc
# 29                                     21 Inc
# ...                                       ...
# 10871                                vushaper
# 10872                                  walkby
# 10873              way.com - what amazes you?
# 10874              way.com - what amazes you?
# 10875                          weBounty, Inc.
# 10876                                 wedgies
# 10877                                 wedgies
# 10878                               weeSpring
# 10879                                wpXtreme
# 10880                             wrkbench.io
# 10881                             wrkbench.io
# 10882                        www.pixxpros.com
# 10883                                    x.ai
# 10884                                    x.ai
# 10885                                    x.ai
# 10886                                    x.ai
# 10887                                  xendit
# 10888                                     xiQ
# 10889                                  yaBeam
# 10890                                   yoPay
# 10891                               youarrive
# 10892                     yourClass Education
# 10893                                zEconomy
# 10894  zPREDICTA (formerly Ixchel Scientific)
# 10895                                   zanda
# 10896                                 zipster
# 10897                                   zurvu
# 10898                                    Ûñdn
# 10899                              äóShwrí_m
# 10900                                  íîasys
#
#                                         Company Name URL Funding Type  \
# 0        https://www.crunchbase.com/organization/waywire         Seed
# 1      https://www.crunchbase.com/organization/gram-labs         Seed
# 2      https://www.crunchbase.com/organization/io-rea...         Seed
# 3      https://www.crunchbase.com/organization/dev-color         Seed
# 4       https://www.crunchbase.com/organization/10-by-10         Seed
# 10899      https://www.crunchbase.com/organization/shwrm         Seed
# 10900   https://www.crunchbase.com/organization/íîasys-2         Seed
#
#        Money Raised Announced On Date
# 0         1750000.0        2012-06-30
# 1         1000000.0        2016-07-27
# 2         1500000.0        2015-10-01
# 3          120000.0        2016-08-23
# 4          120000.0        2017-07-01
# 5        13900000.0        2016-06-27
# 6        55000000.0        2015-01-12
# 7        55000000.0        2016-03-17
# 8         3000000.0        2012-10-08
# 9         1600000.0        2014-05-08
# 10         935000.0        2014-11-26
# 11        2200000.0        2015-12-18
# 12       11999347.0        2014-12-04
# 13        4000000.0        2014-07-07
# 14       21500000.0        2017-05-31
# 15       20000000.0        2015-12-08
# 16        4000000.0        2015-10-15
# 17        1250000.0        2015-02-18
# 18         500000.0        2016-02-01
# 19         680000.0        2016-09-01
# 20        2500000.0        2015-04-27
# 21         500000.0        2017-03-15
# 22         125000.0        2015-10-20
# 23          30000.0        2015-09-09
# 24        3000000.0        2016-07-11
# 25        3499965.0        2015-06-01
# 26        2100000.0        2015-05-01
# 27         120000.0        2014-12-01
# 28      116000000.0        2015-03-10
# 29        5050000.0        2013-11-17
# ...             ...               ...
# 10871      200000.0        2012-03-01
# 10872      650000.0        2013-04-10
# 10873     1000000.0        2016-04-04
# 10874      250000.0        2013-01-18
# 10875       20000.0        2015-02-28
# 10876      700000.0        2014-12-18
# 10877      550000.0        2012-11-14
# 10878      200000.0        2013-04-02
# 10879      100000.0        2013-11-10
# 10880      975000.0        2015-03-12
# 10881       60000.0        2013-10-01
# 10882      100000.0        2017-08-01
# 10883    10000000.0        2017-08-14
# 10884     2100000.0        2014-05-21
# 10885     9200000.0        2015-01-05
# 10886    23000000.0        2016-04-07
# 10887      120000.0        2015-09-01
# 10888      725000.0        2014-11-18
# 10889      150000.0        2013-06-01
# 10890      550000.0        2016-01-29
# 10891      250000.0        2016-01-01
# 10892       30000.0        2015-10-07
# 10893     1550000.0        2014-06-18
# 10894      120000.0        2015-09-01
# 10895       10000.0        2013-01-21
# 10896     2000000.0        2016-08-12
# 10897     1200000.0        2014-03-20
# 10898       20000.0        2016-02-01
# 10899       50000.0        2013-01-01
# 10900       15000.0        2014-12-18
#
# [10901 rows x 5 columns]

# %%
## Read file and then sort 
##
csv_file = "../Org_Output.csv"
org_df = pd.read_csv(csv_file, encoding="iso-8859-1")
org_df = org_df.sort_values("Company Name").reset_index(drop=True)
print(len(org_df.index))
org_df.head(5)
# Out:
# 497523
#    Unnamed: 0                                  UUID         Company Name  \
# 0      187767  8e2c2fbd-2244-32eb-8e35-9ea9cefeb90f                  !K7
# 1      324012  7268c6ad-9c37-3265-7545-0f4c07fe22a2            !SHOUTTAG
# 2      369276  b8f77030-aab4-3914-a2ce-85302f459390        !hey software
# 3      134099  7ef2d009-800d-c9b6-0f15-5f52c1c6c3e1           !mpossible
# 4      362136  1bf2f0d9-b344-085d-2130-91a7746c1020  "Believe & Succeed"
#
#                            Homepage
# 0                 http://www.k7.com
# 1              https://shouttag.com
# 2            http://www.heyinc.com/
# 3  http://www.impossiblevisions.com
# 4    http://www.believe-succeed.com

# %%
# # Rename columns so they are easier to use
# crunch_df.rename(columns={"Company Name":"company_name",
#                           "Company Name URL":"url",
#                           "Category Groups":"cat_group",
#                           "Headquarters Location":"hq_location",
#                           "Description":"desc",
#                           "Crunchbase Rank":"crunch_rank",
#                           "Founded Date":"founded_date",
#                           "Closed Date":"closed_date",
#                           "Status":"status",
#                           "Number of Employees":"emp_count",
#                           "Number of Funding Rounds":"fund_rnd_cnt",
#                           "Last Funding Date":"last_fund_date",
#                           "Last Funding Amount":"last_fund_amt",
#                           "Last Funding Type":"last_fund_type",
#                           "Last Equity Funding Amount":"last_eqty_fund_amt",
#                           "Total Equity Funding Amount":"tot_eqty_fund_amt",
#                           "Total Funding Amount":"tot_fund_amt"},inplace=True)
# crunch_df.head(5)

# %%
# 127 records with Status == "Closed"
closed_df = companies_df.loc[companies_df["Status"] == "Closed"]
closed_df.head(5)
print(len(closed_df.index))
# Out:
# 253

# %%
# 8360 records with Status == "Operating"
oper_df = companies_df.loc[companies_df["Status"] == "Operating"]
oper_df.head(5)
print(len(oper_df.index))
# Out:
# 7922

# %%
funding_type = companies_df["Last Funding Type"].value_counts()
funding_type
# Out:
# Seed        6167
# Series A    1638
# Series B     649
# Series C     168
# Series D      42
# Name: Last Funding Type, dtype: int64

# %%
## Web scraping program
##  Test URL https://www.similarweb.com/website/shotput.com#overview 

## https://github.com/douglasmiranda/splinter-examples/blob/master/another_examples/screenshot.py
## http://splinter.readthedocs.io/en/latest/tutorial.html

from splinter import Browser
import csv
from bs4 import BeautifulSoup 
import time

# browser = Browser('chrome')
# browser = Browser('firefox')

with Browser() as browser:
    # Visit URL
    #url = "https://www.similarweb.com/website/" 
    #url_suffix = "#overview"
    
    # loop thru the urls in data frame
    counter = 0
    #for index, row in companies_df.iterrows():
    for i in range(0,1):
        counter += 1
        if counter == 2:
            break
        try:
            # temp url for testing
            t_url = "https://www.similarweb.com/website/shotput.com#overview"
            # Use url from data frame
            #url = row["Company Name URL"]
            print(t_url)
            browser.visit(t_url)
            time.sleep(30)
            html = browser.html
            soup = BeautifulSoup(html, "html.parser")
            
            print("Before the soup.prettify")
            
            print(soup.prettify())
            
            #span class="rankingItem-value js-countable"
            print("********  Start for loop to read soup  ********")
            #for line in soup.findAll('a', class_="rankingItem-subTitle is-link"):
            for line in soup.findAll('div', class_="rankingItem-underTitle"):
                # Append to a file or write to a data frame
                print("********  in soup for loop line first read is  ********")
                print(line)
                # Write to a file
                with open('mystats.csv', 'a') as csvfile:
                    csvwriter = csv.writer(csvfile, delimiter=',')
                    csvwriter.writerow(line)
            
            for line in soup.findAll('div', class_="rankingItem-rank js-editable"): 
            #for line in soup.findAll('span', class_="rankingItem-value js-countable"):
                # Append to a file or write to a data frame
                print("********  in soup for loop line second read is  ********")
                print(line)
                # Write to a file
                with open('mystats.csv', 'a') as csvfile:
                    csvwriter = csv.writer(csvfile, delimiter=',')
                    csvwriter.writerow(line)
            
            for line in soup.findAll('span', class_="rankingItem-value js-countable"):
                # Append to a file or write to a data frame
                print("********  in soup for loop line second read is  ********")
                print(line)
                # Write to a file
                with open('mystats.csv', 'a') as csvfile:
                    csvwriter = csv.writer(csvfile, delimiter=',')
                    csvwriter.writerow(line)
            
            line = soup.find('span', class_="engagementInfo-param engagementInfo-param--large u-text-ellipsis")
            # Write to a file
            with open('mystats.csv', 'a') as csvfile:
                csvwriter = csv.writer(csvfile, delimiter=',')
                csvwriter.writerow(line)
        
            # Grab a tag from the html 
            for line in soup.findAll('span', class_="engagementInfo-param u-text-ellipsis"):
            #for line in soup.findAll('span', class_="engagementInfo-valueNumber"):
                # Append to a file or write to a data frame
                print("********  in soup for loop line third read is  ********")
                # Write to a file
                with open('mystats.csv', 'a') as csvfile:
                    csvwriter = csv.writer(csvfile, delimiter=',')
                    csvwriter.writerow(line)
                    
              # Grab a tag from the html 
            for line in soup.findAll('span', class_="engagementInfo-valueNumber"):
                # Append to a file or write to a data frame
                print("********  in soup for loop line fourth read is  ********")
                print(line)
                # Write to a file
                with open('mystats.csv', 'a') as csvfile:
                    csvwriter = csv.writer(csvfile, delimiter=',')
                    csvwriter.writerow(line)       
        
#                     # Write to the the data frame                
#                     # Save the json info into variables
#                     html_tag  = user_account["tag_name"]
#                     html_text = user_account["tag_text"]
               
#                     # Set the data frame info 
#                     companies_df.set_value(index, "col1", html_tag)
#                     companies_df.set_value(index, "col2", html_text)
        except:
            print("Error with url: ", t_url)
# Out:
# https://www.similarweb.com/website/shotput.com#overview
# Before the soup.prettify
# <html class=" js flexbox canvas canvastext webgl no-touch geolocation postmessage no-websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients no-cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths" lang="en">
#  <head>
#   <script async="" id="trdflame" src="https://prod.trendemon.com/apis/loadflame/mainflamejs?aid=1786&amp;uid=1805&amp;baseurl=https%3A%2F%2Fprod.trendemon.com%2F&amp;appid=208770359181748" type="text/javascript">
#   </script>
#   <script async="" src="https://widget.intercom.io/widget/e74067abd037cecbecb0662854f02aee12139f95" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/1523666777957920?v=2.7.20">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/579140632173169?v=2.7.20">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/647747115332565?v=2.7.20">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/596735957094535?v=2.7.20">
#   </script>
#   <script async="" src="//connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="//connect.facebook.net/en_US/fbds.js">
#   </script>
#   <script async="" src="https://sjs.bizographics.com/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://sjs.bizographics.com/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.gstatic.com/recaptcha/api2/r20170829114530/recaptcha__en.js" type="text/javascript">
#   </script>
#   <meta charset="utf-8"/>
#   <link href="/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://www.similarweb.com/website/shotput.com" hreflang="x-default" rel="alternate"/>
#   <link href="https://www.similarweb.com/ja/website/shotput.com" hreflang="ja-jp" rel="alternate"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    Shotput.com Analytics - Market Share Stats &amp; Traffic Ranking
#   </title>
#   <script async="" src="//munchkin.marketo.net/151/munchkin.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript">
#   </script>
#   <script async="" src="https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.gluJ6Ql_26U.O/m=client/rt=j/sv=1/d=1/ed=1/am=AQ/rs=AGLTcCP_g_tqY1b4EVnnCSwsaPUTFdIjbA/cb=gapi.loaded_0">
#   </script>
#   <script id="twitter-wjs" src="https://platform.twitter.com/widgets.js">
#   </script>
#   <script id="facebook-jssdk" src="//connect.facebook.net/en_US/all.js#xfbml=1&amp;appId=113949902026632">
#   </script>
#   <script async="" gapi_processed="true" src="//apis.google.com/js/client.js" type="text/javascript">
#   </script>
#   <script async="" gapi_processed="true" src="//apis.google.com/js/platform.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-NRWLLQ">
#   </script>
#   <script async="" id="www-widgetapi-script" src="https://s.ytimg.com/yts/jsbin/www-widgetapi-vflWgX7t4/www-widgetapi.js" type="text/javascript">
#   </script>
#   <script async="" defer="" src="https://analytics.similarweb.com/swptrk.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="//rum-static.pingdom.net/prum.min.js">
#   </script>
#   <script>
#    var _prum = [['id', '556c418babe53d533185c47d'],
#             ['mark', 'firstbyte', (new Date()).getTime()]];
#         (function () {
#             var s = document.getElementsByTagName('script')[0]
#                 , p = document.createElement('script');
#             p.async = 'async';
#             p.src = '//rum-static.pingdom.net/prum.min.js';
#             s.parentNode.insertBefore(p, s);
#         })();
#   </script>
#   <script>
#    _linkedin_data_partner_id = "36504";
#   </script>
#   <script>
#    (function () {
#             var s = document.getElementsByTagName("script")[0];
#             var b = document.createElement("script");
#             b.type = "text/javascript"; b.async = true;
#             b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#             s.parentNode.insertBefore(b, s);
#         })();
#   </script>
#   <meta content="shotput.com is ranked #106307 for Sports and #5447784 Globally. Get a full report of their traffic statistics and market share." name="description"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,300italic,300,400italic" rel="stylesheet" type="text/css"/>
#   <link href="/css/application.css?version=20170830.1841" rel="stylesheet"/>
#   <link href="/images/touch-icons/similarweb-60x60.png" rel="apple-touch-icon"/>
#   <link href="/images/touch-icons/similarweb-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/images/touch-icons/similarweb-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/images/touch-icons/similarweb-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <script src="//www.google.com/jsapi">
#   </script>
#   <script>
#    google.load('visualization', '1', {'packages': ['geochart', 'treemap']});
#   </script>
#   <script src="https://www.google.com/uds/?file=visualization&amp;v=1&amp;packages=geochart%2Ctreemap" type="text/javascript">
#   </script>
#   <link href="https://www.google.com/uds/api/visualization/1.0/40ff64b1d9d6b3213524485974f36cc0/ui+en.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.google.com/uds/api/visualization/1.0/40ff64b1d9d6b3213524485974f36cc0/format+en,default+en,ui+en,treemap+en,geochart+en.I.js" type="text/javascript">
#   </script>
#   <script src="/scripts/libs/jquery.1.11.2.min.js">
#   </script>
#   <script type="text/javascript">
#    (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date(); a = s.createElement(o),
#         m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js','ga');
#
#
#
#     ga('create', 'UA-42469261-1', 'auto');
#     ga('require', 'displayfeatures');
#     ga('require', 'linkid', 'linkid.js');
#
#
#         ga("send", "pageview");
#   </script>
#   <!-- Piwik -->
#   <script type="text/javascript">
#    var _paq = _paq || [];
#
#     (function () {
#         var parts = window.location.host.split('.');
#         var domain = ['*', parts[parts.length - 2], parts[parts.length - 1]].join('.');
#
#         _paq.push(["setDocumentTitle", document.domain + "/" + document.title]);
#         _paq.push(["setCookieDomain", domain]);
#         _paq.push(["setDomains", [domain]]);
#         _paq.push(["enableLinkTracking"]);
#
#             _paq.push(['setCustomUrl', "/?section=website&pageNumber=1&siteAppID=shotput.com&mainCategory=Sports&language=en"]);
#     })();
#
#     (function () {
#         var u = "https://analytics.similarweb.com/";
#         _paq.push(["setTrackerUrl", u + "swptrk.php"]);
#         _paq.push(["setSiteId", "1"]);
#         var d = document, g = d.createElement("script"), s = d.getElementsByTagName("script")[0]; g.type = "text/javascript";
#         g.defer = true; g.async = true; g.src = u + "swptrk.js"; s.parentNode.insertBefore(g, s);
#     })();
#   </script>
#   <noscript>
#    <img alt="" src="https://analytics.similarweb.com/swptrk.php?idsite=1&amp;rec=1" style="border: 0"/>
#   </noscript>
#   <!-- End Piwik Code -->
#   <!-- Start Visual Website Optimizer Asynchronous Code -->
#   <script type="text/javascript">
#    var _vwo_code = (function () {
#         var account_id = 48102,
#         settings_tolerance = 2000,
#         library_tolerance = 2500,
#         use_existing_jquery = true,
#         // DO NOT EDIT BELOW THIS LINE
#         f = false, d = document; return { use_existing_jquery: function () { return use_existing_jquery; }, library_tolerance: function () { return library_tolerance; }, finish: function () { if (!f) { f = true; var a = d.getElementById('_vis_opt_path_hides'); if (a) a.parentNode.removeChild(a); } }, finished: function () { return f; }, load: function (a) { var b = d.createElement('script'); b.src = a; b.type = 'text/javascript'; b.innerText; b.onerror = function () { _vwo_code.finish(); }; d.getElementsByTagName('head')[0].appendChild(b); }, init: function () { settings_timer = setTimeout('_vwo_code.finish()', settings_tolerance); this.load('//dev.visualwebsiteoptimizer.com/j.php?a=' + account_id + '&u=' + encodeURIComponent(d.URL) + '&r=' + Math.random()); var a = d.createElement('style'), b = 'body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}', h = d.getElementsByTagName('head')[0]; a.setAttribute('id', '_vis_opt_path_hides'); a.setAttribute('type', 'text/css'); if (a.styleSheet) a.styleSheet.cssText = b; else a.appendChild(d.createTextNode(b)); h.appendChild(a); return settings_timer; } };
#     }()); _vwo_settings_timer = _vwo_code.init();
#   </script>
#   <script src="//dev.visualwebsiteoptimizer.com/j.php?a=48102&amp;u=https%3A%2F%2Fwww.similarweb.com%2Fwebsite%2Fshotput.com%23overview&amp;r=0.8874033843172937" type="text/javascript">
#   </script>
#   <!-- End Visual Website Optimizer Asynchronous Code -->
#   <script type="text/javascript">
#    $(function () {
#         function isVwoRunning() {
#             return window._vwo_exp && window._vis_opt_experiment_id in window._vwo_exp;
#         };
#
#         function trackVwoNew() {
#             if (!isVwoRunning()) {
#                 if (window._paq) {
#                     window._paq.push(["trackPageView"]);
#                 }
#                 return;
#             }
#             var experimentId = window._vis_opt_experiment_id;
#             var experiment = window._vwo_exp[experimentId];
#             var combId = experiment.combination_chosen || window._vis_opt_readCookie('_vis_opt_exp_' + experimentId + '_combi');
#             var combName = window._vis_opt_comb_name[combId];
#             if (window._paq) {
#                 window._paq.push(['setCustomVariable', 5, "VWO-" + experimentId, combName, 'page']);
#                 window._paq.push(["trackPageView"]);
#             }
#         };
#
#         // VWO Tracking
#         if (!_vwo_code.finished()) {
#             var origFinish = _vwo_code.finish;
#             _vwo_code.finish = function () {
#                 origFinish();
#                 trackVwoNew();
#             };
#         } else {
#             trackVwoNew();
#         }
#
#     });
#   </script>
#   <meta content="noindex,nofollow" name="robots"/>
#   <script src="https://www.youtube.com/iframe_api">
#   </script>
#   <script src="/scripts/bundles/preload.js?version=20170830.1841">
#   </script>
#   <link href="https://plus.google.com/109431312760858845859" rel="publisher"/>
#   <meta content="F2EF44763A7A0834DDEA8A124D33D0AE" name="msvalidate.01"/>
#   <script defer="" src="/smlrdstl.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    #d__fFH{position:absolute;top:-5000px;left:-5000px}#d__fF{font-family:serif;font-size:200px;visibility:hidden}#sazztsauwtyrydwrcuxyeuescsc{display:none!important}
#   </style>
#   <link href="https://www.similarweb.com/scripts/sdk/dist/sw.sdk.nodeps.css?v=20170830.1841" rel="stylesheet" type="text/css"/>
#   <script src="https://www.similarweb.com/scripts/sdk/dist/bundle.nodeps.min.js?v=20170830.1841">
#   </script>
#   <script async="" src="//munchkin.marketo.net/munchkin.js" type="text/javascript">
#   </script>
#   <link href="https://ajax.googleapis.com/ajax/static/modules/gviz/1.0/core/tooltip.css" rel="stylesheet" type="text/css"/>
#   <script charset="UTF-8" src="https://www.gstatic.com/charts/regioncoder/0/geocodes/countries_en.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}.fb_link img{border:none}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_reset .fb_dialog_legacy{overflow:visible}.fb_dialog_advanced{padding:10px;-moz-border-radius:8px;-webkit-border-radius:8px;border-radius:8px}.fb_dialog_content{background:#fff;color:#333}.fb_dialog_close_icon{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{top:5px;left:5px;right:auto}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_loader{background-color:#f6f7f9;border:1px solid #606060;font-size:24px;padding:20px}.fb_dialog_top_left,.fb_dialog_top_right,.fb_dialog_bottom_left,.fb_dialog_bottom_right{height:10px;width:10px;overflow:hidden;position:absolute}.fb_dialog_top_left{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/ye/r/8YeTNIlTZjm.png) no-repeat 0 0;left:-10px;top:-10px}.fb_dialog_top_right{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/ye/r/8YeTNIlTZjm.png) no-repeat 0 -10px;right:-10px;top:-10px}.fb_dialog_bottom_left{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/ye/r/8YeTNIlTZjm.png) no-repeat 0 -20px;bottom:-10px;left:-10px}.fb_dialog_bottom_right{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/ye/r/8YeTNIlTZjm.png) no-repeat 0 -30px;right:-10px;bottom:-10px}.fb_dialog_vert_left,.fb_dialog_vert_right,.fb_dialog_horiz_top,.fb_dialog_horiz_bottom{position:absolute;background:#525252;filter:alpha(opacity=70);opacity:.7}.fb_dialog_vert_left,.fb_dialog_vert_right{width:10px;height:100%}.fb_dialog_vert_left{margin-left:-10px}.fb_dialog_vert_right{right:0;margin-right:-10px}.fb_dialog_horiz_top,.fb_dialog_horiz_bottom{width:100%;height:10px}.fb_dialog_horiz_top{margin-top:-10px}.fb_dialog_horiz_bottom{bottom:0;margin-bottom:-10px}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{-webkit-transform:none;height:100%;margin:0;overflow:visible;position:absolute;top:-10000px;left:0;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{width:auto;height:auto;min-height:initial;min-width:initial;background:none}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{color:#fff;display:block;padding-top:20px;clear:both;font-size:18px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .45);position:absolute;bottom:0;left:0;right:0;top:0;width:100%;min-height:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_content .dialog_header{-webkit-box-shadow:white 0 1px 1px -1px inset;background:-webkit-gradient(linear, 0% 0%, 0% 100%, from(#738ABA), to(#2C4987));border-bottom:1px solid;border-color:#1d4088;color:#fff;font:14px Helvetica, sans-serif;font-weight:bold;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{-webkit-font-smoothing:subpixel-antialiased;heig ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_hide_iframes iframe{position:relative;left:-10000px}.fb_iframe_widget_loader{position:relative;display:inline-block}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}.fb_iframe_widget_loader iframe{min-height:32px;z-index:2;zoom:1}.fb_iframe_widget_loader .FB_Loader{background:url(http://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat;height:32px;width:32px;margin-left:-16px;position:absolute;left:50%;z-index:4}
#   </style>
#   <script async="true" class="cross" src="https://prod.trendemon.com/apis/loadflame/isused/?previewmode=0&amp;uid=1805&amp;aid=1786&amp;cid=15041437696786772&amp;sid=15041437696786772&amp;cl_url=aHR0cHMlM0EvL3d3dy5zaW1pbGFyd2ViLmNvbS93ZWJzaXRlL3Nob3RwdXQuY29tJTIzb3ZlcnZpZXc=&amp;reffer=&amp;trdflame=jsonp287192" type="text/javascript">
#   </script>
#   <style id="intercom-stylesheet" type="text/css">
#    .intercom-mobile-messenger-active{overflow:hidden;height:100%;width:100%;position:fixed}.intercom-conversation-body,.intercom-conversations-body,.intercom-messenger,.intercom-scrollable{-webkit-overflow-scrolling:touch}@font-face{font-family:intercom-font;src:url(https://js.intercomcdn.com/fonts/proximanova-regular.a7942249.woff) format("woff")}@font-face{font-family:intercom-font;src:url(https://js.intercomcdn.com/fonts/proximanova-semibold.46e3f047.woff) format("woff");font-weight:700}@font-face{font-family:intercom-font;src:url(https://js.intercomcdn.com/fonts/proximanova-regular-italic.053a1112.woff) format("woff");font-style:italic}@font-face{font-family:intercom-font;src:url(https://js.intercomcdn.com/fonts/proximanova-semibold-italic.660bf63e.woff) format("woff");font-weight:700;font-style:italic}#intercom-container a,#intercom-container abbr,#intercom-container acronym,#intercom-container address,#intercom-container applet,#intercom-container article,#intercom-container aside,#intercom-container audio,#intercom-container b,#intercom-container big,#intercom-container blockquote,#intercom-container button,#intercom-container canvas,#intercom-container caption,#intercom-container center,#intercom-container cite,#intercom-container code,#intercom-container dd,#intercom-container del,#intercom-container details,#intercom-container dfn,#intercom-container div,#intercom-container div.form,#intercom-container dl,#intercom-container dt,#intercom-container em,#intercom-container fieldset,#intercom-container figcaption,#intercom-container figure,#intercom-container footer,#intercom-container form,#intercom-container h1,#intercom-container h2,#intercom-container h3,#intercom-container h4,#intercom-container h5,#intercom-container h6,#intercom-container header,#intercom-container hgroup,#intercom-container i,#intercom-container iframe,#intercom-container img,#intercom-container input,#intercom-container input[type],#intercom-container ins,#intercom-container kbd,#intercom-container label,#intercom-container legend,#intercom-container li,#intercom-container mark,#intercom-container menu,#intercom-container nav,#intercom-container object,#intercom-container ol,#intercom-container p,#intercom-container pre,#intercom-container q,#intercom-container s,#intercom-container samp,#intercom-container section,#intercom-container small,#intercom-container span,#intercom-container strike,#intercom-container strong,#intercom-container sub,#intercom-container summary,#intercom-container sup,#intercom-container table,#intercom-container tbody,#intercom-container td,#intercom-container textarea,#intercom-container tfoot,#intercom-container th,#intercom-container thead,#intercom-container time,#intercom-container tr,#intercom-container tt,#intercom-container u,#intercom-container ul,#intercom-container var,#intercom-container video{font-family:"intercom-font", "Helvetica Neue", Helvetica, Arial, sans-serif;font-size-adjust:none;font-size:100%;font-style:normal;letter-spacing:normal;font-stretch:normal;font-variant:normal;font-weight:400;font:normal normal 100% "intercom-font", "Helvetica Neue", Helvetica, Arial, sans-serif;text-align:left;text-align-last:auto;text-decoration:none;-webkit-text-emphasis:none;text-emphasis:none;text-height:auto;text-indent:0;text-justify:auto;text-outline:none;text-shadow:none;text-transform:none;text-wrap:normal;alignment-adjust:auto;alignment-baseline:baseline;-webkit-animation:none 0 ease 0 1 normal;animation:none 0 ease 0 1 normal;-webkit-animation-play-state:running;animation-play-state:running;-webkit-appearance:normal;-moz-appearance:normal;appearance:normal;azimuth:center;-webkit-backface-visibility:visible;backface-visibility:visible;background:none 0 0 auto repeat scroll padding-box transparent;background-color:transparent;background-image:none;baseline-shift:baseline;binding:none;bleed:6pt;bookmark-label:content();bookmark-level:none;bookmark-state:open;bookmark-target:none;border:0 none transparent;borde ...
#   </style>
#   <link href="https://prod.trendemon.com/apis/loadflame/flamecss/1786/1805?agent=desktop" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="view-website" data-backbone-controller="WebsiteController" itemscope="" itemtype="http://schema.org/WebPage">
#   <noindex>
#    <!--[if lte IE 9]>
#         <div class="nonSupportedBrowser-overlay">
#             <p class="nonSupportedBrowser-message">Sorry, we no longer support this browser</p>
#         </div>
#     <![endif]-->
#   </noindex>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-NRWLLQ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function (w, d, s, l, i) {
# w[l] = w[l] || []; w[l].push({
# 'gtm.start':
# new Date().getTime(), event: 'gtm.js'
# }); var f = d.getElementsByTagName(s)[0],
# j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
# '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-NRWLLQ');
#   </script>
#   <div class="wrapper-body wrapperBody--analysis js-wrapperBody">
#    <!-- Header SVG sprite -->
#    <svg style="display: none;">
#     <symbol id="sw-search-icon-submit" viewbox="0 0 19 19">
#      <path d="M7.992 14.517c-3.735 0-6.762-2.974-6.762-6.65 0-3.675 3.027-6.656 6.762-6.656 3.735 0 6.763 2.982 6.763 6.657 0 3.676-3.028 6.65-6.763 6.65zm10.823 3.444l-4.904-4.826c1.285-1.396 2.074-3.236 2.074-5.267C15.984 3.52 12.406 0 7.992 0S0 3.52 0 7.867c0 4.34 3.578 7.86 7.992 7.86 1.907 0 3.656-.658 5.03-1.756l4.923 4.846c.24.237.63.237.87 0 .24-.232.24-.618 0-.855z" fill="#1E3651" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="sw-header-icon-cancel" viewbox="0 0 19 19">
#      <path d="M18.1 1.8l-.9-.9-7.7 7.7L1.8.9l-.9.9 7.7 7.7-7.7 7.7.9.9 7.7-7.7 7.7 7.7.9-.9-7.7-7.7">
#      </path>
#     </symbol>
#     <symbol id="sw-header-similarweb-logo" viewbox="0 0 865 133">
#      <path d="M91.208 11.682c-1.134-.392-2.305-.8-3.525-1.154-19.38-5.742-30.16 3.66-33.024 13.36-3.926 13.255 2.765 22.336 20.104 35.697 21.255 16.37 30.053 31.573 23.89 52.43-1.82 6.17-4.86 11.706-9.03 16.286 17.18-6.997 31.158-21.472 36.83-40.658 9.165-30.947-6.434-63.32-35.246-75.96z">
#      </span>
#     </div>
#     <!-- End Logo -->
#     <!-- Search -->
#     <div class="swSearch js-swSearch">
#      <div class="swSearch-overlay" id="js-swSearch-overlay">
#      </div>
#      <form class="swSearch-form" id="js-swSearch-form">
#       <input autocomplete="off" class="swSearch-input" id="js-swSearch-input" placeholder="Analyze any Website or App" type="text"/>
#       <button class="swSearch-submit" type="submit">
#        <svg class="swSearch-submitIcon" height="19" width="19">
#         <use xlink:href="#sw-search-icon-submit">
#         </use>
#        </svg>
#        <span class="swSearch-submitText">
#         Start
#        </span>
#       </button>
#       <div class="swSearch-dropdown" id="js-swSearch-dropdown" style="max-height: 589px;">
#       </div>
#      </form>
#     </div>
#     <!-- End Search -->
#     <!-- Mobile search toggle button -->
#     <a class="header-searchToggler" id="js-headerSearchToggler">
#      <svg class="header-searchTogglerIcon" height="19" width="19">
#       <use class="header-searchTogglerIconUse header-searchTogglerIconUse--show" xlink:href="#sw-search-icon-submit">
#       </use>
#       <use class="header-searchTogglerIconUse header-searchTogglerIconUse--hide" xlink:href="#sw-header-icon-cancel">
#       </use>
#      </svg>
#     </a>
#     <!-- End Mobile search toggle button -->
#     <!-- Menu -->
#     <div class="headerMenu" id="js-headerMenu">
#      <!-- Menu mobile logo -->
#      <div class="headerMenu-logo">
#       <svg class="headerMenu-logoImage" height="27" width="174">
#        <use xlink:href="#sw-header-similarweb-logo">
#        </use>
#       </svg>
#      </div>
#      <!-- End Menu mobile logo -->
#      <!-- Navigation -->
#      <ul class="headerNav">
#       <!-- Sign In / Up button -->
#       <li class="headerNav-item headerNav-item--login">
#        <a class="headerNav-loginBtn js-noTrackingForClick" data-analytics-category="Registration" data-analytics-label="Header" data-analytics-subname="Sign In" data-sw-sdk="phone" data-sw-sdk-init-state="login" itemprop="url">
#         Log In / Sign Up
#        </a>
#       </li>
#       <!-- End Sign In / Up button -->
#       <!-- Live Demo -->
#       <li class="headerNav-item headerNav-item--demo">
#        <a class="headerNav-itemTitle headerNav-itemTitle--link" data-analytics-category="Internal Link" data-analytics-label="Header/Live Demo" href="/live-demo" itemprop="url">
#         Live Demo
#        </a>
#       </li>
#       <!-- End Live Demo -->
#       <!-- Language -->
#       <li class="headerNav-item headerNav-item--language en js-headerNav-menuItem js-headerNav-menuLang" data-lang="en">
#        <a class="headerNav-itemTitle js-headerNav-menuTitle" data-analytics-action="open" data-analytics-category="Drop down" data-analytics-label="Header/choose language">
#         Language
#        </a>
#        <div class="headerNav-dropdown js-headerNav-menuDropdown">
#         <ul class="headerNav-dropdownList">
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Drop down" data-analytics-label="Header/choose language/en" data-locale="en-us" href="/website/shotput.com">
#            <span class="headerNav-linkLang headerNav-linkLang--en">
#             English
#            </span>
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Drop down" data-analytics-label="Header/choose language/ja" data-locale="ja-jp" href="/ja/website/shotput.com">
#            <span class="headerNav-linkLang headerNav-linkLang--ja">
#             日本語
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <!-- End Language -->
#       <!-- Products -->
#       <li class="headerNav-item js-headerNav-menuItem">
#        <span class="headerNav-itemTitle js-headerNav-menuTitle">
#         Products
#        </span>
#        <div class="headerNav-dropdown js-headerNav-menuDropdown">
#         <div class="headerNav-dropdownArrow">
#         </div>
#         <ul class="headerNav-dropdownList headerNav-dropdownList--subMenu">
#          <!-- Tools -->
#          <li class="headerNav-dropdownSubItem js-headerNav-subMenuItem">
#           <span class="headerNav-dropdownSubTitle js-headerNav-subMenuTitle">
#            Tools
#           </span>
#           <ul class="headerNav-dropdownSubList js-headerNav-subMenuDropdown">
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/SimilarWeb PRO" href="/pro">
#              SimilarWeb PRO
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/SimilarWeb Digital Insights" href="/corp/similarweb-insights/">
#              SimilarWeb Digital Insights
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/SimilarWeb API" href="//developer.similarweb.com">
#              SimilarWeb API
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="External Link" data-analytics-label="Header/Browser Extension" href="//addons.mozilla.org/en-US/firefox/addon/similarweb-sites-recommendatio/">
#              Browser Extension
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Widgets" href="/widgets">
#              Widgets
#             </a>
#            </li>
#           </ul>
#          </li>
#          <!-- End Tools -->
#          <!-- Rankings -->
#          <li class="headerNav-dropdownSubItem js-headerNav-subMenuItem">
#           <span class="headerNav-dropdownSubTitle js-headerNav-subMenuTitle">
#            Rankings
#           </span>
#           <ul class="headerNav-dropdownSubList js-headerNav-subMenuDropdown">
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Top Websites" href="/top-websites" itemprop="significantLink">
#              Top Websites
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Top Mobile Apps" href="/apps/top/google/app-index/us/all/top-free" itemprop="significantLink">
#              Top Mobile Apps
#             </a>
#            </li>
#           </ul>
#          </li>
#          <!-- End Rankings -->
#         </ul>
#        </div>
#       </li>
#       <!-- End Products -->
#       <!-- Solutions -->
#       <li class="headerNav-item js-headerNav-menuItem">
#        <span class="headerNav-itemTitle js-headerNav-menuTitle">
#         Solutions
#        </span>
#        <div class="headerNav-dropdown js-headerNav-menuDropdown">
#         <div class="headerNav-dropdownArrow">
#         </div>
#         <ul class="headerNav-dropdownList headerNav-dropdownList--subMenu">
#          <!-- By Industry -->
#          <li class="headerNav-dropdownSubItem js-headerNav-subMenuItem">
#           <span class="headerNav-dropdownSubTitle js-headerNav-subMenuTitle">
#            By Industry
#           </span>
#           <ul class="headerNav-dropdownSubList js-headerNav-subMenuDropdown">
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Travel" href="/corp/solution/travel/">
#              Travel
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Consumer Goods" href="/corp/solution/consumer-goods-industry/">
#              Consumer Goods
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Retail " href="/corp/solution/ecommerce-industry/">
#              Retail
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Agencies" href="/corp/solution/agencies/">
#              Agencies
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Insurance" href="/corp/solution/insurance/">
#              Insurance
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Ad-tech" href="/corp/solution/ad-tech-industry/">
#              Ad-tech
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Publishing" href="/corp/solution/publishers/">
#              Publishing
#             </a>
#            </li>
#           </ul>
#          </li>
#          <!-- End By Industry -->
#          <!-- By Role -->
#          <li class="headerNav-dropdownSubItem js-headerNav-subMenuItem">
#           <span class="headerNav-dropdownSubTitle js-headerNav-subMenuTitle">
#            By Role
#           </span>
#           <ul class="headerNav-dropdownSubList js-headerNav-subMenuDropdown">
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Marketer" href="/corp/solution/marketer/">
#              Marketer
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Analyst" href="/corp/solution/analyst/">
#              Analyst
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Biz-Dev" href="/corp/solution/biz-dev/">
#              Biz-Dev
#             </a>
#            </li>
#            <li class="headerNav-dropdownLine">
#             <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Investor" href="/corp/solution/investment-industry/">
#              Investor
#             </a>
#            </li>
#           </ul>
#          </li>
#          <!-- End By Role -->
#         </ul>
#        </div>
#       </li>
#       <!-- End Solutions -->
#       <!-- Resources -->
#       <li class="headerNav-item js-headerNav-menuItem">
#        <a class="headerNav-itemTitle headerNav-itemTitle--menuTitleLink js-headerNav-menuTitle" data-analytics-category="Internal Link" data-analytics-label="Header/Resources Library" href="/corp/resources/">
#         Resources
#        </a>
#        <div class="headerNav-dropdown js-headerNav-menuDropdown">
#         <div class="headerNav-dropdownArrow">
#         </div>
#         <ul class="headerNav-dropdownList">
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Resources Library" href="/corp/resources/">
#            Resources Library
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Webinars" href="/corp/webinars/">
#            Webinars
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Events" href="/corp/events/">
#            Events
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Help Center" href="https://support.similarweb.com/">
#            Help Center
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Blog" href="/blog/">
#            Blog
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <!-- End Resources -->
#       <!-- Company -->
#       <li class="headerNav-item js-headerNav-menuItem">
#        <span class="headerNav-itemTitle js-headerNav-menuTitle">
#         Company
#        </span>
#        <div class="headerNav-dropdown js-headerNav-menuDropdown">
#         <div class="headerNav-dropdownArrow">
#         </div>
#         <ul class="headerNav-dropdownList">
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/About Us" href="/corp/about/">
#            About Us
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Our Data" href="/ourdata">
#            Our Data
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Customers" href="/corp/clients/">
#            Customers
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Partners" href="/corp/partner-with-similarweb/">
#            Partners
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Management" href="/corp/management/">
#            Management
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Team" href="/team">
#            Team
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Careers" href="/corp/careers/">
#            Careers
#           </a>
#           <div style="display: none;">
#            <a href="bsbxsaafavrae.html" id="sazztsauwtyrydwrcuxyeuescsc" rel="file">
#             vuuxfvxbaebdbdw
#            </a>
#           </div>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link" data-analytics-category="Internal Link" data-analytics-label="Header/Press" href="/corp/press/">
#            Press
#           </a>
#          </li>
#          <li class="headerNav-dropdownLine">
#           <a class="headerNav-link js-noTrackingEventForClick" data-analytics-category="ContactUs" data-analytics-label="Header" data-sw-sdk="" data-sw-sdk-init-state="contact">
#            Contact Us
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <!-- End Company -->
#       <!-- Pricing -->
#       <li class="headerNav-item headerNav-item--pricing">
#        <a class="headerNav-itemTitle headerNav-itemTitle--link" data-analytics-category="Internal Link" data-analytics-label="Header/Pricing" href="/corp/pricing" itemprop="url">
#         Pricing
#        </a>
#       </li>
#       <!-- End Pricing -->
#      </ul>
#      <!-- End Navigation -->
#      <button class="headerMenu-toggleBtn" id="js-headerMenuToggleBtn">
#       <span class="headerMenu-toggleBtnHamburger">
#       </span>
#      </button>
#     </div>
#     <!-- End Menu -->
#    </header>
#    <main class="content">
#     <div class="analysisPage analysisPage--website isPrintable-false js-analysisPage" data-navbar="SwModule.Views.NavbarView" data-view="SwModule.Views.FixedTooltipView">
#      <div class="analysisPage-container js-websitePage" data-type="website" data-view="SwModule.Views.MainView">
#       <nav class="scroll-navbar js-scroll-nav is-fixed" role="navigation">
#        <a class="navigationLink with-icon overview icon-overview js-navigationLink is-active" data-analytics-category="Scroll Link" data-analytics-label="Navigation Bar/Overview" data-section="overview" href="javascript:void(0)">
#         Overview
#        </a>
#        <a class="navigationLink with-icon referrals icon-referrals disabledInCompared js-navigationLink" data-analytics-category="Scroll Link" data-analytics-label="Navigation Bar/Referrals" data-section="referrals" href="javascript:void(0)">
#         Referrals
#        </a>
#        <a class="navigationLink with-icon search icon-search disabledInCompared js-navigationLink" data-analytics-category="Scroll Link" data-analytics-label="Navigation Bar/Search" data-section="search" href="javascript:void(0)">
#         Search
#        </a>
#        <a class="navigationLink with-icon social icon-social disabledInCompared js-navigationLink" data-analytics-category="Scroll Link" data-analytics-label="Navigation Bar/Social" data-section="social" href="javascript:void(0)">
#         Social
#        </a>
#        <a class="navigationLink with-icon display icon-display disabledInCompared js-navigationLink" data-analytics-category="Scroll Link" data-analytics-label="Navigation Bar/Display" data-section="display" href="javascript:void(0)">
#         Display
#        </a>
#        <a class="navigationLink with-icon websiteContent icon-website-content disabledInCompared js-navigationLink" data-analytics-category="Scroll Link" data-analytics-label="Navigation Bar/WebsiteContent" data-section="websiteContent" href="javascript:void(0)">
#         Content
#        </a>
#        <a class="navigationLink with-icon alsoVisited icon-audience disabledInCompared js-navigationLink" data-analytics-category="Scroll Link" data-analytics-label="Navigation Bar/Audience" data-section="alsoVisited" href="javascript:void(0)">
#         Audience
#        </a>
# ...
#   </script>
#   <div class="sw-glass-pane" id="sw-sdk-container">
#   </div>
#   <div id="d__fFH" style="position: absolute; top: -5000px; left: -5000px;">
#    <object classid="clsid:3050f819-98b5-11cf-bb82-00aa00bdce0b" height="0px" id="d_dlg" width="0px">
#    </object>
#    <span id="d__fF" style='font-family: "Courier",serif; font-size: 72px; visibility: hidden;'>
#     The quick brown fox jumps over the lazy dog.
#    </span>
#   </div>
#   <webengagedata>
#    <style type="text/css">
#     #webklipper-publisher-widget-container, #webklipper-publisher-widget-container * {overflow:visible; -webkit-box-sizing: content-box; -moz-box-sizing: content-box;  box-sizing: content-box; margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;}
#    </style>
#    <div id="webklipper-publisher-widget-container">
#     <iframe frameborder="0" id="webengage-engagement-callback-frame" marginheight="0" marginwidth="0" name="webengage-engagement-callback-frame" style="position: absolute; background-color: transparent; bottom: 0px; right: 0px; border: medium none; overflow: hidden; visibility: hidden; display: none;">
#     </iframe>
#     <iframe frameborder="0" id="_we_wk_data_store" marginheight="0" marginwidth="0" name="_we_wk_data_store" src="https://z15ba20a04.webengage.co/storage-frame-1.15.htm?cdn=y&amp;cbf=webengage-engagement-callback-frame&amp;lc=~15ba20a04" style="position: absolute; background-color: transparent; bottom: 0px; right: 0px; border: medium none; overflow: hidden; visibility: hidden; display: none;">
#     </iframe>
#     <script async="" charset="UTF-8" src="https://c.webengage.com/upf.js?licenseCode=~15ba20a04&amp;luid=03c07c0d2f34524f7d84655eac4a813a0d9815cc&amp;lp=https%3A%2F%2Fwww.similarweb.com%2Fwebsite%2Fshotput.com%23overview&amp;rf=&amp;geo=y&amp;jsonp=_we_jsonp_global_cb_1504143767597" type="text/javascript">
#     </script>
#     <script async="" charset="UTF-8" src="//d23nd6ymopvz52.cloudfront.net/webengage/~15ba20a04/i2l1kgd.js?r=1457409075000" type="text/javascript">
#     </script>
#     <script async="" charset="UTF-8" src="//d23nd6ymopvz52.cloudfront.net/webengage/~15ba20a04/~5bjla40.js?r=1490579510000" type="text/javascript">
#     </script>
#    </div>
#   </webengagedata>
#   <script id="" type="text/javascript">
#    (function(){var a=window._fbq||(window._fbq=[]);if(!a.loaded){var b=document.createElement("script");b.async=!0;b.src="//connect.facebook.net/en_US/fbds.js";var c=document.getElementsByTagName("script")[0];c.parentNode.insertBefore(b,c);a.loaded=!0}a.push(["addPixelId","596735957094535"])})();window._fbq=window._fbq||[];window._fbq.push(["track","PixelInitialized",{}]);
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=596735957094535&amp;ev=PixelInitialized" style="display:none" width="1"/>
#   </noscript>
#   <div style="display: none; visibility: hidden;">
#    <script>
#     (function(){var b=window._fbq||(window._fbq=[]);if(!b.loaded){var a=document.createElement("script");a.async=!0;a.src="//connect.facebook.net/en_US/fbds.js";var c=document.getElementsByTagName("script")[0];c.parentNode.insertBefore(a,c);b.loaded=!0}})();window._fbq=window._fbq||[];window._fbq.push(["track","6019053064983",{value:"0.00",currency:"USD"}]);
#    </script>
#    <noscript>
#    </noscript>
#   </div>
#   <script id="" type="text/javascript">
#    function readCookie(a){a+="\x3d";for(var d=document.cookie.split(/;\s*/),e=0;e<d.length;e++){var g=d[e];if(0==g.indexOf(a))return g.substring(a.length)}return null}var cookie_A=readCookie("user_num");
# if(cookie_A)(function(a,d,e,g,c,f,b){a.GoogleAnalyticsObject=c;a[c]=a[c]||function(){(a[c].q=a[c].q||[]).push(arguments)};a[c].l=1*new Date;f=d.createElement(e);b=d.getElementsByTagName(e)[0];f.async=1;f.src=g;b.parentNode.insertBefore(f,b)})(window,document,"script","//www.google-analytics.com/analytics.js","ga"),ga("create","UA-42469261-1","auto"),ga("send","event","user","loyal_user"),function(a,d,e,g,c){var f,b;a[c]=a[c]||[];f=function(){var b={ti:"5011203"};b.q=a[c];a[c]=new UET(b);a[c].push("pageLoad")};
# b=d.createElement(e);b.src=g;b.async=1;b.onload=b.onreadystatechange=function(){var a=this.readyState;a&&"loaded"!==a&&"complete"!==a||(f(),b.onload=b.onreadystatechange=null)};d=d.getElementsByTagName(e)[0];d.parentNode.insertBefore(b,d)}(window,document,"script","//bat.bing.com/bat.js","uetq");else{document.cookie="user_num\x3dnowset; expires\x3d31 December 2019; path\x3d/";var User_ID=Math.floor(1E8*Math.random()+1),dimensionValue=User_ID;ga("set","dimension3",dimensionValue)};
#   </script>
#   <div style="display: none; visibility: hidden;">
#    <script src="//platform.twitter.com/oct.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     twttr.conversion.trackPid("l6abe",{tw_sale_amount:0,tw_order_quantity:0});
#    </script>
#    <noscript>
#    </noscript>
#   </div>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","//connect.facebook.net/en_US/fbevents.js");fbq("init","1523666777957920");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=1523666777957920&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","579140632173169");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=579140632173169&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","647747115332565");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=647747115332565&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","//connect.facebook.net/en_US/fbevents.js");fbq("init","596735957094535");var desc=google_tag_manager["GTM-NRWLLQ"].macro('gtm4');fbq("trackCustom","Page_Cat",{custom_param:google_tag_manager["GTM-NRWLLQ"].macro('gtm5')});
#   </script>
#   <script id="" src="//platform.twitter.com/oct.js" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    twttr.conversion.trackPid("nu3yv",{tw_sale_amount:0,tw_order_quantity:0});
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://analytics.twitter.com/i/adsct?txn_id=nu3yv&amp;p_id=Twitter&amp;tw_sale_amount=0&amp;tw_order_quantity=0" style="display:none;" width="1"/>
#    <img alt="" height="1" src="//t.co/i/adsct?txn_id=nu3yv&amp;p_id=Twitter&amp;tw_sale_amount=0&amp;tw_order_quantity=0" style="display:none;" width="1"/>
#   </noscript>
#   <img alt="" border="0" height="1" src="https://secure.adnxs.com/seg?t=2&amp;add=&amp;redir=https%3A%2F%2Fsecure.adnxs.com%2Fseg%3Fadd%3D%26add_code%3Dwww_similarweb_com%2Csimilarweb_com%26member%3D232%26redir%3Dhttps%253A%252F%252Fimp2.ads.linkedin.com%252Fl" style="display: none;" width="1"/>
#   <img alt="" border="0" height="1" src="https://cm.g.doubleclick.net/pixel?google_nid=bizo_bk_cm&amp;google_cm" style="display: none;" width="1"/>
#   <script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=l6abe&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels" type="text/javascript">
#   </script>
#   <script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nu3yv&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels" type="text/javascript">
#   </script>
#   <iframe id="intercom-frame" style="display: none;">
#   </iframe>
#   <div id="intercom-container" style="position: fixed; width: 0px; height: 0px; bottom: 0px; right: 0px; z-index: 2147483647;">
#    <div class="intercom-app intercom-app-launcher-enabled" data-reactroot="">
#     <span>
#     </span>
#     <iframe allowfullscreen="" class="intercom-launcher-frame">
#     </iframe>
#     <span>
#     </span>
#     <!-- react-empty: 4 -->
#     <span>
#     </span>
#     <!-- react-empty: 6 -->
#    </div>
#   </div>
#  </body>
# </html>
# ********  Start for loop to read soup  ********
# ********  in soup for loop line first read is  ********
# <div class="rankingItem-underTitle" itemprop="url">
# <a class="rankingItem-subTitle is-link" data-analytics-category="Internal Link" data-analytics-label="Global Rank/Worldwide" href="/top-websites" itemprop="significantLink">Worldwide</a> </div>
# ********  in soup for loop line first read is  ********
# <div class="rankingItem-underTitle" itemprop="url">
# <a class="rankingItem-subTitle is-link" data-analytics-category="Internal Link" data-analytics-label="Country Rank/840" href="/top-websites/united-states" itemprop="significantLink">United States</a> <i class="flag us"></i> </div>
# ********  in soup for loop line first read is  ********
# <div class="rankingItem-underTitle" itemprop="url">
# <a class="rankingItem-subTitle is-link" data-analytics-category="Internal Link" data-analytics-label="Category Rank/sports" href="/top-websites/category/sports" itemprop="significantLink">Sports</a> <a class="rankingItem-categoryEdit js-editCategory" data-options='{"domain":"shotput.com","category": "Sports","categoryIconClass":"sports","categoryLabel": "Sports"}' itemprop="name">Edit</a>
# </div>
# ********  in soup for loop line second read is  ********
# <div class="rankingItem-rank js-editable">
# <span class="rankingItem-value js-countable" data-value="5,447,784">5,447,784</span><i class="rankingItem-valueIcon rankingItem-valueIcon--decreased icon-arrow-down-ranking rankingItem-valueIcon--is-shown"></i>
# </div>
# ********  in soup for loop line second read is  ********
# <div class="rankingItem-rank js-editable">
# <span class="rankingItem-value js-countable" data-value="2,117,644">2,117,644</span><i class="rankingItem-valueIcon rankingItem-valueIcon--decreased icon-arrow-down-ranking rankingItem-valueIcon--is-shown"></i>
# </div>
# ********  in soup for loop line second read is  ********
# <div class="rankingItem-rank js-editable">
# <span class="rankingItem-value js-countable" data-value="106,307">106,307</span><i class="rankingItem-valueIcon rankingItem-valueIcon--decreased icon-arrow-down-ranking rankingItem-valueIcon--is-shown"></i>
# </div>
# ********  in soup for loop line second read is  ********
# <span class="rankingItem-value js-countable" data-value="5,447,784">5,447,784</span>
# ********  in soup for loop line second read is  ********
# <span class="rankingItem-value js-countable" data-value="2,117,644">2,117,644</span>
# ********  in soup for loop line second read is  ********
# <span class="rankingItem-value js-countable" data-value="106,307">106,307</span>
# ********  in soup for loop line third read is  ********
# ********  in soup for loop line third read is  ********
# ********  in soup for loop line third read is  ********
# ********  in soup for loop line fourth read is  ********
# <span class="engagementInfo-valueNumber js-countValue">&lt;12K</span>
# ********  in soup for loop line fourth read is  ********
# <span class="engagementInfo-valueNumber js-countValue">00:01:42</span>
# ********  in soup for loop line fourth read is  ********
# <span class="engagementInfo-valueNumber js-countValue">2.39</span>
# ********  in soup for loop line fourth read is  ********
# <span class="engagementInfo-valueNumber js-countValue">54.01%</span>
